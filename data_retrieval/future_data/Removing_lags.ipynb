# %%
import pandas as pd
import numpy as np

# %%
import os

os.getcwd()
# Out:
# '/Users/skyfano/Documents/Masterarbeit/Prediction_of_energy_prices'

# %%
df = pd.read_csv('./data/Final_data/final_data_july.csv')
train_df = pd.read_csv('./data/Final_data/train_df.csv')
test_df = pd.read_csv('./data/Final_data/test_df.csv')

# %%
df.head()
# Out:
#          Date  Day_ahead_price (€/MWh)  Solar_radiation (W/m2)  \
# 0  2012-01-08                    26.83                   17.54
# 1  2012-01-09                    47.91                   13.04
# 2  2012-01-10                    45.77                   28.71
# 3  2012-01-11                    47.83                   21.58
# 4  2012-01-12                    43.10                   25.12
#
#    Wind_speed (m/s)  Temperature (°C)  Biomass (GWh)  Hard_coal (GWh)  \
# 0              5.21              3.74         98.605          189.718
# 1              4.24              3.80         98.605          344.154
# 2              4.30              4.81         98.605          360.126
# 3              4.08              5.14         98.605          360.330
# 4              6.77              4.98         98.605          306.521
#
#    Hydro (GWh)  Lignite (GWh)  Natural_gas (GWh)  ...  Lag_1_day  Lag_2_days  \
# 0       48.467        354.178            256.892  ...      32.58       36.26
# ...

# %%
# Assuming df is your DataFrame
df = df.drop(columns=['Lag_1_day', 'Lag_2_days', 'Lag_3_days', 'Lag_4_days', 'Lag_5_days',
                      'Lag_6_days', 'Lag_7_days', 'Rolling_mean_7'])

train_df = train_df.drop(columns=['Lag_1_day', 'Lag_2_days', 'Lag_3_days', 'Lag_4_days', 'Lag_5_days',
                                  'Lag_6_days', 'Lag_7_days', 'Rolling_mean_7'])
test_df = test_df.drop(columns=['Lag_1_day', 'Lag_2_days', 'Lag_3_days', 'Lag_4_days', 'Lag_5_days',
                                'Lag_6_days', 'Lag_7_days', 'Rolling_mean_7'])

# %%
# save the dataframe to a new csv file
df.to_csv('./data/Final_data/final_data_no_lags.csv', index=False)
train_df.to_csv('./data/Final_data/train_df_no_lags.csv', index=False)
test_df.to_csv('./data/Final_data/test_df_no_lags.csv', index=False)
