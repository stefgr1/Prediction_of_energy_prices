# %% [markdown]
# ## Import all the data from March to June in 2024 and apply the best performing model to predict the future

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
from pathlib import Path
import pandas as pd

# %%
# Get the current working directory
current_dir = Path.cwd()

# Navigate two directories up
parent_dir = current_dir.parents[1]  # parents[0] is the immediate parent

# %%
# Append the filename to the parent directory
day_ahead_file_path = parent_dir / 'data/Application_data/Day_ahead/day_ahead_prices_jan_july.csv'
energy_prod_file_path = parent_dir / 'data/Application_data/Energy_production/energy_production_march_july_cleaned.csv'
bev_file_path = parent_dir / 'data/BEV_vehicles/storage/BEV_vehicles_per_day.csv'
oil_price_file_path = parent_dir / 'data/Application_data/Oil_price/Brent_oil_march_july_cleaned.csv'
energy_balance_file_path = parent_dir / 'data/Application_data/Import_export/power_import_export_march_june.csv'
elements_file_path = parent_dir / 'data/Application_data/Elements/elements_march_june.csv'
csv_file_path = parent_dir / 'data/Application_data/Day_ahead/day_ahead_prices_jan_july.csv'
ttf_gas_price_2_path = parent_dir / 'data/Application_data/Gas_prices/TTF_final_2.csv'

# %%
# Rename column "Unnamed: 0" to "Date"

# %%
# Read the csv file
day_ahead = pd.read_csv(csv_file_path)
energy_prod = pd.read_csv(energy_prod_file_path)
bev = pd.read_csv(bev_file_path)
oil_price = pd.read_csv(oil_price_file_path)
energy_balance = pd.read_csv(energy_balance_file_path)
elements = pd.read_csv(elements_file_path)   
ttf_gas = pd.read_csv(ttf_gas_price_2_path)

# rename "date" to "Date" for energy_prod and engergy_balance
energy_prod.rename(columns={'date':'Date'}, inplace=True)
energy_balance.rename(columns={'date':'Date'}, inplace=True)
elements.rename(columns={'date':'Date'}, inplace=True)
# Rename column "Unnamed: 0" to "Date" for ttf_gas
ttf_gas.rename(columns={'Unnamed: 0':'Date'}, inplace=True)
# Rename column "CLOSE" to "TTF_gas_price (EUR)" 
ttf_gas.rename(columns={'CLOSE':'TTF_gas_price (EUR)'}, inplace=True)



# Set the Date column as the index
day_ahead.set_index('Date', inplace=True)
energy_prod.set_index('Date', inplace=True)
bev.set_index('Date', inplace=True)
oil_price.set_index('Date', inplace=True)
energy_balance.set_index('Date', inplace=True)
elements.set_index('Date', inplace=True)
ttf_gas.set_index('Date', inplace=True)

# %%
# Combine all the dataframes by the date column 
df = pd.merge(day_ahead, elements, on='Date')
df = pd.merge(df, energy_prod, on='Date')
df = pd.merge(df, energy_balance, on='Date')
df = pd.merge(df, bev, on='Date')
df = pd.merge(df, oil_price, on='Date') 
df = pd.merge(df, ttf_gas, on='Date')


# Show resulting data frame 
df
# Out:
#             Day_Ahead_Price (€/MWh)  Solar Radiation (W/m²)  Wind Speed (m/s)  \
# Date
# 2024-03-01                    70.93                   65.50              3.14
# 2024-03-02                    63.99                  101.71              3.25
# 2024-03-03                    61.08                  111.42              3.31
# 2024-03-04                    75.59                   81.88              2.79
# 2024-03-05                    74.98                   52.29              3.10
# ...                             ...                     ...               ...
# 2024-06-26                   477.36                  294.00              2.66
# 2024-06-27                    92.18                  245.54              2.68
# 2024-06-28                    64.22                  277.38              3.70
# 2024-06-29                    66.86                  297.71              2.58
# 2024-06-30                    45.75                  126.42              3.98
#
#             Temperature (°C)  Biomasse (GWh)  Steinkohle (GWh)  \
# Date
# 2024-03-01              5.81         124.839            68.840
# 2024-03-02              7.75         124.742            48.551
# 2024-03-03              8.15         124.469            56.956
# 2024-03-04              6.42         124.460           110.860
# 2024-03-05              5.66         125.129           134.758
# ...                      ...             ...               ...
# 2024-06-26             21.84         109.777            53.731
# 2024-06-27             22.18         109.346            53.808
# 2024-06-28             20.82         108.416            24.795
# 2024-06-29             21.92         110.140            15.147
# 2024-06-30             18.66         109.100            21.418
#
#             Wasserkraft (GWh)  Braunkohle (GWh)  Erdgas (GWh)  Andere (GWh)  \
# Date
# 2024-03-01             55.295           252.736       256.269        61.390
# 2024-03-02             53.621           192.488       222.065        55.669
# 2024-03-03             50.715           206.578       209.388        52.162
# 2024-03-04             53.916           373.782       277.610        56.478
# 2024-03-05             53.633           399.568       307.345        60.802
# ...                       ...               ...           ...           ...
# 2024-06-26             83.948           237.612       225.785        43.533
# 2024-06-27             86.260           234.484       225.893        45.056
# 2024-06-28             82.231           167.244       189.012        45.409
# 2024-06-29             81.966           121.481       179.526        46.986
# 2024-06-30             77.955           121.919       162.550        47.035
#
#             Pumpspeicher (GWh)  Solar (GWh)  Wind Offshore (GWh)  \
# Date
# 2024-03-01              15.691       99.970              109.303
# 2024-03-02              12.299      178.801               98.946
# 2024-03-03               8.209      202.653              101.406
# 2024-03-04              20.788      101.805               49.602
# 2024-03-05              11.454       72.640              121.064
# ...                        ...          ...                  ...
# 2024-06-26              21.592      410.458               21.854
# 2024-06-27              22.189      352.861               34.405
# 2024-06-28              19.613      389.272               79.420
# 2024-06-29              25.260      410.035               17.858
# 2024-06-30              11.799      188.247               43.102
#
#             Wind Onshore (GWh)  Total Prod (GWh)  \
# Date
# 2024-03-01             258.820          1303.153
# 2024-03-02             264.598          1251.780
# 2024-03-03             235.637          1248.173
# 2024-03-04             126.337          1295.638
# 2024-03-05             179.406          1465.799
# ...                        ...               ...
# 2024-06-26             122.017          1330.307
# 2024-06-27              99.131          1263.433
# 2024-06-28             226.697          1332.109
# 2024-06-29              78.722          1087.121
# 2024-06-30             247.333          1030.458
#
#             net_total_export_import (GWh)  DailyVehicles  Oil_price (EUR)  \
# Date
# 2024-03-01                       -168.740           1012            77.45
# 2024-03-02                        -20.455           1012            77.22
# 2024-03-03                         43.071           1012            76.99
# 2024-03-04                       -149.007           1013            76.76
# 2024-03-05                        -74.175           1012            76.05
# ...                                   ...            ...              ...
# 2024-06-26                        -84.296           1448            79.03
# 2024-06-27                       -221.636           1447            80.08
# 2024-06-28                       -118.481           1447            80.10
# 2024-06-29                       -144.550           1447            80.16
# 2024-06-30                       -108.241           1447            80.22
#
#             TTF_gas_price (EUR)
# Date
# 2024-03-01              25.5000
# 2024-03-02              26.3250
# 2024-03-03              26.7375
# 2024-03-04              27.1500
# 2024-03-05              27.3700
# ...                         ...
# 2024-06-26              33.5500
# 2024-06-27              34.1600
# 2024-06-28              33.8500
# 2024-06-29              33.4250
# 2024-06-30              33.2125
#
# [122 rows x 19 columns]

# %%
df.columns
# Out:
# Index(['Day_Ahead_Price (€/MWh)', 'Solar Radiation (W/m²)', 'Wind Speed (m/s)',
#        'Temperature (°C)', 'Biomasse (GWh)', 'Steinkohle (GWh)',
#        'Wasserkraft (GWh)', 'Braunkohle (GWh)', 'Erdgas (GWh)', 'Andere (GWh)',
#        'Pumpspeicher (GWh)', 'Solar (GWh)', 'Wind Offshore (GWh)',
#        'Wind Onshore (GWh)', 'Total Prod (GWh)',
#        'net_total_export_import (GWh)', 'DailyVehicles', 'Oil_price (EUR)',
#        'TTF_gas_price (EUR)'],
#       dtype='object')

# %%
# Rename the column DailyVehicle to BEV_vehicles
df.rename(columns={'DailyVehicles':'BEV_vehicles'}, inplace=True)
# Rename the columns to English
df.rename(columns={'Biomasse (GWh)':'Biomass (GWh)', 'Steinkohle (GWh)':'Hard Coal (GWh)', 'Wasserkraft (GWh)':'Hydro (GWh)', 'Braunkohle (GWh)':'Lignite (GWh)', 'Erdgas (GWh)':'Natural Gas (GWh)', 'Andere (GWh)':'Other (GWh)', 'Pumpspeicher (GWh)':'Pumped storage generation (GWh)', 'net_total_export_import (GWh)': 'Net_total_export_import (GWh)'}, inplace=True)

# %%
df
# Out:
#             Day_Ahead_Price (€/MWh)  Solar Radiation (W/m²)  Wind Speed (m/s)  \
# Date
# 2024-03-01                    70.93                   65.50              3.14
# 2024-03-02                    63.99                  101.71              3.25
# 2024-03-03                    61.08                  111.42              3.31
# 2024-03-04                    75.59                   81.88              2.79
# 2024-03-05                    74.98                   52.29              3.10
# ...                             ...                     ...               ...
# 2024-06-26                   477.36                  294.00              2.66
# 2024-06-27                    92.18                  245.54              2.68
# 2024-06-28                    64.22                  277.38              3.70
# 2024-06-29                    66.86                  297.71              2.58
# 2024-06-30                    45.75                  126.42              3.98
#
#             Temperature (°C)  Biomass (GWh)  Hard Coal (GWh)  Hydro (GWh)  \
# Date
# 2024-03-01              5.81        124.839           68.840       55.295
# 2024-03-02              7.75        124.742           48.551       53.621
# 2024-03-03              8.15        124.469           56.956       50.715
# 2024-03-04              6.42        124.460          110.860       53.916
# 2024-03-05              5.66        125.129          134.758       53.633
# ...                      ...            ...              ...          ...
# 2024-06-26             21.84        109.777           53.731       83.948
# 2024-06-27             22.18        109.346           53.808       86.260
# 2024-06-28             20.82        108.416           24.795       82.231
# 2024-06-29             21.92        110.140           15.147       81.966
# 2024-06-30             18.66        109.100           21.418       77.955
#
#             Lignite (GWh)  Natural Gas (GWh)  Other (GWh)  \
# Date
# 2024-03-01        252.736            256.269       61.390
# 2024-03-02        192.488            222.065       55.669
# 2024-03-03        206.578            209.388       52.162
# 2024-03-04        373.782            277.610       56.478
# 2024-03-05        399.568            307.345       60.802
# ...                   ...                ...          ...
# 2024-06-26        237.612            225.785       43.533
# 2024-06-27        234.484            225.893       45.056
# 2024-06-28        167.244            189.012       45.409
# 2024-06-29        121.481            179.526       46.986
# 2024-06-30        121.919            162.550       47.035
#
#             Pumped storage generation (GWh)  Solar (GWh)  Wind Offshore (GWh)  \
# Date
# 2024-03-01                           15.691       99.970              109.303
# 2024-03-02                           12.299      178.801               98.946
# 2024-03-03                            8.209      202.653              101.406
# 2024-03-04                           20.788      101.805               49.602
# 2024-03-05                           11.454       72.640              121.064
# ...                                     ...          ...                  ...
# 2024-06-26                           21.592      410.458               21.854
# 2024-06-27                           22.189      352.861               34.405
# 2024-06-28                           19.613      389.272               79.420
# 2024-06-29                           25.260      410.035               17.858
# 2024-06-30                           11.799      188.247               43.102
#
#             Wind Onshore (GWh)  Total Prod (GWh)  \
# Date
# 2024-03-01             258.820          1303.153
# 2024-03-02             264.598          1251.780
# 2024-03-03             235.637          1248.173
# 2024-03-04             126.337          1295.638
# 2024-03-05             179.406          1465.799
# ...                        ...               ...
# 2024-06-26             122.017          1330.307
# 2024-06-27              99.131          1263.433
# 2024-06-28             226.697          1332.109
# 2024-06-29              78.722          1087.121
# 2024-06-30             247.333          1030.458
#
#             Net_total_export_import (GWh)  BEV_vehicles  Oil_price (EUR)  \
# Date
# 2024-03-01                       -168.740          1012            77.45
# 2024-03-02                        -20.455          1012            77.22
# 2024-03-03                         43.071          1012            76.99
# 2024-03-04                       -149.007          1013            76.76
# 2024-03-05                        -74.175          1012            76.05
# ...                                   ...           ...              ...
# 2024-06-26                        -84.296          1448            79.03
# 2024-06-27                       -221.636          1447            80.08
# 2024-06-28                       -118.481          1447            80.10
# 2024-06-29                       -144.550          1447            80.16
# 2024-06-30                       -108.241          1447            80.22
#
#             TTF_gas_price (EUR)
# Date
# 2024-03-01              25.5000
# 2024-03-02              26.3250
# 2024-03-03              26.7375
# 2024-03-04              27.1500
# 2024-03-05              27.3700
# ...                         ...
# 2024-06-26              33.5500
# 2024-06-27              34.1600
# 2024-06-28              33.8500
# 2024-06-29              33.4250
# 2024-06-30              33.2125
#
# [122 rows x 19 columns]

# %%
# Rename column "Hard Coal" to "Hard_coal"
df.rename(columns={'Hard Coal (GWh)': 'Hard_coal (GWh)'}, inplace=True)
# Rename column Natural Gas to Natural_gas
df.rename(columns={'Natural Gas (GWh)': 'Natural_gas (GWh)'}, inplace=True)
# Rename column "Nuclear" to "Nuclear_energy"
df.rename(columns={'Nuclear (GWh)': 'Nuclear_energy (GWh)'}, inplace=True)
# Rename column "Pumped Storage generation" to "Pumped_storage_generation"
df.rename(columns={'Pumped storage generation (GWh)': 'Pumped_storage_generation (GWh)'}, inplace=True)
# Rename column "Solar" to "Solar_energy"
df.rename(columns={'Solar (GWh)': 'Solar_energy (GWh)'}, inplace=True)
# Rename column "Wind offshore (GWh)" to "Wind_offshore (GWh)"
df.rename(columns={'Wind Offshore (GWh)': 'Wind_offshore (GWh)'}, inplace=True)
# Rename column "Wind onshore (GWh)" to "Wind_onshore (GWh)"
df.rename(columns={'Wind Onshore (GWh)': 'Wind_onshore (GWh)'}, inplace=True)

# Rename column "Wind_speed" to "Wind_speed (m/s)"
df.rename(columns={'Wind Speed (m/s)': 'Wind_speed (m/s)'}, inplace=True)
# Rename column "Solar_radiation" to "Solar_radiation (W/m2)"
df.rename(columns={'Solar Radiation (W/m²)': 'Solar_radiation (W/m2)'}, inplace=True)
# Rename column "Day_Ahead_Price" to "Day_ahead_price (EUR/MWh)"
df.rename(columns={'Day_Ahead_Price (€/MWh)': 'Day_ahead_price (€/MWh)'}, inplace=True)
df.rename(
    columns={'TTF_gas_price (EUR)': 'TTF_gas_price (€/MWh)'}, inplace=True)

# Drop column Total Prod (GWh)
df.drop(columns=['Total Prod (GWh)'], inplace=True)

# Add a column for "Nuclear_energy (GWh)" containing only 0 values
df['Nuclear_energy (GWh)'] = 0

# %%
df
# Out:
#             Day_ahead_price (€/MWh)  Solar_radiation (W/m2)  Wind_speed (m/s)  \
# Date
# 2024-03-01                    70.93                   65.50              3.14
# 2024-03-02                    63.99                  101.71              3.25
# 2024-03-03                    61.08                  111.42              3.31
# 2024-03-04                    75.59                   81.88              2.79
# 2024-03-05                    74.98                   52.29              3.10
# ...                             ...                     ...               ...
# 2024-06-26                   477.36                  294.00              2.66
# 2024-06-27                    92.18                  245.54              2.68
# 2024-06-28                    64.22                  277.38              3.70
# 2024-06-29                    66.86                  297.71              2.58
# 2024-06-30                    45.75                  126.42              3.98
#
#             Temperature (°C)  Biomass (GWh)  Hard_coal (GWh)  Hydro (GWh)  \
# Date
# 2024-03-01              5.81        124.839           68.840       55.295
# 2024-03-02              7.75        124.742           48.551       53.621
# 2024-03-03              8.15        124.469           56.956       50.715
# 2024-03-04              6.42        124.460          110.860       53.916
# 2024-03-05              5.66        125.129          134.758       53.633
# ...                      ...            ...              ...          ...
# 2024-06-26             21.84        109.777           53.731       83.948
# 2024-06-27             22.18        109.346           53.808       86.260
# 2024-06-28             20.82        108.416           24.795       82.231
# 2024-06-29             21.92        110.140           15.147       81.966
# 2024-06-30             18.66        109.100           21.418       77.955
#
#             Lignite (GWh)  Natural_gas (GWh)  Other (GWh)  \
# Date
# 2024-03-01        252.736            256.269       61.390
# 2024-03-02        192.488            222.065       55.669
# 2024-03-03        206.578            209.388       52.162
# 2024-03-04        373.782            277.610       56.478
# 2024-03-05        399.568            307.345       60.802
# ...                   ...                ...          ...
# 2024-06-26        237.612            225.785       43.533
# 2024-06-27        234.484            225.893       45.056
# 2024-06-28        167.244            189.012       45.409
# 2024-06-29        121.481            179.526       46.986
# 2024-06-30        121.919            162.550       47.035
#
#             Pumped_storage_generation (GWh)  Solar_energy (GWh)  \
# Date
# 2024-03-01                           15.691              99.970
# 2024-03-02                           12.299             178.801
# 2024-03-03                            8.209             202.653
# 2024-03-04                           20.788             101.805
# 2024-03-05                           11.454              72.640
# ...                                     ...                 ...
# 2024-06-26                           21.592             410.458
# 2024-06-27                           22.189             352.861
# 2024-06-28                           19.613             389.272
# 2024-06-29                           25.260             410.035
# 2024-06-30                           11.799             188.247
#
#             Wind_offshore (GWh)  Wind_onshore (GWh)  \
# Date
# 2024-03-01              109.303             258.820
# 2024-03-02               98.946             264.598
# 2024-03-03              101.406             235.637
# 2024-03-04               49.602             126.337
# 2024-03-05              121.064             179.406
# ...                         ...                 ...
# 2024-06-26               21.854             122.017
# 2024-06-27               34.405              99.131
# 2024-06-28               79.420             226.697
# 2024-06-29               17.858              78.722
# 2024-06-30               43.102             247.333
#
#             Net_total_export_import (GWh)  BEV_vehicles  Oil_price (EUR)  \
# Date
# 2024-03-01                       -168.740          1012            77.45
# 2024-03-02                        -20.455          1012            77.22
# 2024-03-03                         43.071          1012            76.99
# 2024-03-04                       -149.007          1013            76.76
# 2024-03-05                        -74.175          1012            76.05
# ...                                   ...           ...              ...
# 2024-06-26                        -84.296          1448            79.03
# 2024-06-27                       -221.636          1447            80.08
# 2024-06-28                       -118.481          1447            80.10
# 2024-06-29                       -144.550          1447            80.16
# 2024-06-30                       -108.241          1447            80.22
#
#             TTF_gas_price (€/MWh)  Nuclear_energy (GWh)
# Date
# 2024-03-01                25.5000                     0
# 2024-03-02                26.3250                     0
# 2024-03-03                26.7375                     0
# 2024-03-04                27.1500                     0
# 2024-03-05                27.3700                     0
# ...                           ...                   ...
# 2024-06-26                33.5500                     0
# 2024-06-27                34.1600                     0
# 2024-06-28                33.8500                     0
# 2024-06-29                33.4250                     0
# 2024-06-30                33.2125                     0
#
# [122 rows x 19 columns]

# %%
# Import the data and prepare for further processing
def load_and_prepare_data(file_path):
    """
    Load energy prices data from a CSV file, ensure chronological order, and convert 'Date' to datetime.
    """
    df = pd.read_csv(file_path, parse_dates=['Date'])
    df['Date'] = pd.to_datetime(df['Date'])
    df.sort_values('Date', inplace=True)
    df.set_index('Date', inplace=True)
    df = pd.DataFrame(df)
    return df
    
# Import the data
df_old = load_and_prepare_data('../../data/Final_data/final_data.csv')

# %%
df.columns
# Out:
# Index(['Day_ahead_price (€/MWh)', 'Solar_radiation (W/m2)', 'Wind_speed (m/s)',
#        'Temperature (°C)', 'Biomass (GWh)', 'Hard_coal (GWh)', 'Hydro (GWh)',
#        'Lignite (GWh)', 'Natural_gas (GWh)', 'Other (GWh)',
#        'Pumped_storage_generation (GWh)', 'Solar_energy (GWh)',
#        'Wind_offshore (GWh)', 'Wind_onshore (GWh)',
#        'Net_total_export_import (GWh)', 'BEV_vehicles', 'Oil_price (EUR)',
#        'TTF_gas_price (€/MWh)', 'Nuclear_energy (GWh)'],
#       dtype='object')

# %%
df_old.columns
# Out:
# Index(['BEV_vehicles', 'Biomass (GWh)', 'Day_ahead_price (€/MWh)',
#        'Hard_coal (GWh)', 'Hydro (GWh)', 'Lignite (GWh)', 'Natural_gas (GWh)',
#        'Nuclear_energy (GWh)', 'Oil_price (EUR)', 'Other (GWh)',
#        'Pumped_storage_generation (GWh)', 'Solar_energy (GWh)',
#        'Solar_radiation (W/m2)', 'TTF_gas_price (€/MWh)', 'Temperature (°C)',
#        'Wind_offshore (GWh)', 'Wind_onshore (GWh)', 'Wind_speed (m/s)',
#        'Net_total_export_import (GWh)'],
#       dtype='object')

# %%
# Assuming df1 and df2 are your two DataFrames
# df1 has the original desired order, and df2 needs to be reordered

# Define the correct order of columns based on the desired order
correct_order = ['Day_ahead_price (€/MWh)', 'Solar_radiation (W/m2)', 'Wind_speed (m/s)',
                 'Temperature (°C)', 'Biomass (GWh)', 'Hard_coal (GWh)', 'Hydro (GWh)',
                 'Lignite (GWh)', 'Natural_gas (GWh)', 'Other (GWh)',
                 'Pumped_storage_generation (GWh)', 'Solar_energy (GWh)',
                 'Wind_offshore (GWh)', 'Wind_onshore (GWh)',
                 'Net_total_export_import (GWh)', 'BEV_vehicles', 'Oil_price (EUR)',
                 'TTF_gas_price (€/MWh)', 'Nuclear_energy (GWh)']

# Reorder df1 and df2 according to the correct order
df = df[correct_order]
df_old = df_old[correct_order]

# %%
df
# Out:
#             Day_ahead_price (€/MWh)  Solar_radiation (W/m2)  Wind_speed (m/s)  \
# Date
# 2024-03-01                    70.93                   65.50              3.14
# 2024-03-02                    63.99                  101.71              3.25
# 2024-03-03                    61.08                  111.42              3.31
# 2024-03-04                    75.59                   81.88              2.79
# 2024-03-05                    74.98                   52.29              3.10
# ...                             ...                     ...               ...
# 2024-06-26                   477.36                  294.00              2.66
# 2024-06-27                    92.18                  245.54              2.68
# 2024-06-28                    64.22                  277.38              3.70
# 2024-06-29                    66.86                  297.71              2.58
# 2024-06-30                    45.75                  126.42              3.98
#
#             Temperature (°C)  Biomass (GWh)  Hard_coal (GWh)  Hydro (GWh)  \
# Date
# 2024-03-01              5.81        124.839           68.840       55.295
# 2024-03-02              7.75        124.742           48.551       53.621
# 2024-03-03              8.15        124.469           56.956       50.715
# 2024-03-04              6.42        124.460          110.860       53.916
# 2024-03-05              5.66        125.129          134.758       53.633
# ...                      ...            ...              ...          ...
# 2024-06-26             21.84        109.777           53.731       83.948
# 2024-06-27             22.18        109.346           53.808       86.260
# 2024-06-28             20.82        108.416           24.795       82.231
# 2024-06-29             21.92        110.140           15.147       81.966
# 2024-06-30             18.66        109.100           21.418       77.955
#
#             Lignite (GWh)  Natural_gas (GWh)  Other (GWh)  \
# Date
# 2024-03-01        252.736            256.269       61.390
# 2024-03-02        192.488            222.065       55.669
# 2024-03-03        206.578            209.388       52.162
# 2024-03-04        373.782            277.610       56.478
# 2024-03-05        399.568            307.345       60.802
# ...                   ...                ...          ...
# 2024-06-26        237.612            225.785       43.533
# 2024-06-27        234.484            225.893       45.056
# 2024-06-28        167.244            189.012       45.409
# 2024-06-29        121.481            179.526       46.986
# 2024-06-30        121.919            162.550       47.035
#
#             Pumped_storage_generation (GWh)  Solar_energy (GWh)  \
# Date
# 2024-03-01                           15.691              99.970
# 2024-03-02                           12.299             178.801
# 2024-03-03                            8.209             202.653
# 2024-03-04                           20.788             101.805
# 2024-03-05                           11.454              72.640
# ...                                     ...                 ...
# 2024-06-26                           21.592             410.458
# 2024-06-27                           22.189             352.861
# 2024-06-28                           19.613             389.272
# 2024-06-29                           25.260             410.035
# 2024-06-30                           11.799             188.247
#
#             Wind_offshore (GWh)  Wind_onshore (GWh)  \
# Date
# 2024-03-01              109.303             258.820
# 2024-03-02               98.946             264.598
# 2024-03-03              101.406             235.637
# 2024-03-04               49.602             126.337
# 2024-03-05              121.064             179.406
# ...                         ...                 ...
# 2024-06-26               21.854             122.017
# 2024-06-27               34.405              99.131
# 2024-06-28               79.420             226.697
# 2024-06-29               17.858              78.722
# 2024-06-30               43.102             247.333
#
#             Net_total_export_import (GWh)  BEV_vehicles  Oil_price (EUR)  \
# Date
# 2024-03-01                       -168.740          1012            77.45
# 2024-03-02                        -20.455          1012            77.22
# 2024-03-03                         43.071          1012            76.99
# 2024-03-04                       -149.007          1013            76.76
# 2024-03-05                        -74.175          1012            76.05
# ...                                   ...           ...              ...
# 2024-06-26                        -84.296          1448            79.03
# 2024-06-27                       -221.636          1447            80.08
# 2024-06-28                       -118.481          1447            80.10
# 2024-06-29                       -144.550          1447            80.16
# 2024-06-30                       -108.241          1447            80.22
#
#             TTF_gas_price (€/MWh)  Nuclear_energy (GWh)
# Date
# 2024-03-01                25.5000                     0
# 2024-03-02                26.3250                     0
# 2024-03-03                26.7375                     0
# 2024-03-04                27.1500                     0
# 2024-03-05                27.3700                     0
# ...                           ...                   ...
# 2024-06-26                33.5500                     0
# 2024-06-27                34.1600                     0
# 2024-06-28                33.8500                     0
# 2024-06-29                33.4250                     0
# 2024-06-30                33.2125                     0
#
# [122 rows x 19 columns]

# %%
df_old
# Out:
#             Day_ahead_price (€/MWh)  Solar_radiation (W/m2)  Wind_speed (m/s)  \
# Date
# 2012-01-01                    18.19                   14.75              4.95
# 2012-01-02                    33.82                   15.12              5.00
# 2012-01-03                    35.03                   31.88              7.77
# 2012-01-04                    32.16                   25.21              8.04
# 2012-01-05                    20.35                   13.46              9.98
# ...                             ...                     ...               ...
# 2024-02-25                    61.09                   97.58              3.43
# 2024-02-26                    66.27                   73.25              3.12
# 2024-02-27                    73.84                   58.12              3.11
# 2024-02-28                    71.82                   66.00              2.46
# 2024-02-29                    63.20                   98.83              3.48
#
#             Temperature (°C)  Biomass (GWh)  Hard_coal (GWh)  Hydro (GWh)  \
# Date
# 2012-01-01              8.39         98.605          108.454       51.011
# 2012-01-02              7.41         98.605          222.656       51.862
# 2012-01-03              5.23         98.605          162.204       48.851
# 2012-01-04              4.78         98.605          189.633       47.101
# 2012-01-05              4.23         98.605          175.733       45.854
# ...                      ...            ...              ...          ...
# 2024-02-25              4.52        123.683           48.501       58.671
# 2024-02-26              4.96        124.810           69.146       58.444
# 2024-02-27              4.53        124.989          103.379       59.181
# 2024-02-28              3.69        125.068           93.416       58.160
# 2024-02-29              4.72        124.721           69.303       54.257
#
#             Lignite (GWh)  Natural_gas (GWh)  Other (GWh)  \
# Date
# 2012-01-01        325.337            188.811       54.040
# 2012-01-02        343.168            229.293       54.166
# 2012-01-03        336.773            241.297       53.518
# 2012-01-04        323.976            252.289       52.194
# 2012-01-05        327.502            259.018       52.179
# ...                   ...                ...          ...
# 2024-02-25        193.697            255.124       60.627
# 2024-02-26        281.177            289.764       59.810
# 2024-02-27        351.355            354.042       67.170
# 2024-02-28        350.348            338.216       65.375
# 2024-02-29        237.303            266.570       55.867
#
#             Pumped_storage_generation (GWh)  Solar_energy (GWh)  \
# Date
# 2012-01-01                           19.314               6.263
# 2012-01-02                           28.892               6.312
# 2012-01-03                           21.072              24.226
# 2012-01-04                           28.300              14.157
# 2012-01-05                           31.887               4.728
# ...                                     ...                 ...
# 2024-02-25                           13.565             169.216
# 2024-02-26                           12.231             110.504
# 2024-02-27                           23.753              85.584
# 2024-02-28                           19.042             106.330
# 2024-02-29                           16.402             170.459
#
#             Wind_offshore (GWh)  Wind_onshore (GWh)  \
# Date
# 2012-01-01                3.404             235.467
# 2012-01-02                3.350             231.772
# 2012-01-03                7.292             504.484
# 2012-01-04                7.828             541.528
# 2012-01-05                8.280             572.819
# ...                         ...                 ...
# 2024-02-25               29.879             278.787
# 2024-02-26               62.336             239.555
# 2024-02-27               16.951             131.761
# 2024-02-28               68.585              76.355
# 2024-02-29              135.399             352.238
#
#             Net_total_export_import (GWh)  BEV_vehicles  Oil_price (EUR)  \
# Date
# 2012-01-01                         54.662             6            99.64
# 2012-01-02                        -64.477             6           100.04
# 2012-01-03                        -35.078             6           100.44
# 2012-01-04                         22.924             6           103.15
# 2012-01-05                         35.618             6           103.92
# ...                                   ...           ...              ...
# 2024-02-25                        -36.930           947            75.22
# 2024-02-26                       -198.686           947            75.09
# 2024-02-27                       -209.332           947            76.11
# 2024-02-28                       -206.956           947            76.57
# 2024-02-29                        -59.574           963            76.99
#
#             TTF_gas_price (€/MWh)  Nuclear_energy (GWh)
# Date
# 2012-01-01                21.1000               250.979
# 2012-01-02                20.0000               258.671
# 2012-01-03                20.9000               271.495
# 2012-01-04                21.4000               270.613
# 2012-01-05                21.3000               287.555
# ...                           ...                   ...
# 2024-02-25                23.7625                 0.000
# 2024-02-26                23.9000                 0.000
# 2024-02-27                24.8300                 0.000
# 2024-02-28                24.8000                 0.000
# 2024-02-29                24.8800                 0.000
#
# [4443 rows x 19 columns]

# %%
# Ensure df1 has only the columns that are present in df2
common_columns = df_old.columns.intersection(df.columns)

# Reorder df1 to match the column order of df2, using only common columns
df = df[common_columns]

# Display the first few rows of df1 to confirm the column order
df
# Out:
#             Day_ahead_price (€/MWh)  Solar_radiation (W/m2)  Wind_speed (m/s)  \
# Date
# 2024-03-01                    70.93                   65.50              3.14
# 2024-03-02                    63.99                  101.71              3.25
# 2024-03-03                    61.08                  111.42              3.31
# 2024-03-04                    75.59                   81.88              2.79
# 2024-03-05                    74.98                   52.29              3.10
# ...                             ...                     ...               ...
# 2024-06-26                   477.36                  294.00              2.66
# 2024-06-27                    92.18                  245.54              2.68
# 2024-06-28                    64.22                  277.38              3.70
# 2024-06-29                    66.86                  297.71              2.58
# 2024-06-30                    45.75                  126.42              3.98
#
#             Temperature (°C)  Biomass (GWh)  Hard_coal (GWh)  Hydro (GWh)  \
# Date
# 2024-03-01              5.81        124.839           68.840       55.295
# 2024-03-02              7.75        124.742           48.551       53.621
# 2024-03-03              8.15        124.469           56.956       50.715
# 2024-03-04              6.42        124.460          110.860       53.916
# 2024-03-05              5.66        125.129          134.758       53.633
# ...                      ...            ...              ...          ...
# 2024-06-26             21.84        109.777           53.731       83.948
# 2024-06-27             22.18        109.346           53.808       86.260
# 2024-06-28             20.82        108.416           24.795       82.231
# 2024-06-29             21.92        110.140           15.147       81.966
# 2024-06-30             18.66        109.100           21.418       77.955
#
#             Lignite (GWh)  Natural_gas (GWh)  Other (GWh)  \
# Date
# 2024-03-01        252.736            256.269       61.390
# 2024-03-02        192.488            222.065       55.669
# 2024-03-03        206.578            209.388       52.162
# 2024-03-04        373.782            277.610       56.478
# 2024-03-05        399.568            307.345       60.802
# ...                   ...                ...          ...
# 2024-06-26        237.612            225.785       43.533
# 2024-06-27        234.484            225.893       45.056
# 2024-06-28        167.244            189.012       45.409
# 2024-06-29        121.481            179.526       46.986
# 2024-06-30        121.919            162.550       47.035
#
#             Pumped_storage_generation (GWh)  Solar_energy (GWh)  \
# Date
# 2024-03-01                           15.691              99.970
# 2024-03-02                           12.299             178.801
# 2024-03-03                            8.209             202.653
# 2024-03-04                           20.788             101.805
# 2024-03-05                           11.454              72.640
# ...                                     ...                 ...
# 2024-06-26                           21.592             410.458
# 2024-06-27                           22.189             352.861
# 2024-06-28                           19.613             389.272
# 2024-06-29                           25.260             410.035
# 2024-06-30                           11.799             188.247
#
#             Wind_offshore (GWh)  Wind_onshore (GWh)  \
# Date
# 2024-03-01              109.303             258.820
# 2024-03-02               98.946             264.598
# 2024-03-03              101.406             235.637
# 2024-03-04               49.602             126.337
# 2024-03-05              121.064             179.406
# ...                         ...                 ...
# 2024-06-26               21.854             122.017
# 2024-06-27               34.405              99.131
# 2024-06-28               79.420             226.697
# 2024-06-29               17.858              78.722
# 2024-06-30               43.102             247.333
#
#             Net_total_export_import (GWh)  BEV_vehicles  Oil_price (EUR)  \
# Date
# 2024-03-01                       -168.740          1012            77.45
# 2024-03-02                        -20.455          1012            77.22
# 2024-03-03                         43.071          1012            76.99
# 2024-03-04                       -149.007          1013            76.76
# 2024-03-05                        -74.175          1012            76.05
# ...                                   ...           ...              ...
# 2024-06-26                        -84.296          1448            79.03
# 2024-06-27                       -221.636          1447            80.08
# 2024-06-28                       -118.481          1447            80.10
# 2024-06-29                       -144.550          1447            80.16
# 2024-06-30                       -108.241          1447            80.22
#
#             TTF_gas_price (€/MWh)  Nuclear_energy (GWh)
# Date
# 2024-03-01                25.5000                     0
# 2024-03-02                26.3250                     0
# 2024-03-03                26.7375                     0
# 2024-03-04                27.1500                     0
# 2024-03-05                27.3700                     0
# ...                           ...                   ...
# 2024-06-26                33.5500                     0
# 2024-06-27                34.1600                     0
# 2024-06-28                33.8500                     0
# 2024-06-29                33.4250                     0
# 2024-06-30                33.2125                     0
#
# [122 rows x 19 columns]

# %%
# Save data frame to csv in Final_application_data folder
df.to_csv(parent_dir / 'data/Application_data/Final_application_data/final_application_data.csv')
df_old.to_csv(parent_dir / 'data/Final_data/final_data.csv')
