# %% [markdown]
# # XGBoost Model

# %%
# Load the necessary packages
from darts import TimeSeries
from darts.models import XGBModel
import pandas as pd
import plotly.graph_objs as go
import numpy as np

# %%
# Load in the train and test data
train_df = pd.read_csv('../../data/Final_data/train_df.csv')
test_df = pd.read_csv('../../data/Final_data/test_df.csv')

train_df['Date'] = pd.to_datetime(train_df['Date'])
test_df['Date'] = pd.to_datetime(test_df['Date'])

# Create the time series
series_train = TimeSeries.from_dataframe(train_df, 'Date', 'Day_ahead_price (€/MWh)').astype('float32')
series_test = TimeSeries.from_dataframe(test_df, 'Date', 'Day_ahead_price (€/MWh)').astype('float32')

# Define the future covariates columns from your dataframe
future_covariates_columns = ['Solar_radiation (W/m2)', 'Wind_speed (m/s)', 'Temperature (°C)', 
                             'Biomass (GWh)', 'Hard_coal (GWh)', 'Hydro (GWh)', 'Lignite (GWh)', 
                             'Natural_gas (GWh)', 'Other (GWh)', 'Pumped_storage_generation (GWh)', 
                             'Solar_energy (GWh)', 'Wind_offshore (GWh)', 'Wind_onshore (GWh)', 
                             'Net_total_export_import (GWh)', 'BEV_vehicles', 'Oil_price (EUR)', 
                             'TTF_gas_price (€/MWh)', 'Nuclear_energy (GWh)']

# Convert future covariates to TimeSeries objects
future_covariates_train = TimeSeries.from_dataframe(train_df, 'Date', future_covariates_columns).astype('float32')
future_covariates_test = TimeSeries.from_dataframe(test_df, 'Date', future_covariates_columns).astype('float32')

# Concatenate the train and test data
df = pd.concat([train_df, test_df])
df['Date'] = pd.to_datetime(df['Date'])

df
# Out:
#           Date  Day_ahead_price (€/MWh)  Solar_radiation (W/m2)  \
# 0   2012-01-01                    18.19                   14.75
# 1   2012-01-02                    33.82                   15.12
# 2   2012-01-03                    35.03                   31.88
# 3   2012-01-04                    32.16                   25.21
# 4   2012-01-05                    20.35                   13.46
# ..         ...                      ...                     ...
# 754 2024-07-24                    66.61                  225.04
# 755 2024-07-25                    78.34                  272.71
# 756 2024-07-26                    93.04                  172.33
# 757 2024-07-27                    80.74                  176.67
# 758 2024-07-28                    43.96                  235.92
#
#      Wind_speed (m/s)  Temperature (°C)  Biomass (GWh)  Hard_coal (GWh)  \
# 0                4.95              8.39         98.605          108.454
# 1                5.00              7.41         98.605          222.656
# 2                7.77              5.23         98.605          162.204
# 3                8.04              4.78         98.605          189.633
# 4                9.98              4.23         98.605          175.733
# ..                ...               ...            ...              ...
# 754              3.47             17.54        110.007           43.469
# 755              2.12             17.85        110.410           50.676
# 756              2.60             19.09        110.852           42.333
# 757              2.05             19.63        110.479           33.307
# 758              3.48             18.17        110.731           11.629
#
#      Hydro (GWh)  Lignite (GWh)  Natural_gas (GWh)  Other (GWh)  \
# 0         51.011        325.337            188.811       54.040
# 1         51.862        343.168            229.293       54.166
# 2         48.851        336.773            241.297       53.518
# 3         47.101        323.976            252.289       52.194
# 4         45.854        327.502            259.018       52.179
# ..           ...            ...                ...          ...
# 754       85.857        199.246            194.291       54.026
# 755       82.632        195.983            209.610       52.963
# 756       79.531        205.273            205.773       52.616
# 757       74.958        184.012            216.412       50.927
# 758       74.669        141.084            158.503       51.515
#
#      Pumped_storage_generation (GWh)  Solar_energy (GWh)  Wind_offshore (GWh)  \
# 0                             19.314               6.263                3.404
# 1                             28.892               6.312                3.350
# 2                             21.072              24.226                7.292
# 3                             28.300              14.157                7.828
# 4                             31.887               4.728                8.280
# ..                               ...                 ...                  ...
# 754                           20.934             325.285               49.360
# 755                           18.766             394.116               51.053
# 756                           19.081             256.246               40.449
# 757                           18.856             244.051                2.180
# 758                           12.365             345.645               24.192
#
#      Wind_onshore (GWh)  Net_total_export_import (GWh)  BEV_vehicles  \
# 0               235.467                         54.662             6
# 1               231.772                        -64.477             6
# 2               504.484                        -35.078             6
# 3               541.528                         22.924             6
# 4               572.819                         35.618             6
# ..                  ...                            ...           ...
# 754             179.921                       -168.705           992
# 755              42.885                       -194.496           992
# 756             129.267                       -241.786           993
# 757              32.001                       -251.655           992
# 758             171.537                        -65.418           992
#
#      Oil_price (EUR)  TTF_gas_price (€/MWh)  Nuclear_energy (GWh)
# 0              99.64                  21.10               250.979
# 1             100.04                  20.00               258.671
# 2             100.44                  20.90               271.495
# 3             103.15                  21.40               270.613
# 4             103.92                  21.30               287.555
# ..               ...                    ...                   ...
# 754            75.75                  32.63                 0.000
# 755            76.36                  31.70                 0.000
# 756            75.21                  32.20                 0.000
# 757            74.79                  32.90                 0.000
# 758            74.37                  33.25                 0.000
#
# [4593 rows x 20 columns]

# %% [markdown]
# ### Hyperparameter Tuning

# %% [markdown]
# ##### Here only using the split into train and test set

# %%
import pandas as pd
import numpy as np
from darts import TimeSeries
from darts.models import XGBModel
from darts.dataprocessing.transformers import Scaler
from sklearn.preprocessing import MaxAbsScaler, RobustScaler, StandardScaler
import plotly.graph_objs as go
from darts.metrics import mape, rmse, mse, mae
import optuna

# Convert future covariates to TimeSeries objects
future_covariates_train = TimeSeries.from_dataframe(train_df, 'Date', future_covariates_columns).astype('float32')
future_covariates_full = TimeSeries.from_dataframe(df, 'Date', future_covariates_columns, fill_missing_dates=True, freq="D").astype('float32')

# Determine required start date for future covariates
input_chunk_length = 500  # Set based on desired look-back period
required_start_date = pd.Timestamp(test_df['Date'].iloc[0]) - pd.DateOffset(days=input_chunk_length)

# Ensure future_covariates_full covers the required range
required_end_date = pd.Timestamp(test_df['Date'].iloc[0]) + pd.DateOffset(days=len(series_test)-1)

# Check if future_covariates_full has sufficient data
if future_covariates_full.start_time() > required_start_date or future_covariates_full.end_time() < required_end_date:
    print("Warning: The future_covariates_full is not long enough to cover the required input chunk length and prediction range.")
    # Extend the future_covariates_full or adjust your dataset

# Slice the future covariates to the required range, including data from the training period
future_covariates_test = future_covariates_full.slice(required_start_date, required_end_date)

# Scaling the data
scaler_series = Scaler(MaxAbsScaler())
scaler_covariates = Scaler(MaxAbsScaler())

# Fit the scaler on the training data
series_train_scaled = scaler_series.fit_transform(series_train)
future_covariates_train_scaled = scaler_covariates.fit_transform(future_covariates_train)

# Transform the test series and future covariates using the same scaler
series_test_scaled = scaler_series.transform(series_test)
future_covariates_test_scaled = scaler_covariates.transform(future_covariates_test)

# Define the Optuna objective function
def objective(trial):
    # Define hyperparameters to tune
    max_depth = trial.suggest_int('max_depth', 3, 15)
    learning_rate = trial.suggest_float('learning_rate', 0.001, 0.3, log=True)
    n_estimators = trial.suggest_int('n_estimators', 50, 500)
    input_chunk_length = trial.suggest_int('input_chunk_length', 10, 300)
    min_child_weight = trial.suggest_float('min_child_weight', 0.1, 10.0)
    subsample = trial.suggest_float('subsample', 0.5, 1.0)
    colsample_bytree = trial.suggest_float('colsample_bytree', 0.5, 1.0)
    gamma = trial.suggest_float('gamma', 0, 5)
    
    model = XGBModel(
        lags=input_chunk_length,
        output_chunk_length=1,
        lags_future_covariates=[0],
        max_depth=max_depth,
        learning_rate=learning_rate,
        n_estimators=n_estimators,
        min_child_weight=min_child_weight,
        subsample=subsample,
        colsample_bytree=colsample_bytree,
        gamma=gamma,
        random_state=42
    )

    # Train the model
    model.fit(series_train_scaled, future_covariates=future_covariates_train_scaled, verbose=False) 

    # Make predictions on the test set
    forecast_scaled = model.predict(n=len(series_test_scaled), future_covariates=future_covariates_test_scaled)

    # Inverse transform the forecast to the original scale
    forecast = scaler_series.inverse_transform(forecast_scaled)

    # Evaluate the model performance using MAPE
    error = mse(series_test, forecast)

    return error

# Create an Optuna study and optimize
study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=500, n_jobs=7)

# Print the best hyperparameters
print('/n Best hyperparameters: ', study.best_params)

# Extract the best hyperparameters from the Optuna study
best_params = study.best_params

# Use the best hyperparameters to define the XGBoost model
best_model = XGBModel(
    lags=best_params['input_chunk_length'],
    output_chunk_length=1,  # Predicting one day at a time
    lags_future_covariates=[0],  # Using the current value of future covariates for prediction
    max_depth=best_params['max_depth'],
    learning_rate=best_params['learning_rate'],
    n_estimators=best_params['n_estimators'],
    min_child_weight=best_params['min_child_weight'],  
    subsample=best_params['subsample'],               
    colsample_bytree=best_params['colsample_bytree'], 
    gamma=best_params['gamma'],                       
    random_state=42
)

# Train the model with the best hyperparameters
best_model.fit(series_train_scaled, future_covariates=future_covariates_train_scaled)

# Make predictions on the test set
forecast_scaled = best_model.predict(n=len(series_test_scaled), future_covariates=future_covariates_test_scaled)

# Inverse transform the forecast to the original scale
forecast = scaler_series.inverse_transform(forecast_scaled)

# Convert TimeSeries to DataFrame for Plotly plotting
test_df_plotly = series_test.pd_dataframe()
forecast_df_plotly = forecast.pd_dataframe()

# Plot the results using Plotly
fig = go.Figure()

# Add actual test data trace
fig.add_trace(go.Scatter(x=test_df_plotly.index, y=test_df_plotly['Day_ahead_price (€/MWh)'],
                         mode='lines', name='Actual Test Data', line=dict(color='darkblue')))

# Add forecast data trace
fig.add_trace(go.Scatter(x=forecast_df_plotly.index, y=forecast_df_plotly['Day_ahead_price (€/MWh)'],
                         mode='lines', name='XGBoost Forecast on Test Data', line=dict(color='red')))

# Update layout
fig.update_layout(
    title='XGBoost Model - Test Performance Only',
    xaxis_title='Date',
    yaxis_title='Day Ahead Price (€/MWh)',
    legend=dict(
        x=1,   # Set x position to 1 (far right)
        y=1,   # Set y position to 1 (top)
        xanchor='right',  # Anchor the legend's x position to the right
        yanchor='top',    # Anchor the legend's y position to the top
        bordercolor='black',  # Optional: Add a border around the legend
        borderwidth=1        # Optional: Set the border width
    ),
    template='plotly_white'
)

# Show the plot
fig.show()


# Evaluate the model using Darts' metrics
print(f'Mean Absolute Error on Test Set: {mae(series_test, forecast)}')
print(f'Mean Absolute Percentage Error on Test Set: {mape(series_test, forecast)}')
print(f'Mean Squared Error on Test Set: {mse(series_test, forecast)}')
print(f'Root Mean Squared Error on Test Set: {rmse(series_test, forecast)}')
# Out:
# [I 2024-09-11 16:32:14,554] A new study created in memory with name: no-name-7bf12ae9-e63d-4069-a80e-a7886a97088d
# [I 2024-09-11 16:32:17,853] Trial 2 finished with value: 13425.576171875 and parameters: {'max_depth': 10, 'learning_rate': 0.11412292578151693, 'n_estimators': 94, 'input_chunk_length': 174, 'min_child_weight': 6.684650061736955, 'subsample': 0.5995434823216879, 'colsample_bytree': 0.9530333606533643, 'gamma': 3.2094585686884747}. Best is trial 2 with value: 13425.576171875.
# [I 2024-09-11 16:32:18,074] Trial 1 finished with value: 5174.0810546875 and parameters: {'max_depth': 14, 'learning_rate': 0.04592239719235583, 'n_estimators': 53, 'input_chunk_length': 267, 'min_child_weight': 4.084409377339601, 'subsample': 0.5285195582991558, 'colsample_bytree': 0.6142118508152623, 'gamma': 0.19988472135412827}. Best is trial 1 with value: 5174.0810546875.
# [I 2024-09-11 16:32:18,109] Trial 0 finished with value: 12420.2451171875 and parameters: {'max_depth': 7, 'learning_rate': 0.015079457004004279, 'n_estimators': 65, 'input_chunk_length': 23, 'min_child_weight': 4.53055498128994, 'subsample': 0.6251210076099751, 'colsample_bytree': 0.5065873010244861, 'gamma': 0.7230285139020604}. Best is trial 1 with value: 5174.0810546875.
# [I 2024-09-11 16:32:18,841] Trial 5 finished with value: 11274.4765625 and parameters: {'max_depth': 4, 'learning_rate': 0.014246744142387666, 'n_estimators': 168, 'input_chunk_length': 232, 'min_child_weight': 3.1117005457551756, 'subsample': 0.8795710017145092, 'colsample_bytree': 0.9628506853846326, 'gamma': 2.377785573380178}. Best is trial 1 with value: 5174.0810546875.
# [I 2024-09-11 16:32:18,854] Trial 6 finished with value: 14644.7705078125 and parameters: {'max_depth': 12, 'learning_rate': 0.006081421672349205, 'n_estimators': 145, 'input_chunk_length': 237, 'min_child_weight': 8.09337683640431, 'subsample': 0.9343750216681623, 'colsample_bytree': 0.9052921000939431, 'gamma': 3.1786077769371888}. Best is trial 1 with value: 5174.0810546875.
# [I 2024-09-11 16:32:19,066] Trial 4 finished with value: 18881.6015625 and parameters: {'max_depth': 9, 'learning_rate': 0.0017667180613330285, 'n_estimators': 158, 'input_chunk_length': 164, 'min_child_weight': 7.386763397484565, 'subsample': 0.8108405415752444, 'colsample_bytree': 0.848526499945442, 'gamma': 4.272923025936501}. Best is trial 1 with value: 5174.0810546875.
# [I 2024-09-11 16:32:20,896] Trial 3 finished with value: 9529.7099609375 and parameters: {'max_depth': 9, 'learning_rate': 0.2694203544250174, 'n_estimators': 491, 'input_chunk_length': 143, 'min_child_weight': 0.3800194277643043, 'subsample': 0.5783811973144507, 'colsample_bytree': 0.700381389984817, 'gamma': 1.2940401378347217}. Best is trial 1 with value: 5174.0810546875.
# [I 2024-09-11 16:32:23,145] Trial 12 finished with value: 13697.5966796875 and parameters: {'max_depth': 15, 'learning_rate': 0.12807886500687876, 'n_estimators': 266, 'input_chunk_length': 140, 'min_child_weight': 6.705831639786099, 'subsample': 0.7204652838722951, 'colsample_bytree': 0.6274469473195419, 'gamma': 3.002283032667759}. Best is trial 1 with value: 5174.0810546875.
# [I 2024-09-11 16:32:23,207] Trial 8 finished with value: 17225.923828125 and parameters: {'max_depth': 5, 'learning_rate': 0.002269965645282459, 'n_estimators': 222, 'input_chunk_length': 129, 'min_child_weight': 3.187919191274497, 'subsample': 0.6252590954337793, 'colsample_bytree': 0.7511899415931834, 'gamma': 1.3973919822580076}. Best is trial 1 with value: 5174.0810546875.
# [I 2024-09-11 16:32:23,438] Trial 10 finished with value: 13093.3388671875 and parameters: {'max_depth': 8, 'learning_rate': 0.014361620925933946, 'n_estimators': 265, 'input_chunk_length': 151, 'min_child_weight': 2.8900369126945145, 'subsample': 0.8649023561095359, 'colsample_bytree': 0.5947459928982914, 'gamma': 3.2856895067249203}. Best is trial 1 with value: 5174.0810546875.
# [I 2024-09-11 16:32:24,069] Trial 7 finished with value: 6935.0078125 and parameters: {'max_depth': 3, 'learning_rate': 0.01623360292160414, 'n_estimators': 396, 'input_chunk_length': 103, 'min_child_weight': 6.658397730834735, 'subsample': 0.9877180727065723, 'colsample_bytree': 0.869783686393521, 'gamma': 0.6267046668466791}. Best is trial 1 with value: 5174.0810546875.
# [I 2024-09-11 16:32:25,828] Trial 11 finished with value: 18891.904296875 and parameters: {'max_depth': 8, 'learning_rate': 0.0011714339332024237, 'n_estimators': 336, 'input_chunk_length': 232, 'min_child_weight': 4.747632759042239, 'subsample': 0.8110289997990082, 'colsample_bytree': 0.549655757241712, 'gamma': 2.420236336238853}. Best is trial 1 with value: 5174.0810546875.
# [I 2024-09-11 16:32:26,769] Trial 9 finished with value: 15837.453125 and parameters: {'max_depth': 10, 'learning_rate': 0.0015225729121233534, 'n_estimators': 491, 'input_chunk_length': 46, 'min_child_weight': 1.0918832379701815, 'subsample': 0.6287813011191661, 'colsample_bytree': 0.9979142243408903, 'gamma': 3.197535049014297}. Best is trial 1 with value: 5174.0810546875.
# [I 2024-09-11 16:32:27,499] Trial 14 finished with value: 8556.6611328125 and parameters: {'max_depth': 4, 'learning_rate': 0.1076685300292722, 'n_estimators': 221, 'input_chunk_length': 52, 'min_child_weight': 9.509629538479677, 'subsample': 0.863687696424659, 'colsample_bytree': 0.8543081424936491, 'gamma': 2.1247504074552817}. Best is trial 1 with value: 5174.0810546875.
# [I 2024-09-11 16:32:28,336] Trial 13 finished with value: 8371.2138671875 and parameters: {'max_depth': 3, 'learning_rate': 0.02157264281715192, 'n_estimators': 491, 'input_chunk_length': 179, 'min_child_weight': 5.207458746402654, 'subsample': 0.8382895631752549, 'colsample_bytree': 0.690808749154552, 'gamma': 1.483043248016556}. Best is trial 1 with value: 5174.0810546875.
# [I 2024-09-11 16:32:33,153] Trial 17 finished with value: 3727.910400390625 and parameters: {'max_depth': 14, 'learning_rate': 0.04590891328935251, 'n_estimators': 374, 'input_chunk_length': 50, 'min_child_weight': 9.633439375724157, 'subsample': 0.5014083536715059, 'colsample_bytree': 0.7953261738817956, 'gamma': 0.028811222348787413}. Best is trial 17 with value: 3727.910400390625.
# [I 2024-09-11 16:32:33,472] Trial 16 finished with value: 4843.0185546875 and parameters: {'max_depth': 15, 'learning_rate': 0.04236370272876207, 'n_estimators': 397, 'input_chunk_length': 299, 'min_child_weight': 9.994433905298997, 'subsample': 0.7203179951916342, 'colsample_bytree': 0.5087365203276759, 'gamma': 0.03995049928736574}. Best is trial 17 with value: 3727.910400390625.
# [I 2024-09-11 16:32:34,791] Trial 15 finished with value: 17691.158203125 and parameters: {'max_depth': 8, 'learning_rate': 0.0011348548621048212, 'n_estimators': 427, 'input_chunk_length': 236, 'min_child_weight': 2.585799289881494, 'subsample': 0.9496025428923249, 'colsample_bytree': 0.9927208860405223, 'gamma': 2.216447421332113}. Best is trial 17 with value: 3727.910400390625.
# [I 2024-09-11 16:32:35,639] Trial 18 finished with value: 4126.41845703125 and parameters: {'max_depth': 15, 'learning_rate': 0.043668624882343236, 'n_estimators': 420, 'input_chunk_length': 297, 'min_child_weight': 9.724613073862113, 'subsample': 0.5050767007764706, 'colsample_bytree': 0.7932830891718303, 'gamma': 0.11849226096779075}. Best is trial 17 with value: 3727.910400390625.
# [I 2024-09-11 16:32:37,817] Trial 20 finished with value: 3836.42626953125 and parameters: {'max_depth': 15, 'learning_rate': 0.03706702355747066, 'n_estimators': 379, 'input_chunk_length': 297, 'min_child_weight': 5.375625883484368, 'subsample': 0.5048397926646134, 'colsample_bytree': 0.7509100108651103, 'gamma': 0.04964902965494544}. Best is trial 17 with value: 3727.910400390625.
# [I 2024-09-11 16:32:37,869] Trial 19 finished with value: 4824.86572265625 and parameters: {'max_depth': 15, 'learning_rate': 0.04414790216123177, 'n_estimators': 379, 'input_chunk_length': 281, 'min_child_weight': 9.665958301249287, 'subsample': 0.5009825202501608, 'colsample_bytree': 0.8008835913144112, 'gamma': 0.01740484592795455}. Best is trial 17 with value: 3727.910400390625.
# [I 2024-09-11 16:32:39,690] Trial 21 finished with value: 3928.84033203125 and parameters: {'max_depth': 15, 'learning_rate': 0.04466172318571453, 'n_estimators': 383, 'input_chunk_length': 288, 'min_child_weight': 5.762612453406431, 'subsample': 0.514658516077112, 'colsample_bytree': 0.7811817184270458, 'gamma': 0.0080905081698808}. Best is trial 17 with value: 3727.910400390625.
# [I 2024-09-11 16:32:40,289] Trial 25 finished with value: 16675.693359375 and parameters: {'max_depth': 13, 'learning_rate': 0.04424674757696738, 'n_estimators': 343, 'input_chunk_length': 85, 'min_child_weight': 8.918008721460197, 'subsample': 0.5041364323469534, 'colsample_bytree': 0.7762529468193081, 'gamma': 4.7209397387812055}. Best is trial 17 with value: 3727.910400390625.
# [I 2024-09-11 16:32:40,327] Trial 23 finished with value: 4552.77099609375 and parameters: {'max_depth': 13, 'learning_rate': 0.04290912371038873, 'n_estimators': 401, 'input_chunk_length': 90, 'min_child_weight': 9.964941408538444, 'subsample': 0.750165993798006, 'colsample_bytree': 0.777632352912844, 'gamma': 0.12891595811847445}. Best is trial 17 with value: 3727.910400390625.
# [I 2024-09-11 16:32:40,555] Trial 22 finished with value: 3837.102783203125 and parameters: {'max_depth': 15, 'learning_rate': 0.043811624891203924, 'n_estimators': 386, 'input_chunk_length': 285, 'min_child_weight': 8.838803095239836, 'subsample': 0.5010270222914375, 'colsample_bytree': 0.777806130584819, 'gamma': 0.07418348730833128}. Best is trial 17 with value: 3727.910400390625.
# [I 2024-09-11 16:32:41,074] Trial 24 finished with value: 4157.50537109375 and parameters: {'max_depth': 13, 'learning_rate': 0.044881486766714294, 'n_estimators': 354, 'input_chunk_length': 95, 'min_child_weight': 9.99217876351984, 'subsample': 0.7128258923671215, 'colsample_bytree': 0.7844274864731332, 'gamma': 0.11104717530029573}. Best is trial 17 with value: 3727.910400390625.
# [I 2024-09-11 16:32:43,110] Trial 27 finished with value: 6784.0078125 and parameters: {'max_depth': 13, 'learning_rate': 0.028762446125652145, 'n_estimators': 328, 'input_chunk_length': 87, 'min_child_weight': 8.432016622903472, 'subsample': 0.5389336251905816, 'colsample_bytree': 0.7775394314224142, 'gamma': 0.70233858122778}. Best is trial 17 with value: 3727.910400390625.
# [I 2024-09-11 16:32:45,617] Trial 28 finished with value: 6675.4794921875 and parameters: {'max_depth': 13, 'learning_rate': 0.07463024410542489, 'n_estimators': 336, 'input_chunk_length': 200, 'min_child_weight': 8.572598569575977, 'subsample': 0.5584376193651108, 'colsample_bytree': 0.7130695714008491, 'gamma': 0.7379459101737629}. Best is trial 17 with value: 3727.910400390625.
# [I 2024-09-11 16:32:45,752] Trial 26 finished with value: 7795.03759765625 and parameters: {'max_depth': 13, 'learning_rate': 0.006156621068532992, 'n_estimators': 340, 'input_chunk_length': 83, 'min_child_weight': 8.316381544468008, 'subsample': 0.6791830735430195, 'colsample_bytree': 0.7921994067462537, 'gamma': 0.7560000824486021}. Best is trial 17 with value: 3727.910400390625.
# [I 2024-09-11 16:32:46,630] Trial 30 finished with value: 6265.8193359375 and parameters: {'max_depth': 12, 'learning_rate': 0.07590606250901857, 'n_estimators': 323, 'input_chunk_length': 195, 'min_child_weight': 6.001363017797361, 'subsample': 0.558438227103562, 'colsample_bytree': 0.6966202089876417, 'gamma': 0.7449003543909487}. Best is trial 17 with value: 3727.910400390625.
# [I 2024-09-11 16:32:46,803] Trial 29 finished with value: 6463.6298828125 and parameters: {'max_depth': 12, 'learning_rate': 0.07885783087421944, 'n_estimators': 329, 'input_chunk_length': 207, 'min_child_weight': 5.629173846013815, 'subsample': 0.5637140197702228, 'colsample_bytree': 0.697955267740412, 'gamma': 0.7962623455885804}. Best is trial 17 with value: 3727.910400390625.
# [I 2024-09-11 16:32:49,535] Trial 31 finished with value: 7806.99267578125 and parameters: {'max_depth': 12, 'learning_rate': 0.007475456143245988, 'n_estimators': 329, 'input_chunk_length': 205, 'min_child_weight': 7.794970731699344, 'subsample': 0.5639007364607773, 'colsample_bytree': 0.6972834900548378, 'gamma': 0.8093173219407729}. Best is trial 17 with value: 3727.910400390625.
# [I 2024-09-11 16:32:50,125] Trial 32 finished with value: 7837.18798828125 and parameters: {'max_depth': 12, 'learning_rate': 0.0069170085544291845, 'n_estimators': 314, 'input_chunk_length': 204, 'min_child_weight': 8.55458360569777, 'subsample': 0.5598812214650464, 'colsample_bytree': 0.6974132838292315, 'gamma': 0.8294413862614591}. Best is trial 17 with value: 3727.910400390625.
# [I 2024-09-11 16:32:51,507] Trial 33 finished with value: 7643.01513671875 and parameters: {'max_depth': 11, 'learning_rate': 0.07930264828630174, 'n_estimators': 453, 'input_chunk_length': 201, 'min_child_weight': 7.741252871834994, 'subsample': 0.6641772529479146, 'colsample_bytree': 0.7064457964455311, 'gamma': 1.0014356845096568}. Best is trial 17 with value: 3727.910400390625.
# [I 2024-09-11 16:32:55,259] Trial 36 finished with value: 8773.2802734375 and parameters: {'max_depth': 11, 'learning_rate': 0.24920756215706008, 'n_estimators': 449, 'input_chunk_length': 261, 'min_child_weight': 7.783872566335841, 'subsample': 0.661268846349821, 'colsample_bytree': 0.6651187821230817, 'gamma': 1.1591921614630112}. Best is trial 17 with value: 3727.910400390625.
# [I 2024-09-11 16:32:56,189] Trial 35 finished with value: 8648.65234375 and parameters: {'max_depth': 11, 'learning_rate': 0.009546625986947239, 'n_estimators': 457, 'input_chunk_length': 260, 'min_child_weight': 7.347318700263724, 'subsample': 0.5828436464989657, 'colsample_bytree': 0.7319544863752497, 'gamma': 1.0894040807573573}. Best is trial 17 with value: 3727.910400390625.
# [I 2024-09-11 16:32:56,755] Trial 34 finished with value: 8717.6748046875 and parameters: {'max_depth': 11, 'learning_rate': 0.007443965255963344, 'n_estimators': 456, 'input_chunk_length': 266, 'min_child_weight': 7.677585192935558, 'subsample': 0.6609349686550031, 'colsample_bytree': 0.6535883508259971, 'gamma': 1.1327274438888713}. Best is trial 17 with value: 3727.910400390625.
# [I 2024-09-11 16:32:56,990] Trial 37 finished with value: 5732.59814453125 and parameters: {'max_depth': 14, 'learning_rate': 0.02561595779693423, 'n_estimators': 463, 'input_chunk_length': 272, 'min_child_weight': 4.047659406670409, 'subsample': 0.5941267582283453, 'colsample_bytree': 0.8303698932151719, 'gamma': 0.4339145309383808}. Best is trial 17 with value: 3727.910400390625.
# [I 2024-09-11 16:32:58,613] Trial 38 finished with value: 6135.9736328125 and parameters: {'max_depth': 14, 'learning_rate': 0.025025508914986217, 'n_estimators': 441, 'input_chunk_length': 263, 'min_child_weight': 4.341306066667956, 'subsample': 0.5298373454664709, 'colsample_bytree': 0.8276672870818819, 'gamma': 0.4706419976904931}. Best is trial 17 with value: 3727.910400390625.
# [I 2024-09-11 16:32:58,916] Trial 39 finished with value: 5339.5302734375 and parameters: {'max_depth': 14, 'learning_rate': 0.02608403198840364, 'n_estimators': 429, 'input_chunk_length': 262, 'min_child_weight': 3.9558491662840964, 'subsample': 0.6062849875268871, 'colsample_bytree': 0.7387000534957422, 'gamma': 0.40649128882958363}. Best is trial 17 with value: 3727.910400390625.
# [I 2024-09-11 16:32:59,894] Trial 40 finished with value: 6119.05322265625 and parameters: {'max_depth': 14, 'learning_rate': 0.028660005224307797, 'n_estimators': 453, 'input_chunk_length': 265, 'min_child_weight': 4.149244957335007, 'subsample': 0.6003219447071971, 'colsample_bytree': 0.8268381103229817, 'gamma': 0.4570383088571257}. Best is trial 17 with value: 3727.910400390625.
# [I 2024-09-11 16:33:01,581] Trial 41 finished with value: 6626.94873046875 and parameters: {'max_depth': 14, 'learning_rate': 0.026431275241089035, 'n_estimators': 371, 'input_chunk_length': 261, 'min_child_weight': 3.6105765724278855, 'subsample': 0.5981437581192498, 'colsample_bytree': 0.8722859318546196, 'gamma': 0.42266158679713967}. Best is trial 17 with value: 3727.910400390625.
# [I 2024-09-11 16:33:01,650] Trial 43 finished with value: 6481.50439453125 and parameters: {'max_depth': 14, 'learning_rate': 0.027347203073329874, 'n_estimators': 291, 'input_chunk_length': 19, 'min_child_weight': 6.250277303545158, 'subsample': 0.5334849379696732, 'colsample_bytree': 0.8295015096166906, 'gamma': 0.3970290965888496}. Best is trial 17 with value: 3727.910400390625.
# [I 2024-09-11 16:33:01,972] Trial 44 finished with value: 6358.20703125 and parameters: {'max_depth': 14, 'learning_rate': 0.03058703435683608, 'n_estimators': 294, 'input_chunk_length': 16, 'min_child_weight': 6.043091746985864, 'subsample': 0.5199003286770504, 'colsample_bytree': 0.8965634680744047, 'gamma': 0.3693173364880861}. Best is trial 17 with value: 3727.910400390625.
# [I 2024-09-11 16:33:02,670] Trial 42 finished with value: 6621.98828125 and parameters: {'max_depth': 14, 'learning_rate': 0.026681307771716765, 'n_estimators': 370, 'input_chunk_length': 280, 'min_child_weight': 4.085089634047545, 'subsample': 0.5292627284828384, 'colsample_bytree': 0.8419012495392072, 'gamma': 0.47988743316019766}. Best is trial 17 with value: 3727.910400390625.
# [I 2024-09-11 16:33:03,871] Trial 46 finished with value: 8645.7685546875 and parameters: {'max_depth': 14, 'learning_rate': 0.18412835419708395, 'n_estimators': 294, 'input_chunk_length': 27, 'min_child_weight': 9.165760409178228, 'subsample': 0.5294575762857447, 'colsample_bytree': 0.8825149658646219, 'gamma': 1.7369040737930486}. Best is trial 17 with value: 3727.910400390625.
# [I 2024-09-11 16:33:04,393] Trial 45 finished with value: 9013.1044921875 and parameters: {'max_depth': 14, 'learning_rate': 0.20538376658165455, 'n_estimators': 373, 'input_chunk_length': 12, 'min_child_weight': 9.13435710135755, 'subsample': 0.5300039271022263, 'colsample_bytree': 0.9150405459771569, 'gamma': 1.74516938594686}. Best is trial 17 with value: 3727.910400390625.
# [I 2024-09-11 16:33:07,761] Trial 47 finished with value: 11484.384765625 and parameters: {'max_depth': 15, 'learning_rate': 0.06541303489991367, 'n_estimators': 384, 'input_chunk_length': 299, 'min_child_weight': 9.178971160225593, 'subsample': 0.5212093519334244, 'colsample_bytree': 0.8774541875397887, 'gamma': 1.6746147605035415}. Best is trial 17 with value: 3727.910400390625.
# [I 2024-09-11 16:33:10,582] Trial 48 finished with value: 10319.84375 and parameters: {'max_depth': 15, 'learning_rate': 0.12350893906418095, 'n_estimators': 410, 'input_chunk_length': 298, 'min_child_weight': 9.113273940410611, 'subsample': 0.5188920172932243, 'colsample_bytree': 0.901757645265353, 'gamma': 1.7437970165039598}. Best is trial 17 with value: 3727.910400390625.
# [I 2024-09-11 16:33:10,860] Trial 49 finished with value: 4612.13330078125 and parameters: {'max_depth': 15, 'learning_rate': 0.056221402193974944, 'n_estimators': 374, 'input_chunk_length': 294, 'min_child_weight': 9.011356479900279, 'subsample': 0.5010197782644051, 'colsample_bytree': 0.8939167680319366, 'gamma': 0.21889126716128168}. Best is trial 17 with value: 3727.910400390625.
# [I 2024-09-11 16:33:11,109] Trial 50 finished with value: 5251.91943359375 and parameters: {'max_depth': 15, 'learning_rate': 0.15602233603803267, 'n_estimators': 412, 'input_chunk_length': 298, 'min_child_weight': 6.895578193374532, 'subsample': 0.5004850895825361, 'colsample_bytree': 0.7543592252411433, 'gamma': 0.22193780080670666}. Best is trial 17 with value: 3727.910400390625.
# [I 2024-09-11 16:33:12,210] Trial 51 finished with value: 5986.88623046875 and parameters: {'max_depth': 15, 'learning_rate': 0.058690867363083016, 'n_estimators': 412, 'input_chunk_length': 300, 'min_child_weight': 9.202595221726165, 'subsample': 0.5003305930501136, 'colsample_bytree': 0.7527290682057387, 'gamma': 0.24183996223509752}. Best is trial 17 with value: 3727.910400390625.
# [I 2024-09-11 16:33:13,054] Trial 52 finished with value: 4082.367919921875 and parameters: {'max_depth': 15, 'learning_rate': 0.057429659867695035, 'n_estimators': 411, 'input_chunk_length': 298, 'min_child_weight': 9.164001745987687, 'subsample': 0.5050562843290152, 'colsample_bytree': 0.7538646999563069, 'gamma': 0.2532414878601612}. Best is trial 17 with value: 3727.910400390625.
# [I 2024-09-11 16:33:15,032] Trial 53 finished with value: 4626.96923828125 and parameters: {'max_depth': 15, 'learning_rate': 0.018310464995119447, 'n_estimators': 413, 'input_chunk_length': 298, 'min_child_weight': 7.13209643195826, 'subsample': 0.501645003507202, 'colsample_bytree': 0.7528870661854399, 'gamma': 0.2284929771986362}. Best is trial 17 with value: 3727.910400390625.
# [I 2024-09-11 16:33:15,777] Trial 54 finished with value: 4793.3193359375 and parameters: {'max_depth': 15, 'learning_rate': 0.05489149623657883, 'n_estimators': 411, 'input_chunk_length': 247, 'min_child_weight': 5.034268129010984, 'subsample': 0.5093610837835866, 'colsample_bytree': 0.758440034287684, 'gamma': 0.2500928946633103}. Best is trial 17 with value: 3727.910400390625.
# [I 2024-09-11 16:33:18,227] Trial 57 finished with value: 14118.416015625 and parameters: {'max_depth': 15, 'learning_rate': 0.03668518878204848, 'n_estimators': 352, 'input_chunk_length': 61, 'min_child_weight': 2.0939099180227387, 'subsample': 0.7762014833238744, 'colsample_bytree': 0.8081309558538466, 'gamma': 3.6273885742775023}. Best is trial 17 with value: 3727.910400390625.
# [I 2024-09-11 16:33:19,409] Trial 55 finished with value: 4795.65625 and parameters: {'max_depth': 15, 'learning_rate': 0.057407144475288746, 'n_estimators': 412, 'input_chunk_length': 245, 'min_child_weight': 5.1005457555477545, 'subsample': 0.5010878220785858, 'colsample_bytree': 0.7540630540763523, 'gamma': 0.26699690269796195}. Best is trial 17 with value: 3727.910400390625.
# [I 2024-09-11 16:33:22,496] Trial 56 finished with value: 4199.9873046875 and parameters: {'max_depth': 15, 'learning_rate': 0.019986267299221646, 'n_estimators': 476, 'input_chunk_length': 245, 'min_child_weight': 5.126923064483534, 'subsample': 0.5476159160038312, 'colsample_bytree': 0.7557314293394113, 'gamma': 0.19655926787592568}. Best is trial 17 with value: 3727.910400390625.
# [I 2024-09-11 16:33:26,749] Trial 61 finished with value: 4673.34375 and parameters: {'max_depth': 15, 'learning_rate': 0.036536730770215395, 'n_estimators': 85, 'input_chunk_length': 280, 'min_child_weight': 9.532238485627973, 'subsample': 0.5448134060692951, 'colsample_bytree': 0.7342849189320839, 'gamma': 0.0025497244891763554}. Best is trial 17 with value: 3727.910400390625.
# [I 2024-09-11 16:33:27,251] Trial 58 finished with value: 4316.19580078125 and parameters: {'max_depth': 6, 'learning_rate': 0.018162211818904345, 'n_estimators': 354, 'input_chunk_length': 71, 'min_child_weight': 5.012957286980169, 'subsample': 0.7969424111907508, 'colsample_bytree': 0.8077451658306469, 'gamma': 0.020993676453903296}. Best is trial 17 with value: 3727.910400390625.
# [I 2024-09-11 16:33:28,270] Trial 62 finished with value: 5820.009765625 and parameters: {'max_depth': 7, 'learning_rate': 0.09436727581187179, 'n_estimators': 472, 'input_chunk_length': 284, 'min_child_weight': 9.575114781952589, 'subsample': 0.5468392794461471, 'colsample_bytree': 0.726961280970122, 'gamma': 0.06476654552542066}. Best is trial 17 with value: 3727.910400390625.
# [I 2024-09-11 16:33:28,829] Trial 59 finished with value: 3426.4765625 and parameters: {'max_depth': 15, 'learning_rate': 0.018705375317605705, 'n_estimators': 477, 'input_chunk_length': 248, 'min_child_weight': 1.8068710983396343, 'subsample': 0.5782602859280923, 'colsample_bytree': 0.8144522615273794, 'gamma': 0.03198804699101412}. Best is trial 59 with value: 3426.4765625.
# [I 2024-09-11 16:33:29,013] Trial 64 finished with value: 4997.7568359375 and parameters: {'max_depth': 6, 'learning_rate': 0.09750065829939251, 'n_estimators': 241, 'input_chunk_length': 281, 'min_child_weight': 9.530878991976582, 'subsample': 0.5736433546539823, 'colsample_bytree': 0.8108046212721979, 'gamma': 0.06289467581209146}. Best is trial 59 with value: 3426.4765625.
# [I 2024-09-11 16:33:29,130] Trial 60 finished with value: 3739.440673828125 and parameters: {'max_depth': 6, 'learning_rate': 0.03628422042316495, 'n_estimators': 478, 'input_chunk_length': 245, 'min_child_weight': 1.8714800715672113, 'subsample': 0.5464915761381576, 'colsample_bytree': 0.8061324014907075, 'gamma': 0.011368152641145372}. Best is trial 59 with value: 3426.4765625.
# [I 2024-09-11 16:33:29,299] Trial 63 finished with value: 3031.569580078125 and parameters: {'max_depth': 13, 'learning_rate': 0.09954432144255271, 'n_estimators': 475, 'input_chunk_length': 283, 'min_child_weight': 9.628215233728508, 'subsample': 0.550064574916946, 'colsample_bytree': 0.7236657196983185, 'gamma': 0.03789915013928216}. Best is trial 63 with value: 3031.569580078125.
# [I 2024-09-11 16:33:32,996] Trial 65 finished with value: 5861.22216796875 and parameters: {'max_depth': 13, 'learning_rate': 0.10800101888301437, 'n_estimators': 433, 'input_chunk_length': 118, 'min_child_weight': 9.48282026697088, 'subsample': 0.5789935854329255, 'colsample_bytree': 0.8051964432706955, 'gamma': 0.5962212657085829}. Best is trial 63 with value: 3031.569580078125.
# [I 2024-09-11 16:33:33,701] Trial 66 finished with value: 5770.0380859375 and parameters: {'max_depth': 13, 'learning_rate': 0.09675794448323577, 'n_estimators': 435, 'input_chunk_length': 120, 'min_child_weight': 8.121693346409355, 'subsample': 0.6274190666419409, 'colsample_bytree': 0.7967112420660458, 'gamma': 0.5979993147466518}. Best is trial 63 with value: 3031.569580078125.
# [I 2024-09-11 16:33:35,292] Trial 67 finished with value: 6993.818359375 and parameters: {'max_depth': 13, 'learning_rate': 0.03510553801519814, 'n_estimators': 390, 'input_chunk_length': 107, 'min_child_weight': 9.971119862405015, 'subsample': 0.5736399706028522, 'colsample_bytree': 0.7864042839761833, 'gamma': 0.6332246372667205}. Best is trial 63 with value: 3031.569580078125.
# [I 2024-09-11 16:33:37,047] Trial 70 finished with value: 6109.3095703125 and parameters: {'max_depth': 9, 'learning_rate': 0.036462487048288895, 'n_estimators': 430, 'input_chunk_length': 226, 'min_child_weight': 1.1548492957994076, 'subsample': 0.6213766352613914, 'colsample_bytree': 0.7733770117912464, 'gamma': 0.5941123018422101}. Best is trial 63 with value: 3031.569580078125.
# [I 2024-09-11 16:33:37,735] Trial 68 finished with value: 6874.52490234375 and parameters: {'max_depth': 13, 'learning_rate': 0.011996238630392151, 'n_estimators': 432, 'input_chunk_length': 122, 'min_child_weight': 0.5877529537269792, 'subsample': 0.5748971789873806, 'colsample_bytree': 0.7941251823358941, 'gamma': 0.6070377783158751}. Best is trial 63 with value: 3031.569580078125.
# [I 2024-09-11 16:33:38,503] Trial 69 finished with value: 7220.64404296875 and parameters: {'max_depth': 13, 'learning_rate': 0.011926609205661097, 'n_estimators': 496, 'input_chunk_length': 121, 'min_child_weight': 0.5145523415526343, 'subsample': 0.5795658552637736, 'colsample_bytree': 0.7737270198438008, 'gamma': 0.693782320804625}. Best is trial 63 with value: 3031.569580078125.
# [I 2024-09-11 16:33:39,636] Trial 71 finished with value: 6450.60888671875 and parameters: {'max_depth': 9, 'learning_rate': 0.010663883457766258, 'n_estimators': 494, 'input_chunk_length': 221, 'min_child_weight': 0.42793638430162284, 'subsample': 0.618907232670803, 'colsample_bytree': 0.7827072684664375, 'gamma': 0.5791087229260758}. Best is trial 63 with value: 3031.569580078125.
# [I 2024-09-11 16:33:41,822] Trial 72 finished with value: 13012.8408203125 and parameters: {'max_depth': 9, 'learning_rate': 0.010654550164838123, 'n_estimators': 494, 'input_chunk_length': 227, 'min_child_weight': 1.1221096839603206, 'subsample': 0.6208722805203605, 'colsample_bytree': 0.8546150459971367, 'gamma': 2.739935993331658}. Best is trial 63 with value: 3031.569580078125.
# [I 2024-09-11 16:33:43,562] Trial 73 finished with value: 7484.65234375 and parameters: {'max_depth': 9, 'learning_rate': 0.012290151141026781, 'n_estimators': 499, 'input_chunk_length': 229, 'min_child_weight': 0.5808348391098539, 'subsample': 0.5480436750356255, 'colsample_bytree': 0.8568659857768832, 'gamma': 0.9232351427332375}. Best is trial 63 with value: 3031.569580078125.
# [I 2024-09-11 16:33:44,499] Trial 74 finished with value: 14305.48046875 and parameters: {'max_depth': 9, 'learning_rate': 0.01236675637394984, 'n_estimators': 499, 'input_chunk_length': 223, 'min_child_weight': 1.4108423068463471, 'subsample': 0.6129836490862679, 'colsample_bytree': 0.8541859701126198, 'gamma': 3.6094610202865596}. Best is trial 63 with value: 3031.569580078125.
# [I 2024-09-11 16:33:48,064] Trial 77 finished with value: 7727.62841796875 and parameters: {'max_depth': 5, 'learning_rate': 0.05085512183640365, 'n_estimators': 483, 'input_chunk_length': 289, 'min_child_weight': 1.7903364883330102, 'subsample': 0.5455402045551796, 'colsample_bytree': 0.6736769346200114, 'gamma': 0.9002965527107614}. Best is trial 63 with value: 3031.569580078125.
# [I 2024-09-11 16:33:49,753] Trial 78 finished with value: 4892.87548828125 and parameters: {'max_depth': 14, 'learning_rate': 0.04679271249369171, 'n_estimators': 473, 'input_chunk_length': 273, 'min_child_weight': 1.8071135346954987, 'subsample': 0.5468980543978015, 'colsample_bytree': 0.8530092783434059, 'gamma': 0.2809012705629227}. Best is trial 63 with value: 3031.569580078125.
# [I 2024-09-11 16:33:50,945] Trial 76 finished with value: 8531.669921875 and parameters: {'max_depth': 4, 'learning_rate': 0.004169324086298008, 'n_estimators': 483, 'input_chunk_length': 214, 'min_child_weight': 1.6640527321265473, 'subsample': 0.5505799969208695, 'colsample_bytree': 0.6705135908021309, 'gamma': 0.9022246968725114}. Best is trial 63 with value: 3031.569580078125.
# [I 2024-09-11 16:33:51,318] Trial 79 finished with value: 5573.2470703125 and parameters: {'max_depth': 4, 'learning_rate': 0.06796070059802094, 'n_estimators': 473, 'input_chunk_length': 287, 'min_child_weight': 1.967019167883566, 'subsample': 0.5502786355001348, 'colsample_bytree': 0.7168505853612838, 'gamma': 0.3178504219895554}. Best is trial 63 with value: 3031.569580078125.
# [I 2024-09-11 16:33:52,165] Trial 75 finished with value: 7773.99853515625 and parameters: {'max_depth': 4, 'learning_rate': 0.003903269483382008, 'n_estimators': 495, 'input_chunk_length': 218, 'min_child_weight': 0.22107554710871136, 'subsample': 0.9251635472177002, 'colsample_bytree': 0.8559588774418883, 'gamma': 0.9231504887148578}. Best is trial 63 with value: 3031.569580078125.
# [I 2024-09-11 16:33:58,687] Trial 85 finished with value: 4181.2490234375 and parameters: {'max_depth': 14, 'learning_rate': 0.02215926329231279, 'n_estimators': 134, 'input_chunk_length': 176, 'min_child_weight': 2.4346208239278426, 'subsample': 0.5225503484052088, 'colsample_bytree': 0.8167898044428126, 'gamma': 0.07774741318897996}. Best is trial 63 with value: 3031.569580078125.
# [I 2024-09-11 16:33:59,571] Trial 84 finished with value: 4037.224853515625 and parameters: {'max_depth': 10, 'learning_rate': 0.06425812015184826, 'n_estimators': 443, 'input_chunk_length': 189, 'min_child_weight': 8.645219409554102, 'subsample': 0.515704413922357, 'colsample_bytree': 0.7162166338801913, 'gamma': 0.13260561339313426}. Best is trial 63 with value: 3031.569580078125.
# [I 2024-09-11 16:34:00,395] Trial 83 finished with value: 11183.5625 and parameters: {'max_depth': 10, 'learning_rate': 0.003912793941480892, 'n_estimators': 181, 'input_chunk_length': 158, 'min_child_weight': 8.6631297319883, 'subsample': 0.9068583165293562, 'colsample_bytree': 0.7179036586359435, 'gamma': 0.12639133533256988}. Best is trial 63 with value: 3031.569580078125.
# [I 2024-09-11 16:34:00,776] Trial 80 finished with value: 9450.822265625 and parameters: {'max_depth': 4, 'learning_rate': 0.0027524827367331303, 'n_estimators': 479, 'input_chunk_length': 288, 'min_child_weight': 1.9930403720383238, 'subsample': 0.5183646696023395, 'colsample_bytree': 0.6762180355511352, 'gamma': 0.3299108249510878}. Best is trial 63 with value: 3031.569580078125.
# [I 2024-09-11 16:34:01,301] Trial 81 finished with value: 8045.82421875 and parameters: {'max_depth': 4, 'learning_rate': 0.0035638558998640282, 'n_estimators': 475, 'input_chunk_length': 288, 'min_child_weight': 2.323427930549429, 'subsample': 0.6417235152421297, 'colsample_bytree': 0.6639681515107674, 'gamma': 0.3599563382996277}. Best is trial 63 with value: 3031.569580078125.
# [I 2024-09-11 16:34:03,001] Trial 86 finished with value: 4279.833984375 and parameters: {'max_depth': 14, 'learning_rate': 0.02328298933622257, 'n_estimators': 392, 'input_chunk_length': 254, 'min_child_weight': 5.473743319148606, 'subsample': 0.516751466791799, 'colsample_bytree': 0.7671344552861907, 'gamma': 0.1170667880858085}. Best is trial 63 with value: 3031.569580078125.
# [I 2024-09-11 16:34:05,138] Trial 82 finished with value: 9701.1142578125 and parameters: {'max_depth': 10, 'learning_rate': 0.0025748061893227205, 'n_estimators': 469, 'input_chunk_length': 273, 'min_child_weight': 2.4689134212965516, 'subsample': 0.5160374950472951, 'colsample_bytree': 0.7199687949462803, 'gamma': 0.2976980015091502}. Best is trial 63 with value: 3031.569580078125.
# [I 2024-09-11 16:34:07,850] Trial 87 finished with value: 3489.8818359375 and parameters: {'max_depth': 10, 'learning_rate': 0.03263850682674069, 'n_estimators': 397, 'input_chunk_length': 162, 'min_child_weight': 3.1275205869524996, 'subsample': 0.5125578966946629, 'colsample_bytree': 0.77120656445231, 'gamma': 0.11536125199786348}. Best is trial 63 with value: 3031.569580078125.
# [I 2024-09-11 16:34:08,192] Trial 88 finished with value: 3742.29638671875 and parameters: {'max_depth': 14, 'learning_rate': 0.1463107253338696, 'n_estimators': 448, 'input_chunk_length': 253, 'min_child_weight': 8.765259922423681, 'subsample': 0.524012519056498, 'colsample_bytree': 0.7674891105639673, 'gamma': 0.1526873368160332}. Best is trial 63 with value: 3031.569580078125.
# [I 2024-09-11 16:34:10,184] Trial 90 finished with value: 3017.03955078125 and parameters: {'max_depth': 8, 'learning_rate': 0.08660593034611302, 'n_estimators': 396, 'input_chunk_length': 253, 'min_child_weight': 8.829246443566152, 'subsample': 0.5152910451762337, 'colsample_bytree': 0.766632533030797, 'gamma': 0.01117827114576006}. Best is trial 90 with value: 3017.03955078125.
# [I 2024-09-11 16:34:10,363] Trial 91 finished with value: 3052.93701171875 and parameters: {'max_depth': 8, 'learning_rate': 0.08670211089813855, 'n_estimators': 400, 'input_chunk_length': 188, 'min_child_weight': 8.840622330392101, 'subsample': 0.5154295554897981, 'colsample_bytree': 0.7696144286078453, 'gamma': 0.011490888519333848}. Best is trial 90 with value: 3017.03955078125.
# [I 2024-09-11 16:34:10,855] Trial 92 finished with value: 5717.6494140625 and parameters: {'max_depth': 8, 'learning_rate': 0.03250911837013231, 'n_estimators': 445, 'input_chunk_length': 184, 'min_child_weight': 8.701461310151501, 'subsample': 0.5123903004027326, 'colsample_bytree': 0.7402523701200604, 'gamma': 0.47147596070119774}. Best is trial 90 with value: 3017.03955078125.
# [I 2024-09-11 16:34:12,653] Trial 93 finished with value: 6238.57861328125 and parameters: {'max_depth': 7, 'learning_rate': 0.0861488393815112, 'n_estimators': 444, 'input_chunk_length': 185, 'min_child_weight': 2.994757028844699, 'subsample': 0.9955904592060961, 'colsample_bytree': 0.7405514907153766, 'gamma': 0.48469193822244355}. Best is trial 90 with value: 3017.03955078125.
# [I 2024-09-11 16:34:13,026] Trial 89 finished with value: 4298.57763671875 and parameters: {'max_depth': 8, 'learning_rate': 0.08214338683984926, 'n_estimators': 444, 'input_chunk_length': 186, 'min_child_weight': 8.814654706511734, 'subsample': 0.515526213058797, 'colsample_bytree': 0.7717914844701899, 'gamma': 0.002670739132796503}. Best is trial 90 with value: 3017.03955078125.
# [I 2024-09-11 16:34:15,332] Trial 94 finished with value: 6128.291015625 and parameters: {'max_depth': 10, 'learning_rate': 0.032266379357764725, 'n_estimators': 364, 'input_chunk_length': 144, 'min_child_weight': 3.527538785825775, 'subsample': 0.9928184643119018, 'colsample_bytree': 0.7409021568072485, 'gamma': 0.49675139594816553}. Best is trial 90 with value: 3017.03955078125.
# [I 2024-09-11 16:34:17,504] Trial 97 finished with value: 5797.8193359375 and parameters: {'max_depth': 7, 'learning_rate': 0.1749664697551044, 'n_estimators': 398, 'input_chunk_length': 143, 'min_child_weight': 2.8689558695361086, 'subsample': 0.5357032546923941, 'colsample_bytree': 0.7377679502929498, 'gamma': 0.48833664077513905}. Best is trial 90 with value: 3017.03955078125.
# [I 2024-09-11 16:34:17,899] Trial 96 finished with value: 6259.99853515625 and parameters: {'max_depth': 8, 'learning_rate': 0.032062149641641495, 'n_estimators': 361, 'input_chunk_length': 252, 'min_child_weight': 3.4321405155196656, 'subsample': 0.5355206128193226, 'colsample_bytree': 0.7412545912887648, 'gamma': 0.49093383079918623}. Best is trial 90 with value: 3017.03955078125.
# [I 2024-09-11 16:34:20,045] Trial 100 finished with value: 4491.791015625 and parameters: {'max_depth': 7, 'learning_rate': 0.14226250404334911, 'n_estimators': 363, 'input_chunk_length': 138, 'min_child_weight': 3.259169989748192, 'subsample': 0.5336369961522284, 'colsample_bytree': 0.8174033520142672, 'gamma': 0.10273010536549634}. Best is trial 90 with value: 3017.03955078125.
# [I 2024-09-11 16:34:22,131] Trial 95 finished with value: 3432.958740234375 and parameters: {'max_depth': 12, 'learning_rate': 0.015154482854566054, 'n_estimators': 362, 'input_chunk_length': 142, 'min_child_weight': 3.0690911558905656, 'subsample': 0.5636295733544022, 'colsample_bytree': 0.7415841559442347, 'gamma': 0.01928567642091758}. Best is trial 90 with value: 3017.03955078125.
# [I 2024-09-11 16:34:22,529] Trial 101 finished with value: 5586.5302734375 and parameters: {'max_depth': 7, 'learning_rate': 0.13487974098413735, 'n_estimators': 399, 'input_chunk_length': 167, 'min_child_weight': 2.7805593265145774, 'subsample': 0.5323740992059977, 'colsample_bytree': 0.8164787111311634, 'gamma': 0.15397756808884847}. Best is trial 90 with value: 3017.03955078125.
# [I 2024-09-11 16:34:23,920] Trial 99 finished with value: 6642.787109375 and parameters: {'max_depth': 7, 'learning_rate': 0.28515213983546633, 'n_estimators': 399, 'input_chunk_length': 168, 'min_child_weight': 3.2354441764471327, 'subsample': 0.5629806797802055, 'colsample_bytree': 0.7660345780442323, 'gamma': 0.000192447886357517}. Best is trial 90 with value: 3017.03955078125.
# [I 2024-09-11 16:34:25,239] Trial 102 finished with value: 4666.70068359375 and parameters: {'max_depth': 6, 'learning_rate': 0.12185418769261452, 'n_estimators': 423, 'input_chunk_length': 166, 'min_child_weight': 8.206156163859642, 'subsample': 0.589496950427934, 'colsample_bytree': 0.8198105624994174, 'gamma': 0.1617289968574584}. Best is trial 90 with value: 3017.03955078125.
# [I 2024-09-11 16:34:26,005] Trial 103 finished with value: 3527.31494140625 and parameters: {'max_depth': 6, 'learning_rate': 0.12771981427029708, 'n_estimators': 460, 'input_chunk_length': 239, 'min_child_weight': 8.29245482186382, 'subsample': 0.5635165321562938, 'colsample_bytree': 0.7642357297842269, 'gamma': 0.15992649556771033}. Best is trial 90 with value: 3017.03955078125.
# [I 2024-09-11 16:34:27,428] Trial 104 finished with value: 4696.72705078125 and parameters: {'max_depth': 12, 'learning_rate': 0.24528094927275362, 'n_estimators': 462, 'input_chunk_length': 168, 'min_child_weight': 8.000727622204106, 'subsample': 0.5637209716128785, 'colsample_bytree': 0.7637978267720701, 'gamma': 0.16468504371116388}. Best is trial 90 with value: 3017.03955078125.
# [I 2024-09-11 16:34:28,047] Trial 105 finished with value: 5023.29931640625 and parameters: {'max_depth': 12, 'learning_rate': 0.24006060218799147, 'n_estimators': 314, 'input_chunk_length': 165, 'min_child_weight': 2.744991304309564, 'subsample': 0.561393664904768, 'colsample_bytree': 0.766049662600247, 'gamma': 0.1809171254240578}. Best is trial 90 with value: 3017.03955078125.
# [I 2024-09-11 16:34:28,649] Trial 106 finished with value: 12138.6572265625 and parameters: {'max_depth': 12, 'learning_rate': 0.2642811257561553, 'n_estimators': 343, 'input_chunk_length': 235, 'min_child_weight': 8.19639719766681, 'subsample': 0.5904545159242014, 'colsample_bytree': 0.7945386003818883, 'gamma': 4.414858953808465}. Best is trial 90 with value: 3017.03955078125.
# [I 2024-09-11 16:34:32,901] Trial 109 finished with value: 5520.3623046875 and parameters: {'max_depth': 12, 'learning_rate': 0.20975765511650488, 'n_estimators': 384, 'input_chunk_length': 238, 'min_child_weight': 8.367660177295631, 'subsample': 0.570271479873154, 'colsample_bytree': 0.8417124760900707, 'gamma': 0.33860000240367183}. Best is trial 90 with value: 3017.03955078125.
# [I 2024-09-11 16:34:32,999] Trial 108 finished with value: 5837.24755859375 and parameters: {'max_depth': 12, 'learning_rate': 0.0412422364108467, 'n_estimators': 460, 'input_chunk_length': 29, 'min_child_weight': 9.373789808257131, 'subsample': 0.5632423230696749, 'colsample_bytree': 0.8382538716561595, 'gamma': 0.3506204605768501}. Best is trial 90 with value: 3017.03955078125.
# [I 2024-09-11 16:34:34,423] Trial 107 finished with value: 4525.83349609375 and parameters: {'max_depth': 12, 'learning_rate': 0.015889023097865444, 'n_estimators': 422, 'input_chunk_length': 241, 'min_child_weight': 8.207821796623914, 'subsample': 0.5866788510253339, 'colsample_bytree': 0.7891042188235554, 'gamma': 0.1724802945017515}. Best is trial 90 with value: 3017.03955078125.
# [I 2024-09-11 16:34:35,107] Trial 110 finished with value: 15508.578125 and parameters: {'max_depth': 5, 'learning_rate': 0.014208545938198805, 'n_estimators': 379, 'input_chunk_length': 271, 'min_child_weight': 8.39498564744267, 'subsample': 0.5600186543910557, 'colsample_bytree': 0.8409256859531165, 'gamma': 4.56646047890378}. Best is trial 90 with value: 3017.03955078125.
# [I 2024-09-11 16:34:36,473] Trial 112 finished with value: 6451.064453125 and parameters: {'max_depth': 6, 'learning_rate': 0.11198466940988488, 'n_estimators': 379, 'input_chunk_length': 241, 'min_child_weight': 9.756681327159177, 'subsample': 0.5269471154789516, 'colsample_bytree': 0.7068225551592972, 'gamma': 0.380764471830811}. Best is trial 90 with value: 3017.03955078125.
# [I 2024-09-11 16:34:38,070] Trial 111 finished with value: 6046.1494140625 and parameters: {'max_depth': 5, 'learning_rate': 0.016963461600269833, 'n_estimators': 380, 'input_chunk_length': 235, 'min_child_weight': 9.759684119857242, 'subsample': 0.5249213562590066, 'colsample_bytree': 0.7993644616719213, 'gamma': 0.3450640542557328}. Best is trial 90 with value: 3017.03955078125.
# [I 2024-09-11 16:34:41,464] Trial 98 finished with value: 4000.174560546875 and parameters: {'max_depth': 8, 'learning_rate': 0.01530312103986662, 'n_estimators': 399, 'input_chunk_length': 168, 'min_child_weight': 8.11221854009877, 'subsample': 0.5626512780151248, 'colsample_bytree': 0.765271947206246, 'gamma': 0.00012760957410776208}. Best is trial 90 with value: 3017.03955078125.
# [I 2024-09-11 16:34:42,505] Trial 113 finished with value: 7839.93408203125 and parameters: {'max_depth': 5, 'learning_rate': 0.15702953989987856, 'n_estimators': 458, 'input_chunk_length': 242, 'min_child_weight': 9.356757830581302, 'subsample': 0.5357868249863128, 'colsample_bytree': 0.784877624908378, 'gamma': 0.366668456057973}. Best is trial 90 with value: 3017.03955078125.
# [I 2024-09-11 16:34:43,090] Trial 115 finished with value: 7926.1220703125 and parameters: {'max_depth': 5, 'learning_rate': 0.11348588533351647, 'n_estimators': 378, 'input_chunk_length': 258, 'min_child_weight': 9.727822695647893, 'subsample': 0.7055353867543602, 'colsample_bytree': 0.7070795525522026, 'gamma': 1.3826592511883606}. Best is trial 90 with value: 3017.03955078125.
# [I 2024-09-11 16:34:44,665] Trial 116 finished with value: 9597.5341796875 and parameters: {'max_depth': 6, 'learning_rate': 0.15764739408523712, 'n_estimators': 453, 'input_chunk_length': 250, 'min_child_weight': 4.76094657125285, 'subsample': 0.5254920459316048, 'colsample_bytree': 0.7044497979926123, 'gamma': 2.270405660780672}. Best is trial 90 with value: 3017.03955078125.
# [I 2024-09-11 16:34:45,643] Trial 117 finished with value: 3563.032958984375 and parameters: {'max_depth': 8, 'learning_rate': 0.1619541660718991, 'n_estimators': 389, 'input_chunk_length': 250, 'min_child_weight': 3.7983476502060336, 'subsample': 0.5098467355449213, 'colsample_bytree': 0.7824040664879675, 'gamma': 0.04543421558858004}. Best is trial 90 with value: 3017.03955078125.
# [I 2024-09-11 16:34:49,041] Trial 118 finished with value: 3826.015869140625 and parameters: {'max_depth': 14, 'learning_rate': 0.07454548317481272, 'n_estimators': 486, 'input_chunk_length': 249, 'min_child_weight': 4.641567808492188, 'subsample': 0.5417088144286026, 'colsample_bytree': 0.7805393767114936, 'gamma': 0.025948311304820046}. Best is trial 90 with value: 3017.03955078125.
# [I 2024-09-11 16:34:49,937] Trial 119 finished with value: 10276.51953125 and parameters: {'max_depth': 14, 'learning_rate': 0.07209675698338074, 'n_estimators': 453, 'input_chunk_length': 255, 'min_child_weight': 4.664984093859877, 'subsample': 0.5356416773616853, 'colsample_bytree': 0.7829113115990689, 'gamma': 1.9747553139762153}. Best is trial 90 with value: 3017.03955078125.
# [I 2024-09-11 16:34:50,945] Trial 121 finished with value: 4461.44189453125 and parameters: {'max_depth': 11, 'learning_rate': 0.03998544842064885, 'n_estimators': 354, 'input_chunk_length': 252, 'min_child_weight': 8.905529799341998, 'subsample': 0.5101837991722472, 'colsample_bytree': 0.7477476982252964, 'gamma': 0.22747661023114762}. Best is trial 90 with value: 3017.03955078125.
# [I 2024-09-11 16:34:51,674] Trial 120 finished with value: 4569.45166015625 and parameters: {'max_depth': 14, 'learning_rate': 0.0401283431577069, 'n_estimators': 485, 'input_chunk_length': 211, 'min_child_weight': 8.929358282753931, 'subsample': 0.5092984930307777, 'colsample_bytree': 0.7301603252744325, 'gamma': 0.21963997405599486}. Best is trial 90 with value: 3017.03955078125.
# [I 2024-09-11 16:34:52,735] Trial 122 finished with value: 17547.865234375 and parameters: {'max_depth': 14, 'learning_rate': 0.020283684012852677, 'n_estimators': 483, 'input_chunk_length': 212, 'min_child_weight': 3.8062140147217693, 'subsample': 0.54207989797693, 'colsample_bytree': 0.5675956324223996, 'gamma': 4.925564524566893}. Best is trial 90 with value: 3017.03955078125.
# [I 2024-09-11 16:34:54,208] Trial 123 finished with value: 5224.34765625 and parameters: {'max_depth': 11, 'learning_rate': 0.07085762368353551, 'n_estimators': 485, 'input_chunk_length': 254, 'min_child_weight': 3.8682972949475634, 'subsample': 0.509874489532373, 'colsample_bytree': 0.6873633839191925, 'gamma': 0.26312595033463343}. Best is trial 90 with value: 3017.03955078125.
# [I 2024-09-11 16:34:55,871] Trial 114 finished with value: 3724.293212890625 and parameters: {'max_depth': 8, 'learning_rate': 0.015202927159652064, 'n_estimators': 423, 'input_chunk_length': 256, 'min_child_weight': 9.819768348147603, 'subsample': 0.6900626218125274, 'colsample_bytree': 0.7830929442780032, 'gamma': 0.005027102917874956}. Best is trial 90 with value: 3017.03955078125.
# ...
# [I 2024-09-11 16:42:16,389] Trial 460 finished with value: 5216.24658203125 and parameters: {'max_depth': 14, 'learning_rate': 0.13220542646059746, 'n_estimators': 329, 'input_chunk_length': 144, 'min_child_weight': 6.644685525290408, 'subsample': 0.5281086205772836, 'colsample_bytree': 0.7926649537075868, 'gamma': 0.21913067847029316}. Best is trial 385 with value: 2570.861572265625.
# [I 2024-09-11 16:42:17,518] Trial 461 finished with value: 4634.8408203125 and parameters: {'max_depth': 14, 'learning_rate': 0.11495373672199216, 'n_estimators': 317, 'input_chunk_length': 146, 'min_child_weight': 5.4773625958240935, 'subsample': 0.5109524398576857, 'colsample_bytree': 0.796378584177522, 'gamma': 0.19646953914855964}. Best is trial 385 with value: 2570.861572265625.
# [I 2024-09-11 16:42:18,517] Trial 462 finished with value: 3752.139404296875 and parameters: {'max_depth': 14, 'learning_rate': 0.11021497574319013, 'n_estimators': 325, 'input_chunk_length': 144, 'min_child_weight': 6.226781190121595, 'subsample': 0.5134133771439668, 'colsample_bytree': 0.7933765527077179, 'gamma': 0.17822832574694372}. Best is trial 385 with value: 2570.861572265625.
# [I 2024-09-11 16:42:19,504] Trial 464 finished with value: 5997.25341796875 and parameters: {'max_depth': 14, 'learning_rate': 0.112666763013938, 'n_estimators': 321, 'input_chunk_length': 138, 'min_child_weight': 5.727215565949347, 'subsample': 0.5288411693132932, 'colsample_bytree': 0.7913306194610455, 'gamma': 0.4672958240803374}. Best is trial 385 with value: 2570.861572265625.
# [I 2024-09-11 16:42:20,288] Trial 465 finished with value: 4078.87939453125 and parameters: {'max_depth': 14, 'learning_rate': 0.11193950546130259, 'n_estimators': 312, 'input_chunk_length': 137, 'min_child_weight': 5.694894321784411, 'subsample': 0.5277173443962581, 'colsample_bytree': 0.7945259234291935, 'gamma': 0.1893279508251146}. Best is trial 385 with value: 2570.861572265625.
# [I 2024-09-11 16:42:20,736] Trial 466 finished with value: 5529.7265625 and parameters: {'max_depth': 14, 'learning_rate': 0.11490568455917761, 'n_estimators': 321, 'input_chunk_length': 135, 'min_child_weight': 5.774904982130436, 'subsample': 0.5289456750228916, 'colsample_bytree': 0.795253509950828, 'gamma': 0.42532750573341727}. Best is trial 385 with value: 2570.861572265625.
# [I 2024-09-11 16:42:21,212] Trial 467 finished with value: 6070.94482421875 and parameters: {'max_depth': 14, 'learning_rate': 0.10424571276087133, 'n_estimators': 307, 'input_chunk_length': 135, 'min_child_weight': 5.8968592648054985, 'subsample': 0.5279235016409373, 'colsample_bytree': 0.7929047058348322, 'gamma': 0.48804191975246514}. Best is trial 385 with value: 2570.861572265625.
# [I 2024-09-11 16:42:23,014] Trial 468 finished with value: 4319.31298828125 and parameters: {'max_depth': 14, 'learning_rate': 0.1096743570201147, 'n_estimators': 337, 'input_chunk_length': 135, 'min_child_weight': 5.80115148849502, 'subsample': 0.5272649625260835, 'colsample_bytree': 0.7965855922863716, 'gamma': 0.14984343923303545}. Best is trial 385 with value: 2570.861572265625.
# [I 2024-09-11 16:42:23,371] Trial 469 finished with value: 12802.23046875 and parameters: {'max_depth': 14, 'learning_rate': 0.08624682562690024, 'n_estimators': 307, 'input_chunk_length': 136, 'min_child_weight': 6.095725901759859, 'subsample': 0.5276444900961641, 'colsample_bytree': 0.7926958370075086, 'gamma': 2.832576047147176}. Best is trial 385 with value: 2570.861572265625.
# [I 2024-09-11 16:42:23,946] Trial 463 finished with value: 4648.63916015625 and parameters: {'max_depth': 14, 'learning_rate': 0.11172623360771278, 'n_estimators': 311, 'input_chunk_length': 138, 'min_child_weight': 5.984090335409372, 'subsample': 0.5114116206928725, 'colsample_bytree': 0.7948991585463152, 'gamma': 0.0005738811434918192}. Best is trial 385 with value: 2570.861572265625.
# [I 2024-09-11 16:42:25,285] Trial 470 finished with value: 3400.996826171875 and parameters: {'max_depth': 14, 'learning_rate': 0.08672505830986309, 'n_estimators': 309, 'input_chunk_length': 152, 'min_child_weight': 5.77289495865696, 'subsample': 0.5194436064913202, 'colsample_bytree': 0.797940628407138, 'gamma': 0.10270945047501301}. Best is trial 385 with value: 2570.861572265625.
# [I 2024-09-11 16:42:26,140] Trial 471 finished with value: 4001.1162109375 and parameters: {'max_depth': 14, 'learning_rate': 0.08475737952783004, 'n_estimators': 309, 'input_chunk_length': 152, 'min_child_weight': 4.219774688861618, 'subsample': 0.5185534659918593, 'colsample_bytree': 0.7997759251399172, 'gamma': 0.09809073629411656}. Best is trial 385 with value: 2570.861572265625.
# [I 2024-09-11 16:42:28,584] Trial 472 finished with value: 2964.372314453125 and parameters: {'max_depth': 14, 'learning_rate': 0.08516679908752385, 'n_estimators': 340, 'input_chunk_length': 151, 'min_child_weight': 5.836099471011287, 'subsample': 0.5188742594846389, 'colsample_bytree': 0.8033063092395465, 'gamma': 0.003791648880779995}. Best is trial 385 with value: 2570.861572265625.
# [I 2024-09-11 16:42:28,689] Trial 475 finished with value: 4114.47412109375 and parameters: {'max_depth': 14, 'learning_rate': 0.09426478493653118, 'n_estimators': 315, 'input_chunk_length': 133, 'min_child_weight': 5.888328893830468, 'subsample': 0.5148328931674675, 'colsample_bytree': 0.7588789955167975, 'gamma': 0.08692787407075307}. Best is trial 385 with value: 2570.861572265625.
# [I 2024-09-11 16:42:29,181] Trial 476 finished with value: 4200.19677734375 and parameters: {'max_depth': 14, 'learning_rate': 0.09224130612919128, 'n_estimators': 300, 'input_chunk_length': 153, 'min_child_weight': 6.086799268271242, 'subsample': 0.5181066826178715, 'colsample_bytree': 0.7553658832724996, 'gamma': 0.10619451508285546}. Best is trial 385 with value: 2570.861572265625.
# [I 2024-09-11 16:42:30,236] Trial 477 finished with value: 14019.4423828125 and parameters: {'max_depth': 14, 'learning_rate': 0.09512629475377092, 'n_estimators': 343, 'input_chunk_length': 130, 'min_child_weight': 4.8969695642892646, 'subsample': 0.5095261077939449, 'colsample_bytree': 0.7809329514566292, 'gamma': 3.0995678483130717}. Best is trial 385 with value: 2570.861572265625.
# [I 2024-09-11 16:42:30,791] Trial 473 finished with value: 4215.44580078125 and parameters: {'max_depth': 14, 'learning_rate': 0.08333318945973263, 'n_estimators': 307, 'input_chunk_length': 153, 'min_child_weight': 5.964777627941852, 'subsample': 0.5209089092976504, 'colsample_bytree': 0.7563068386672641, 'gamma': 0.001238084342418426}. Best is trial 385 with value: 2570.861572265625.
# [I 2024-09-11 16:42:31,343] Trial 478 finished with value: 4231.5263671875 and parameters: {'max_depth': 14, 'learning_rate': 0.0960371110659649, 'n_estimators': 343, 'input_chunk_length': 133, 'min_child_weight': 5.5188257744517815, 'subsample': 0.5505979545959337, 'colsample_bytree': 0.7563459249458884, 'gamma': 0.262868208885331}. Best is trial 385 with value: 2570.861572265625.
# [I 2024-09-11 16:42:33,776] Trial 474 finished with value: 2591.61962890625 and parameters: {'max_depth': 14, 'learning_rate': 0.0848374457222291, 'n_estimators': 340, 'input_chunk_length': 151, 'min_child_weight': 5.12541411192068, 'subsample': 0.5159698595521157, 'colsample_bytree': 0.7576634092283544, 'gamma': 0.0008635313634075114}. Best is trial 385 with value: 2570.861572265625.
# [I 2024-09-11 16:42:33,920] Trial 480 finished with value: 13388.0009765625 and parameters: {'max_depth': 15, 'learning_rate': 0.14054528023597906, 'n_estimators': 334, 'input_chunk_length': 158, 'min_child_weight': 5.5528592291009415, 'subsample': 0.5077776829428226, 'colsample_bytree': 0.8161984972525116, 'gamma': 2.5517467103488336}. Best is trial 385 with value: 2570.861572265625.
# [I 2024-09-11 16:42:34,290] Trial 479 finished with value: 4358.5927734375 and parameters: {'max_depth': 14, 'learning_rate': 0.09599141407285858, 'n_estimators': 339, 'input_chunk_length': 156, 'min_child_weight': 6.0149311744039915, 'subsample': 0.5084044535001496, 'colsample_bytree': 0.8179025284312123, 'gamma': 0.2674206396995437}. Best is trial 385 with value: 2570.861572265625.
# [I 2024-09-11 16:42:34,881] Trial 481 finished with value: 4822.68310546875 and parameters: {'max_depth': 14, 'learning_rate': 0.1298459149873088, 'n_estimators': 342, 'input_chunk_length': 164, 'min_child_weight': 1.1745071441239072, 'subsample': 0.5051600820697347, 'colsample_bytree': 0.7814332448357768, 'gamma': 0.26434734473164395}. Best is trial 385 with value: 2570.861572265625.
# [I 2024-09-11 16:42:35,975] Trial 482 finished with value: 4286.35205078125 and parameters: {'max_depth': 14, 'learning_rate': 0.13529136043387469, 'n_estimators': 332, 'input_chunk_length': 159, 'min_child_weight': 5.930761151525838, 'subsample': 0.5354850062576525, 'colsample_bytree': 0.8223418656894251, 'gamma': 0.26783731320199305}. Best is trial 385 with value: 2570.861572265625.
# [I 2024-09-11 16:42:36,380] Trial 484 finished with value: 3253.048095703125 and parameters: {'max_depth': 15, 'learning_rate': 0.13026580895025386, 'n_estimators': 137, 'input_chunk_length': 164, 'min_child_weight': 5.482820429853579, 'subsample': 0.5053700878121515, 'colsample_bytree': 0.8068297787587254, 'gamma': 0.005941764991367508}. Best is trial 385 with value: 2570.861572265625.
# [I 2024-09-11 16:42:36,462] Trial 483 finished with value: 5224.17236328125 and parameters: {'max_depth': 14, 'learning_rate': 0.13505415073474217, 'n_estimators': 332, 'input_chunk_length': 160, 'min_child_weight': 8.999712208797654, 'subsample': 0.5017559640656771, 'colsample_bytree': 0.8184619722039995, 'gamma': 0.2668240813918902}. Best is trial 385 with value: 2570.861572265625.
# [I 2024-09-11 16:42:39,661] Trial 487 finished with value: 4049.609375 and parameters: {'max_depth': 14, 'learning_rate': 0.1362390821102754, 'n_estimators': 329, 'input_chunk_length': 166, 'min_child_weight': 5.367488156188641, 'subsample': 0.5368666353284691, 'colsample_bytree': 0.781247810430889, 'gamma': 0.1470659296062349}. Best is trial 385 with value: 2570.861572265625.
# [I 2024-09-11 16:42:40,443] Trial 488 finished with value: 4689.50244140625 and parameters: {'max_depth': 14, 'learning_rate': 0.12692495868714512, 'n_estimators': 330, 'input_chunk_length': 152, 'min_child_weight': 4.692947394000128, 'subsample': 0.5378634362612879, 'colsample_bytree': 0.8058576743510916, 'gamma': 0.14639000352208947}. Best is trial 385 with value: 2570.861572265625.
# [I 2024-09-11 16:42:40,938] Trial 486 finished with value: 3509.222900390625 and parameters: {'max_depth': 14, 'learning_rate': 0.12336153406615596, 'n_estimators': 331, 'input_chunk_length': 155, 'min_child_weight': 5.6078947145011115, 'subsample': 0.5005464764006627, 'colsample_bytree': 0.6215038137627809, 'gamma': 0.005055445355498157}. Best is trial 385 with value: 2570.861572265625.
# [I 2024-09-11 16:42:41,740] Trial 485 finished with value: 3634.418701171875 and parameters: {'max_depth': 14, 'learning_rate': 0.13245031438474353, 'n_estimators': 328, 'input_chunk_length': 162, 'min_child_weight': 6.030975935826532, 'subsample': 0.5061658083857119, 'colsample_bytree': 0.8191152978573073, 'gamma': 0.0027948280296292544}. Best is trial 385 with value: 2570.861572265625.
# [I 2024-09-11 16:42:43,213] Trial 491 finished with value: 5018.85693359375 and parameters: {'max_depth': 15, 'learning_rate': 0.1497988435888226, 'n_estimators': 294, 'input_chunk_length': 165, 'min_child_weight': 5.316586226639757, 'subsample': 0.5191540098900881, 'colsample_bytree': 0.8104089909187588, 'gamma': 0.011848849170471382}. Best is trial 385 with value: 2570.861572265625.
# [I 2024-09-11 16:42:43,777] Trial 489 finished with value: 4406.36474609375 and parameters: {'max_depth': 15, 'learning_rate': 0.1238247211898719, 'n_estimators': 329, 'input_chunk_length': 150, 'min_child_weight': 5.574746316124911, 'subsample': 0.5363326008259619, 'colsample_bytree': 0.5648005008294107, 'gamma': 0.004730782759769539}. Best is trial 385 with value: 2570.861572265625.
# [I 2024-09-11 16:42:45,033] Trial 490 finished with value: 3315.308349609375 and parameters: {'max_depth': 14, 'learning_rate': 0.15020525996221232, 'n_estimators': 328, 'input_chunk_length': 151, 'min_child_weight': 5.381621379667932, 'subsample': 0.501097287676935, 'colsample_bytree': 0.8071070726832326, 'gamma': 0.0023127476141231312}. Best is trial 385 with value: 2570.861572265625.
# [I 2024-09-11 16:42:45,425] Trial 493 finished with value: 2935.07568359375 and parameters: {'max_depth': 15, 'learning_rate': 0.12026224486646929, 'n_estimators': 120, 'input_chunk_length': 142, 'min_child_weight': 5.143485669866231, 'subsample': 0.5189291848463682, 'colsample_bytree': 0.6607231665353801, 'gamma': 0.01533266072959074}. Best is trial 385 with value: 2570.861572265625.
# [I 2024-09-11 16:42:45,772] Trial 495 finished with value: 7080.1494140625 and parameters: {'max_depth': 15, 'learning_rate': 0.14789046398674302, 'n_estimators': 123, 'input_chunk_length': 203, 'min_child_weight': 5.262733984371321, 'subsample': 0.5190367350017381, 'colsample_bytree': 0.8094851512155534, 'gamma': 0.8184664553395131}. Best is trial 385 with value: 2570.861572265625.
# [I 2024-09-11 16:42:47,095] Trial 494 finished with value: 4060.2529296875 and parameters: {'max_depth': 15, 'learning_rate': 0.1461182569499351, 'n_estimators': 345, 'input_chunk_length': 204, 'min_child_weight': 5.155555224423058, 'subsample': 0.5201887355910064, 'colsample_bytree': 0.8042801264170102, 'gamma': 0.07262529832943332}. Best is trial 385 with value: 2570.861572265625.
# [I 2024-09-11 16:42:48,544] Trial 499 finished with value: 4297.42529296875 and parameters: {'max_depth': 15, 'learning_rate': 0.11927601540727106, 'n_estimators': 127, 'input_chunk_length': 141, 'min_child_weight': 5.40758790349262, 'subsample': 0.5189070675374927, 'colsample_bytree': 0.5622347547428278, 'gamma': 0.11350752529047298}. Best is trial 385 with value: 2570.861572265625.
# [I 2024-09-11 16:42:48,744] Trial 497 finished with value: 5393.0830078125 and parameters: {'max_depth': 15, 'learning_rate': 0.15004711883102434, 'n_estimators': 321, 'input_chunk_length': 143, 'min_child_weight': 5.292897897186591, 'subsample': 0.5150807268829892, 'colsample_bytree': 0.5014855594386879, 'gamma': 0.08654225421010381}. Best is trial 385 with value: 2570.861572265625.
# [I 2024-09-11 16:42:49,162] Trial 498 finished with value: 3632.251708984375 and parameters: {'max_depth': 13, 'learning_rate': 0.10341391276554887, 'n_estimators': 340, 'input_chunk_length': 139, 'min_child_weight': 5.090495133481889, 'subsample': 0.5194411862172522, 'colsample_bytree': 0.7675906553477576, 'gamma': 0.13830107710410677}. Best is trial 385 with value: 2570.861572265625.
# [I 2024-09-11 16:42:49,192] Trial 496 finished with value: 3480.068115234375 and parameters: {'max_depth': 13, 'learning_rate': 0.10346527017739403, 'n_estimators': 345, 'input_chunk_length': 148, 'min_child_weight': 5.08609110222342, 'subsample': 0.5160694044660549, 'colsample_bytree': 0.806306315936221, 'gamma': 0.0036214301308115787}. Best is trial 385 with value: 2570.861572265625.
# [I 2024-09-11 16:42:50,571] Trial 492 finished with value: 4833.04736328125 and parameters: {'max_depth': 15, 'learning_rate': 0.15165014486397224, 'n_estimators': 325, 'input_chunk_length': 175, 'min_child_weight': 5.007486879917718, 'subsample': 0.518275265651324, 'colsample_bytree': 0.8085853683035612, 'gamma': 3.352804321916617e-05}. Best is trial 385 with value: 2570.861572265625.
# /n Best hyperparameters:  {'max_depth': 14, 'learning_rate': 0.18973066180608145, 'n_estimators': 267, 'input_chunk_length': 285, 'min_child_weight': 1.6607694655354948, 'subsample': 0.846461608657852, 'colsample_bytree': 0.5605099283678379, 'gamma': 0.000967675267927029}
# Mean Absolute Error on Test Set: 28.56793785095215
# Mean Absolute Percentage Error on Test Set: 75.23526000976562
# Mean Squared Error on Test Set: 2570.861572265625
# Root Mean Squared Error on Test Set: 50.70366287231445

# %%
# Save the created figure as png file and the error metrics 
fig.write_image("../../predictions/XGBoost/XGBoost_forecast_no_tscv.png")
error_metrics = pd.DataFrame({'MAE': [mae(series_test, forecast)], 'MAPE': [mape(series_test, forecast)], 'MSE': [mse(series_test, forecast)], 'RMSE': [rmse(series_test, forecast)]})
error_metrics.to_csv('../../predictions/XGBoost/XGBoost_error_metrics_no_tscv.csv', index=False)

# Also save hyperparameters of the model in the csv file
best_params_df = pd.DataFrame(best_params, index=[0])
best_params_df.to_csv('../../predictions/XGBoost/XGBoost_hyperparameters_no_tscv.csv', index=False)

# %% [markdown]
# ##### Applying the TimeSeriesSplit

# %%
import pandas as pd
import numpy as np
from darts import TimeSeries
from darts.models import XGBModel
from darts.dataprocessing.transformers import Scaler
from darts.metrics import mape, rmse, mse, mae
import optuna
from sklearn.model_selection import TimeSeriesSplit
import plotly.graph_objs as go

# Function to train the model and evaluate performance using cross-validation
def train_and_evaluate(tscv, series_train_scaled, future_covariates_train_scaled, scaler_series, n_splits):
    def objective(trial):
        # Define hyperparameters to tune
        max_depth = trial.suggest_int('max_depth', 3, 15)
        learning_rate = trial.suggest_float('learning_rate', 0.001, 0.3, log=True)
        n_estimators = trial.suggest_int('n_estimators', 50, 500)
        input_chunk_length = trial.suggest_int('input_chunk_length', 10, 200)
        min_child_weight = trial.suggest_float('min_child_weight', 0.1, 10.0)
        subsample = trial.suggest_float('subsample', 0.5, 1.0)
        colsample_bytree = trial.suggest_float('colsample_bytree', 0.5, 1.0)
        gamma = trial.suggest_float('gamma', 0, 5)
        output_chunk_length = trial.suggest_int('output_chunk_length', 1, 7)  # Tune for longer horizons

        # Initialize the model with the trial hyperparameters
        model = XGBModel(
            lags=input_chunk_length,
            output_chunk_length=output_chunk_length,
            lags_future_covariates=[0],
            max_depth=max_depth,
            learning_rate=learning_rate,
            n_estimators=n_estimators,
            min_child_weight=min_child_weight,
            subsample=subsample,
            colsample_bytree=colsample_bytree,
            gamma=gamma,
            random_state=42
        )

        # Cross-validation loop
        errors_mse, errors_mae, errors_mape, errors_rmse = [], [], [], []

        for train_index, test_index in tscv.split(series_train_scaled.pd_dataframe()):
            # Check if there is enough data in the current fold to accommodate input_chunk_length
            if len(train_index) <= input_chunk_length:
                continue  # Skip this fold if not enough data

            # Get the corresponding date ranges from indices
            train_start, train_end = series_train_scaled.time_index[train_index[0]], series_train_scaled.time_index[train_index[-1]]
            test_start, test_end = series_train_scaled.time_index[test_index[0]], series_train_scaled.time_index[test_index[-1]]

            # Slice the TimeSeries objects based on date ranges
            train_series = series_train_scaled.slice(train_start, train_end)
            val_series = series_train_scaled.slice(test_start, test_end)
            train_covariates = future_covariates_train_scaled.slice(train_start, train_end)
            val_covariates = future_covariates_train_scaled.slice(test_start, test_end)

            # Train the model on the training set
            model.fit(train_series, future_covariates=train_covariates)

            # Predict on the validation set
            forecast_scaled = model.predict(n=len(val_series), future_covariates=val_covariates)

            # Inverse transform the forecast to the original scale
            forecast = scaler_series.inverse_transform(forecast_scaled)

            # Calculate errors on the validation set
            errors_mse.append(mse(val_series, forecast))
            errors_mae.append(mae(val_series, forecast))
            errors_rmse.append(rmse(val_series, forecast))

            # Only calculate MAPE if all actual values are positive
            if (val_series.values() > 0).all():
                errors_mape.append(mape(val_series, forecast))
            else:
                errors_mape.append(np.nan)  # or some default value to indicate MAPE could not be calculated

        # Store metrics for the current trial
        trial.set_user_attr('mse', np.mean(errors_mse))
        trial.set_user_attr('mae', np.mean(errors_mae))
        trial.set_user_attr('mape', np.nanmean(errors_mape))  # Use nanmean to handle NaN values
        trial.set_user_attr('rmse', np.mean(errors_rmse))

        # Return the average MSE across all splits as the metric to optimize
        return np.mean(errors_mse)

    # Create an Optuna study and optimize
    study = optuna.create_study(direction='minimize', sampler=optuna.samplers.TPESampler())
    study.optimize(objective, n_trials=300, n_jobs=5)

    return study

# Function to make final predictions and evaluate on the test set
def final_model_evaluation(best_params, series_train_scaled, future_covariates_train_scaled, series_test, future_covariates_test_scaled, scaler_series):
    best_model = XGBModel(
        lags=best_params['input_chunk_length'],
        output_chunk_length=best_params['output_chunk_length'], 
        lags_future_covariates=[0],  # Using the current value of future covariates for prediction
        max_depth=best_params['max_depth'],
        learning_rate=best_params['learning_rate'],
        n_estimators=best_params['n_estimators'],
        min_child_weight=best_params['min_child_weight'],
        subsample=best_params['subsample'],
        colsample_bytree=best_params['colsample_bytree'],
        gamma=best_params['gamma'],
        random_state=42
    )

    # Fit the model on the entire scaled training set
    best_model.fit(series_train_scaled, future_covariates=future_covariates_train_scaled)

    # Make predictions on the test set
    forecast_scaled = best_model.predict(n=len(series_test), future_covariates=future_covariates_test_scaled)

    # Inverse transform the forecast to the original scale
    forecast = scaler_series.inverse_transform(forecast_scaled)

    return forecast

# Convert future covariates to TimeSeries objects
future_covariates_train = TimeSeries.from_dataframe(train_df, 'Date', future_covariates_columns).astype('float32')
future_covariates_full = TimeSeries.from_dataframe(df, 'Date', future_covariates_columns, fill_missing_dates=True, freq="D").astype('float32')

# Scaling the data
scaler_series = Scaler()
scaler_covariates = Scaler()

# Fit the scaler on the full training data
series_train_scaled = scaler_series.fit_transform(series_train)
future_covariates_train_scaled = scaler_covariates.fit_transform(future_covariates_train)

# Define list of n_splits to try
n_splits_list = [5, 10]

# Initialize a dictionary to store DataFrames for each n_splits value
results_dict = {}

# Loop over different n_splits values
for n_splits in n_splits_list:
    print(f"Processing TimeSeriesSplit with {n_splits} splits...")

    # Define TimeSeriesSplit with the current n_splits
    tscv = TimeSeriesSplit(n_splits=n_splits, max_train_size=500) 
    
    # Train and evaluate model using cross-validation
    study = train_and_evaluate(tscv, series_train_scaled, future_covariates_train_scaled, scaler_series, n_splits)

    # Print the best hyperparameters
    print(f'Best hyperparameters for {n_splits} splits: ', study.best_params)

    # Store the best hyperparameters for each split setting
    best_params = study.best_params

    # --- Slicing the Test Covariates According to Best `input_chunk_length` ---
    input_chunk_length = best_params['input_chunk_length']
    required_start_date = pd.Timestamp(test_df['Date'].iloc[0]) - pd.DateOffset(days=input_chunk_length)
    required_end_date = pd.Timestamp(test_df['Date'].iloc[0]) + pd.DateOffset(days=len(series_test) - 1)
    future_covariates_test = future_covariates_full.slice(required_start_date, required_end_date)
    future_covariates_test_scaled = scaler_covariates.transform(future_covariates_test)

    # Make final predictions on the test set using the best hyperparameters
    forecast = final_model_evaluation(best_params, series_train_scaled, future_covariates_train_scaled, series_test, future_covariates_test_scaled, scaler_series)

    # Store the results
    results_dict[f'n_splits_{n_splits}'] = pd.DataFrame({
        'mse': [mse(series_test, forecast)],
        'mae': [mae(series_test, forecast)],
        'mape': [mape(series_test, forecast) if (series_test.values() > 0).all() else np.nan],
        'rmse': [rmse(series_test, forecast)]
    })

# Find the best n_splits based on the lowest mse
comparison_df = pd.concat(
    [df.assign(n_splits=int(n_splits.split('_')[-1])) for n_splits, df in results_dict.items()]
)

best_n_splits = comparison_df['n_splits'].iloc[comparison_df['mse'].idxmin()]

# Corrected: Format the key properly to match the results_dict keys
best_n_splits_key = f'n_splits_{best_n_splits}'  # No need to convert to int, as it's already the correct format

# Extract the best hyperparameters for the best n_splits
best_results_df = results_dict[best_n_splits_key]
best_trial = best_results_df.loc[best_results_df['mse'].idxmin()]

print("\nBest hyperparameter combination and error metrics for the best TimeSeriesSplit configuration:")
print(f"Best n_splits: {best_n_splits_key}")
print(f"Best hyperparameters: {study.best_params}")
print(f"MSE: {best_trial['mse']}")
print(f"MAE: {best_trial['mae']}")
print(f"MAPE: {best_trial['mape']}")
print(f"RMSE: {best_trial['rmse']}")

# Evaluate error metrics on the full test data using the best hyperparameters
mse_test = mse(series_test, forecast)
mae_test = mae(series_test, forecast)
mape_test = mape(series_test, forecast) if (series_test.values() > 0).all() else np.nan
rmse_test = rmse(series_test, forecast)

print("\nError metrics for the test data using the best hyperparameters:")
print(f"MSE on Test Set: {mse_test}")
print(f"MAE on Test Set: {mae_test}")
print(f"MAPE on Test Set: {mape_test}")
print(f"RMSE on Test Set: {rmse_test}")

# Plot the results using Plotly for the best hyperparameters
test_df_plotly = series_test.pd_dataframe()
forecast_df_plotly = forecast.pd_dataframe()

fig = go.Figure()

# Add actual test data trace
fig.add_trace(go.Scatter(x=test_df_plotly.index, y=test_df_plotly['Day_ahead_price (€/MWh)'],
                         mode='lines', name='Actual Test Data', line=dict(color='darkblue')))

# Add forecast data trace
fig.add_trace(go.Scatter(x=forecast_df_plotly.index, y=forecast_df_plotly['Day_ahead_price (€/MWh)'],
                         mode='lines', name='XGBoost Forecast on Test Data', line=dict(color='red')))

# Update layout
fig.update_layout(
    title=f'XGBoost Model - Test Performance (Best n_splits={best_n_splits_key})',
    xaxis_title='Date',
    yaxis_title='Day Ahead Price (€/MWh)',
    legend=dict(
        x=1,   # Set x position to 1 (far right)
        y=1,   # Set y position to 1 (top)
        xanchor='right',  # Anchor the legend's x position to the right
        yanchor='top',    # Anchor the legend's y position to the top
        bordercolor='black',  # Optional: Add a border around the legend
        borderwidth=1        # Optional: Set the border width
    ),
    template='plotly'
)

# Show the plot
fig.show()
# Out:
# [I 2024-09-12 08:32:44,105] A new study created in memory with name: no-name-53cac99f-4efe-4735-a82a-4f17b4a97f33
# Processing TimeSeriesSplit with 5 splits...
# [I 2024-09-12 08:32:46,763] Trial 0 finished with value: 1305.2904052734375 and parameters: {'max_depth': 15, 'learning_rate': 0.10376625701919677, 'n_estimators': 134, 'input_chunk_length': 197, 'min_child_weight': 9.020844422618593, 'subsample': 0.8222321636466098, 'colsample_bytree': 0.735014683281811, 'gamma': 3.6552144118896974, 'output_chunk_length': 1}. Best is trial 0 with value: 1305.2904052734375.
# [I 2024-09-12 08:32:48,940] Trial 3 finished with value: 1264.1754150390625 and parameters: {'max_depth': 10, 'learning_rate': 0.0013831997246393903, 'n_estimators': 63, 'input_chunk_length': 85, 'min_child_weight': 9.940053516671426, 'subsample': 0.7474545947552106, 'colsample_bytree': 0.9032172716029894, 'gamma': 3.8557296393496463, 'output_chunk_length': 6}. Best is trial 3 with value: 1264.1754150390625.
# [I 2024-09-12 08:32:50,124] Trial 2 finished with value: 1260.43212890625 and parameters: {'max_depth': 13, 'learning_rate': 0.03472688149066481, 'n_estimators': 134, 'input_chunk_length': 78, 'min_child_weight': 3.5163952389955218, 'subsample': 0.6577134208632536, 'colsample_bytree': 0.5755862695244257, 'gamma': 4.401011627277732, 'output_chunk_length': 4}. Best is trial 2 with value: 1260.43212890625.
# [I 2024-09-12 08:32:50,825] Trial 4 finished with value: 1266.868896484375 and parameters: {'max_depth': 7, 'learning_rate': 0.02240033390624037, 'n_estimators': 151, 'input_chunk_length': 102, 'min_child_weight': 3.098780224278804, 'subsample': 0.7488050779263677, 'colsample_bytree': 0.9704611266456171, 'gamma': 0.44809042602855453, 'output_chunk_length': 4}. Best is trial 2 with value: 1260.43212890625.
# [I 2024-09-12 08:32:56,672] Trial 7 finished with value: 1307.6253662109375 and parameters: {'max_depth': 3, 'learning_rate': 0.0026780910608913866, 'n_estimators': 122, 'input_chunk_length': 184, 'min_child_weight': 7.531083065790191, 'subsample': 0.6435570952232426, 'colsample_bytree': 0.6069622993143298, 'gamma': 2.641009316131164, 'output_chunk_length': 5}. Best is trial 2 with value: 1260.43212890625.
# [I 2024-09-12 08:32:57,987] Trial 8 finished with value: 1291.691162109375 and parameters: {'max_depth': 9, 'learning_rate': 0.23572611882810843, 'n_estimators': 350, 'input_chunk_length': 159, 'min_child_weight': 2.2263932878219608, 'subsample': 0.9034726308783425, 'colsample_bytree': 0.8304005562582126, 'gamma': 0.38030637002606893, 'output_chunk_length': 2}. Best is trial 2 with value: 1260.43212890625.
# [I 2024-09-12 08:32:59,713] Trial 9 finished with value: 1247.3538818359375 and parameters: {'max_depth': 3, 'learning_rate': 0.0012219819841371665, 'n_estimators': 110, 'input_chunk_length': 34, 'min_child_weight': 4.106458985258219, 'subsample': 0.9899246361934002, 'colsample_bytree': 0.8020443203289075, 'gamma': 3.769569533088104, 'output_chunk_length': 2}. Best is trial 9 with value: 1247.3538818359375.
# [I 2024-09-12 08:33:00,092] Trial 1 finished with value: 1296.846435546875 and parameters: {'max_depth': 5, 'learning_rate': 0.04893883153322087, 'n_estimators': 309, 'input_chunk_length': 163, 'min_child_weight': 8.065469444270303, 'subsample': 0.7946311700340005, 'colsample_bytree': 0.6523972199964068, 'gamma': 1.0936757439357114, 'output_chunk_length': 6}. Best is trial 9 with value: 1247.3538818359375.
# [I 2024-09-12 08:33:02,880] Trial 5 finished with value: 1289.3988037109375 and parameters: {'max_depth': 4, 'learning_rate': 0.005706063510685865, 'n_estimators': 474, 'input_chunk_length': 149, 'min_child_weight': 9.749967472605151, 'subsample': 0.7899193596845295, 'colsample_bytree': 0.9819797180593499, 'gamma': 0.7478424460483835, 'output_chunk_length': 4}. Best is trial 9 with value: 1247.3538818359375.
# [I 2024-09-12 08:33:03,756] Trial 6 finished with value: 1293.351318359375 and parameters: {'max_depth': 5, 'learning_rate': 0.0011488010318640126, 'n_estimators': 294, 'input_chunk_length': 156, 'min_child_weight': 3.8417307183136664, 'subsample': 0.6602788156514359, 'colsample_bytree': 0.9629982435656798, 'gamma': 1.087719022681091, 'output_chunk_length': 6}. Best is trial 9 with value: 1247.3538818359375.
# [I 2024-09-12 08:33:06,321] Trial 12 finished with value: 1239.0955810546875 and parameters: {'max_depth': 6, 'learning_rate': 0.20302700169083998, 'n_estimators': 197, 'input_chunk_length': 18, 'min_child_weight': 8.053125621782867, 'subsample': 0.8693941793333879, 'colsample_bytree': 0.9767069433560875, 'gamma': 0.8572707742240615, 'output_chunk_length': 4}. Best is trial 12 with value: 1239.0955810546875.
# [I 2024-09-12 08:33:07,747] Trial 14 finished with value: 1239.5740966796875 and parameters: {'max_depth': 8, 'learning_rate': 0.007137830350650834, 'n_estimators': 216, 'input_chunk_length': 19, 'min_child_weight': 0.20052388417333766, 'subsample': 0.9807484899668178, 'colsample_bytree': 0.7604345127518991, 'gamma': 2.483973832689896, 'output_chunk_length': 2}. Best is trial 12 with value: 1239.0955810546875.
# [I 2024-09-12 08:33:09,062] Trial 11 finished with value: 1282.216064453125 and parameters: {'max_depth': 13, 'learning_rate': 0.02111671852461678, 'n_estimators': 408, 'input_chunk_length': 138, 'min_child_weight': 0.6615540733026529, 'subsample': 0.9502019096148808, 'colsample_bytree': 0.6708526219487297, 'gamma': 4.218365991055377, 'output_chunk_length': 3}. Best is trial 12 with value: 1239.0955810546875.
# [I 2024-09-12 08:33:10,294] Trial 10 finished with value: 1246.2501220703125 and parameters: {'max_depth': 7, 'learning_rate': 0.0022272995488694667, 'n_estimators': 293, 'input_chunk_length': 28, 'min_child_weight': 1.7387464459301791, 'subsample': 0.703164736630513, 'colsample_bytree': 0.5308135629345003, 'gamma': 2.3822971023976396, 'output_chunk_length': 6}. Best is trial 12 with value: 1239.0955810546875.
# [I 2024-09-12 08:33:10,391] Trial 15 finished with value: 1242.618896484375 and parameters: {'max_depth': 7, 'learning_rate': 0.0061101925356218155, 'n_estimators': 218, 'input_chunk_length': 21, 'min_child_weight': 0.24249471958659008, 'subsample': 0.9986076422456098, 'colsample_bytree': 0.7999632940384309, 'gamma': 2.323577315360452, 'output_chunk_length': 2}. Best is trial 12 with value: 1239.0955810546875.
# [I 2024-09-12 08:33:11,524] Trial 17 finished with value: 1239.0899658203125 and parameters: {'max_depth': 8, 'learning_rate': 0.010233907304276557, 'n_estimators': 200, 'input_chunk_length': 12, 'min_child_weight': 6.001713660965742, 'subsample': 0.5082573703750745, 'colsample_bytree': 0.5284698655997248, 'gamma': 2.187604444909542, 'output_chunk_length': 1}. Best is trial 17 with value: 1239.0899658203125.
# [I 2024-09-12 08:33:12,932] Trial 18 finished with value: 1240.102783203125 and parameters: {'max_depth': 8, 'learning_rate': 0.009296255314393976, 'n_estimators': 214, 'input_chunk_length': 10, 'min_child_weight': 6.288776164263842, 'subsample': 0.5090550039946292, 'colsample_bytree': 0.8842940276004067, 'gamma': 2.064955647683997, 'output_chunk_length': 1}. Best is trial 17 with value: 1239.0899658203125.
# [I 2024-09-12 08:33:13,194] Trial 19 finished with value: 1256.9002685546875 and parameters: {'max_depth': 9, 'learning_rate': 0.007749462589187027, 'n_estimators': 223, 'input_chunk_length': 54, 'min_child_weight': 6.115232712864193, 'subsample': 0.5018721303834358, 'colsample_bytree': 0.870369805824478, 'gamma': 1.6256145701220355, 'output_chunk_length': 1}. Best is trial 17 with value: 1239.0899658203125.
# [I 2024-09-12 08:33:13,331] Trial 16 finished with value: 1239.7449951171875 and parameters: {'max_depth': 8, 'learning_rate': 0.008830943937716221, 'n_estimators': 225, 'input_chunk_length': 16, 'min_child_weight': 0.5112460279840682, 'subsample': 0.9838246638429644, 'colsample_bytree': 0.7146330849700487, 'gamma': 2.047889774834741, 'output_chunk_length': 3}. Best is trial 17 with value: 1239.0899658203125.
# [I 2024-09-12 08:33:14,390] Trial 20 finished with value: 1255.9708251953125 and parameters: {'max_depth': 11, 'learning_rate': 0.08611462791936193, 'n_estimators': 215, 'input_chunk_length': 57, 'min_child_weight': 6.144188322781037, 'subsample': 0.5058481739127051, 'colsample_bytree': 0.5070664318212745, 'gamma': 1.7449781296144091, 'output_chunk_length': 1}. Best is trial 17 with value: 1239.0899658203125.
# [I 2024-09-12 08:33:14,478] Trial 13 finished with value: 1283.445556640625 and parameters: {'max_depth': 6, 'learning_rate': 0.040438117867782786, 'n_estimators': 316, 'input_chunk_length': 137, 'min_child_weight': 1.864189427603548, 'subsample': 0.5336523100933276, 'colsample_bytree': 0.6605251608431226, 'gamma': 2.5696118760287865, 'output_chunk_length': 5}. Best is trial 17 with value: 1239.0899658203125.
# [I 2024-09-12 08:33:17,064] Trial 22 finished with value: 1257.2333984375 and parameters: {'max_depth': 11, 'learning_rate': 0.28043831719499257, 'n_estimators': 50, 'input_chunk_length': 53, 'min_child_weight': 5.464095370851025, 'subsample': 0.5809197530315163, 'colsample_bytree': 0.7041947988240531, 'gamma': 1.6427718230301191, 'output_chunk_length': 7}. Best is trial 17 with value: 1239.0899658203125.
# [I 2024-09-12 08:33:17,254] Trial 23 finished with value: 1257.0443115234375 and parameters: {'max_depth': 11, 'learning_rate': 0.2866182889354075, 'n_estimators': 52, 'input_chunk_length': 54, 'min_child_weight': 5.7146929804398745, 'subsample': 0.5775279481185513, 'colsample_bytree': 0.5251643719045109, 'gamma': 3.094507417623744, 'output_chunk_length': 7}. Best is trial 17 with value: 1239.0899658203125.
# [I 2024-09-12 08:33:19,158] Trial 25 finished with value: 1251.372314453125 and parameters: {'max_depth': 11, 'learning_rate': 0.015212127116089217, 'n_estimators': 175, 'input_chunk_length': 43, 'min_child_weight': 5.003594098139777, 'subsample': 0.8784299331253123, 'colsample_bytree': 0.7700779682030782, 'gamma': 3.211427560841016, 'output_chunk_length': 3}. Best is trial 17 with value: 1239.0899658203125.
# [I 2024-09-12 08:33:21,576] Trial 26 finished with value: 1250.889892578125 and parameters: {'max_depth': 6, 'learning_rate': 0.012645731891292653, 'n_estimators': 179, 'input_chunk_length': 39, 'min_child_weight': 7.599370446444824, 'subsample': 0.8910521696576537, 'colsample_bytree': 0.7834528312424122, 'gamma': 3.2232026173684782, 'output_chunk_length': 3}. Best is trial 17 with value: 1239.0899658203125.
# [I 2024-09-12 08:33:21,790] Trial 27 finished with value: 1251.0955810546875 and parameters: {'max_depth': 6, 'learning_rate': 0.013280242820225576, 'n_estimators': 177, 'input_chunk_length': 39, 'min_child_weight': 7.2915270581089064, 'subsample': 0.9153525927541861, 'colsample_bytree': 0.7730886110858755, 'gamma': 3.0751766927294018, 'output_chunk_length': 3}. Best is trial 17 with value: 1239.0899658203125.
# [I 2024-09-12 08:33:22,855] Trial 21 finished with value: 1261.725830078125 and parameters: {'max_depth': 11, 'learning_rate': 0.2862750794100426, 'n_estimators': 190, 'input_chunk_length': 50, 'min_child_weight': 5.701431615272399, 'subsample': 0.5532931648163895, 'colsample_bytree': 0.5006918118460896, 'gamma': 1.7048365495476894, 'output_chunk_length': 7}. Best is trial 17 with value: 1239.0899658203125.
# [I 2024-09-12 08:33:24,105] Trial 28 finished with value: 1262.802978515625 and parameters: {'max_depth': 5, 'learning_rate': 0.004384115155006996, 'n_estimators': 256, 'input_chunk_length': 77, 'min_child_weight': 7.263932785588754, 'subsample': 0.8909427701381147, 'colsample_bytree': 0.5879732822764837, 'gamma': 1.2303237786088885, 'output_chunk_length': 2}. Best is trial 17 with value: 1239.0899658203125.
# [I 2024-09-12 08:33:26,426] Trial 29 finished with value: 1261.4686279296875 and parameters: {'max_depth': 9, 'learning_rate': 0.0028556629126259064, 'n_estimators': 245, 'input_chunk_length': 74, 'min_child_weight': 6.9160875019855865, 'subsample': 0.9365919596501082, 'colsample_bytree': 0.9294198929998087, 'gamma': 1.0046778910164051, 'output_chunk_length': 2}. Best is trial 17 with value: 1239.0899658203125.
# [I 2024-09-12 08:33:26,825] Trial 30 finished with value: 1260.720458984375 and parameters: {'max_depth': 9, 'learning_rate': 0.0027131142886703, 'n_estimators': 257, 'input_chunk_length': 73, 'min_child_weight': 4.679321189976916, 'subsample': 0.8332158585206001, 'colsample_bytree': 0.9323090441395918, 'gamma': 1.189723501280974, 'output_chunk_length': 2}. Best is trial 17 with value: 1239.0899658203125.
# [I 2024-09-12 08:33:27,605] Trial 31 finished with value: 1261.5992431640625 and parameters: {'max_depth': 9, 'learning_rate': 0.0034283610070616963, 'n_estimators': 264, 'input_chunk_length': 74, 'min_child_weight': 4.7002136012733, 'subsample': 0.857991185859065, 'colsample_bytree': 0.5995287195131949, 'gamma': 1.2535689951835387, 'output_chunk_length': 2}. Best is trial 17 with value: 1239.0899658203125.
# [I 2024-09-12 08:33:28,577] Trial 32 finished with value: 1169.7471923828125 and parameters: {'max_depth': 9, 'learning_rate': 0.1276213250393067, 'n_estimators': 257, 'input_chunk_length': 11, 'min_child_weight': 8.559257957927564, 'subsample': 0.8459393511204318, 'colsample_bytree': 0.9287000136358516, 'gamma': 0.049916004619987575, 'output_chunk_length': 2}. Best is trial 32 with value: 1169.7471923828125.
# [I 2024-09-12 08:33:29,395] Trial 35 finished with value: 1239.7227783203125 and parameters: {'max_depth': 8, 'learning_rate': 0.009895552685627123, 'n_estimators': 103, 'input_chunk_length': 10, 'min_child_weight': 0.9909440649465687, 'subsample': 0.958117222515789, 'colsample_bytree': 0.7205474810330917, 'gamma': 2.0240235219292746, 'output_chunk_length': 1}. Best is trial 32 with value: 1169.7471923828125.
# [I 2024-09-12 08:33:29,708] Trial 33 finished with value: 1078.3009033203125 and parameters: {'max_depth': 8, 'learning_rate': 0.14005307526127475, 'n_estimators': 350, 'input_chunk_length': 11, 'min_child_weight': 8.681098070882076, 'subsample': 0.8485437762285548, 'colsample_bytree': 0.8488853293967111, 'gamma': 0.01205030024146625, 'output_chunk_length': 1}. Best is trial 33 with value: 1078.3009033203125.
# [I 2024-09-12 08:33:29,964] Trial 34 finished with value: 1244.001220703125 and parameters: {'max_depth': 8, 'learning_rate': 0.1302651228859347, 'n_estimators': 342, 'input_chunk_length': 22, 'min_child_weight': 8.747323571285932, 'subsample': 0.8223877183062596, 'colsample_bytree': 0.8445627256987916, 'gamma': 0.25467915811885744, 'output_chunk_length': 1}. Best is trial 33 with value: 1078.3009033203125.
# [I 2024-09-12 08:33:31,006] Trial 24 finished with value: 1254.445556640625 and parameters: {'max_depth': 6, 'learning_rate': 0.2669761393292716, 'n_estimators': 353, 'input_chunk_length': 47, 'min_child_weight': 7.449671401899694, 'subsample': 0.5805492930408948, 'colsample_bytree': 0.5888333065130105, 'gamma': 3.091061180711071, 'output_chunk_length': 7}. Best is trial 33 with value: 1078.3009033203125.
# [I 2024-09-12 08:33:31,992] Trial 36 finished with value: 1081.1368408203125 and parameters: {'max_depth': 8, 'learning_rate': 0.14426338028802543, 'n_estimators': 360, 'input_chunk_length': 26, 'min_child_weight': 8.562646926064305, 'subsample': 0.8043807071239009, 'colsample_bytree': 0.8451977699036437, 'gamma': 0.015645099672037643, 'output_chunk_length': 1}. Best is trial 33 with value: 1078.3009033203125.
# [I 2024-09-12 08:33:32,753] Trial 37 finished with value: 1137.3741455078125 and parameters: {'max_depth': 7, 'learning_rate': 0.14833402005787705, 'n_estimators': 346, 'input_chunk_length': 26, 'min_child_weight': 8.492012273644038, 'subsample': 0.813274441214526, 'colsample_bytree': 0.8508527170364282, 'gamma': 0.05521475847158985, 'output_chunk_length': 1}. Best is trial 33 with value: 1078.3009033203125.
# [I 2024-09-12 08:33:33,260] Trial 38 finished with value: 1070.0743408203125 and parameters: {'max_depth': 10, 'learning_rate': 0.1450999998996335, 'n_estimators': 363, 'input_chunk_length': 26, 'min_child_weight': 8.686208927007305, 'subsample': 0.809264537331411, 'colsample_bytree': 0.9983804551877781, 'gamma': 0.020494669565540524, 'output_chunk_length': 1}. Best is trial 38 with value: 1070.0743408203125.
# [I 2024-09-12 08:33:33,689] Trial 39 finished with value: 1250.4228515625 and parameters: {'max_depth': 10, 'learning_rate': 0.15238238860992667, 'n_estimators': 380, 'input_chunk_length': 31, 'min_child_weight': 8.480670416734483, 'subsample': 0.7812921592062536, 'colsample_bytree': 0.9987868442567014, 'gamma': 0.14852473097908686, 'output_chunk_length': 1}. Best is trial 38 with value: 1070.0743408203125.
# [I 2024-09-12 08:33:34,838] Trial 40 finished with value: 1111.2718505859375 and parameters: {'max_depth': 10, 'learning_rate': 0.06799983972778852, 'n_estimators': 378, 'input_chunk_length': 29, 'min_child_weight': 8.512956926667638, 'subsample': 0.8024638233655647, 'colsample_bytree': 0.9939468837410201, 'gamma': 0.02739450893464641, 'output_chunk_length': 1}. Best is trial 38 with value: 1070.0743408203125.
# [I 2024-09-12 08:33:36,192] Trial 41 finished with value: 1258.3743896484375 and parameters: {'max_depth': 10, 'learning_rate': 0.06864214234932355, 'n_estimators': 400, 'input_chunk_length': 102, 'min_child_weight': 9.042155112172225, 'subsample': 0.7810190922305658, 'colsample_bytree': 0.8416827729712334, 'gamma': 0.10460071705420727, 'output_chunk_length': 1}. Best is trial 38 with value: 1070.0743408203125.
# [I 2024-09-12 08:33:36,987] Trial 42 finished with value: 1198.282958984375 and parameters: {'max_depth': 10, 'learning_rate': 0.07294938019702323, 'n_estimators': 397, 'input_chunk_length': 102, 'min_child_weight': 8.966597402764867, 'subsample': 0.7825677372862753, 'colsample_bytree': 0.8388691453477628, 'gamma': 0.0608266506760235, 'output_chunk_length': 1}. Best is trial 38 with value: 1070.0743408203125.
# [I 2024-09-12 08:33:37,874] Trial 43 finished with value: 1068.683837890625 and parameters: {'max_depth': 13, 'learning_rate': 0.06508913078818325, 'n_estimators': 398, 'input_chunk_length': 89, 'min_child_weight': 9.419322068606467, 'subsample': 0.7942807040593862, 'colsample_bytree': 0.84366599510953, 'gamma': 0.0020675356498820203, 'output_chunk_length': 1}. Best is trial 43 with value: 1068.683837890625.
# [I 2024-09-12 08:33:38,077] Trial 44 finished with value: 1265.2703857421875 and parameters: {'max_depth': 13, 'learning_rate': 0.0678842316848698, 'n_estimators': 434, 'input_chunk_length': 102, 'min_child_weight': 8.014649420577392, 'subsample': 0.7670026722259433, 'colsample_bytree': 0.8459045805921455, 'gamma': 0.5771517310329133, 'output_chunk_length': 1}. Best is trial 43 with value: 1068.683837890625.
# [I 2024-09-12 08:33:39,032] Trial 45 finished with value: 1260.1026611328125 and parameters: {'max_depth': 13, 'learning_rate': 0.07308407675951725, 'n_estimators': 420, 'input_chunk_length': 106, 'min_child_weight': 9.332204785872603, 'subsample': 0.7710981536981113, 'colsample_bytree': 0.8324127474215115, 'gamma': 0.6381389634134926, 'output_chunk_length': 1}. Best is trial 43 with value: 1068.683837890625.
# [I 2024-09-12 08:33:40,686] Trial 46 finished with value: 1243.0809326171875 and parameters: {'max_depth': 13, 'learning_rate': 0.061429011812289096, 'n_estimators': 447, 'input_chunk_length': 26, 'min_child_weight': 9.423375461702676, 'subsample': 0.72547816459924, 'colsample_bytree': 0.9570038831763599, 'gamma': 0.5491116155753814, 'output_chunk_length': 1}. Best is trial 43 with value: 1068.683837890625.
# [I 2024-09-12 08:33:41,504] Trial 47 finished with value: 1259.11962890625 and parameters: {'max_depth': 13, 'learning_rate': 0.18020835900942428, 'n_estimators': 448, 'input_chunk_length': 62, 'min_child_weight': 9.658871274703397, 'subsample': 0.7252416013168779, 'colsample_bytree': 0.8983228343835723, 'gamma': 0.5754392870138723, 'output_chunk_length': 1}. Best is trial 43 with value: 1068.683837890625.
# [I 2024-09-12 08:33:42,700] Trial 48 finished with value: 1310.3370361328125 and parameters: {'max_depth': 14, 'learning_rate': 0.0946806019316556, 'n_estimators': 453, 'input_chunk_length': 191, 'min_child_weight': 9.592795635179954, 'subsample': 0.7308437212833193, 'colsample_bytree': 0.9084734162747903, 'gamma': 0.5728375226718218, 'output_chunk_length': 1}. Best is trial 43 with value: 1068.683837890625.
# [I 2024-09-12 08:33:42,805] Trial 49 finished with value: 1265.8585205078125 and parameters: {'max_depth': 15, 'learning_rate': 0.04644388624463485, 'n_estimators': 463, 'input_chunk_length': 89, 'min_child_weight': 9.485280594319194, 'subsample': 0.7287290641251875, 'colsample_bytree': 0.9030930623010338, 'gamma': 0.5259683763332884, 'output_chunk_length': 1}. Best is trial 43 with value: 1068.683837890625.
# [I 2024-09-12 08:33:46,610] Trial 50 finished with value: 1255.322021484375 and parameters: {'max_depth': 14, 'learning_rate': 0.043015584491600846, 'n_estimators': 441, 'input_chunk_length': 64, 'min_child_weight': 9.911083075262159, 'subsample': 0.7276858203461097, 'colsample_bytree': 0.9505776332751477, 'gamma': 0.41618841922399447, 'output_chunk_length': 2}. Best is trial 43 with value: 1068.683837890625.
# [I 2024-09-12 08:33:48,446] Trial 51 finished with value: 1255.087158203125 and parameters: {'max_depth': 15, 'learning_rate': 0.038919215773192246, 'n_estimators': 475, 'input_chunk_length': 66, 'min_child_weight': 9.995802375240043, 'subsample': 0.8053385330184227, 'colsample_bytree': 0.9053291448875534, 'gamma': 0.39947397639794335, 'output_chunk_length': 2}. Best is trial 43 with value: 1068.683837890625.
# [I 2024-09-12 08:33:55,028] Trial 56 finished with value: 1269.6229248046875 and parameters: {'max_depth': 7, 'learning_rate': 0.11446375015957043, 'n_estimators': 371, 'input_chunk_length': 122, 'min_child_weight': 8.282981163606452, 'subsample': 0.8163312907012756, 'colsample_bytree': 0.808890200625254, 'gamma': 0.8586426212262023, 'output_chunk_length': 2}. Best is trial 43 with value: 1068.683837890625.
# [I 2024-09-12 08:33:59,312] Trial 52 finished with value: 1265.348388671875 and parameters: {'max_depth': 14, 'learning_rate': 0.03665577586860147, 'n_estimators': 487, 'input_chunk_length': 118, 'min_child_weight': 8.063839897586792, 'subsample': 0.8065792328914313, 'colsample_bytree': 0.9542340447611349, 'gamma': 4.916941953705409, 'output_chunk_length': 5}. Best is trial 43 with value: 1068.683837890625.
# [I 2024-09-12 08:33:59,986] Trial 55 finished with value: 1247.584716796875 and parameters: {'max_depth': 7, 'learning_rate': 0.02899937951436162, 'n_estimators': 369, 'input_chunk_length': 33, 'min_child_weight': 8.228273246026337, 'subsample': 0.799771546598548, 'colsample_bytree': 0.8707342586507053, 'gamma': 4.825784491907953, 'output_chunk_length': 5}. Best is trial 43 with value: 1068.683837890625.
# [I 2024-09-12 08:34:00,263] Trial 53 finished with value: 1253.532958984375 and parameters: {'max_depth': 12, 'learning_rate': 0.04601835649723339, 'n_estimators': 492, 'input_chunk_length': 64, 'min_child_weight': 9.945108235950697, 'subsample': 0.8082595178475069, 'colsample_bytree': 0.8163551798506388, 'gamma': 0.3211989153392562, 'output_chunk_length': 5}. Best is trial 43 with value: 1068.683837890625.
# [I 2024-09-12 08:34:01,111] Trial 54 finished with value: 1266.7415771484375 and parameters: {'max_depth': 12, 'learning_rate': 0.029919022859797927, 'n_estimators': 495, 'input_chunk_length': 128, 'min_child_weight': 9.915010543730636, 'subsample': 0.8117218452619321, 'colsample_bytree': 0.9565653555105492, 'gamma': 0.34633383221325265, 'output_chunk_length': 5}. Best is trial 43 with value: 1068.683837890625.
# [I 2024-09-12 08:34:02,724] Trial 58 finished with value: 1248.639892578125 and parameters: {'max_depth': 4, 'learning_rate': 0.02606818088088738, 'n_estimators': 310, 'input_chunk_length': 33, 'min_child_weight': 6.887635131890997, 'subsample': 0.6847718646485073, 'colsample_bytree': 0.8708479265694289, 'gamma': 0.3074858381255599, 'output_chunk_length': 1}. Best is trial 43 with value: 1068.683837890625.
# [I 2024-09-12 08:34:03,307] Trial 59 finished with value: 1243.9365234375 and parameters: {'max_depth': 12, 'learning_rate': 0.17774595107810945, 'n_estimators': 323, 'input_chunk_length': 23, 'min_child_weight': 6.597451340458739, 'subsample': 0.6816752275879034, 'colsample_bytree': 0.9996095530682095, 'gamma': 0.2941375374174746, 'output_chunk_length': 1}. Best is trial 43 with value: 1068.683837890625.
# [I 2024-09-12 08:34:03,603] Trial 60 finished with value: 1066.7344970703125 and parameters: {'max_depth': 12, 'learning_rate': 0.2031970176457003, 'n_estimators': 320, 'input_chunk_length': 22, 'min_child_weight': 6.599475029197225, 'subsample': 0.7583072720098462, 'colsample_bytree': 0.9888805000875083, 'gamma': 0.00896679568558189, 'output_chunk_length': 1}. Best is trial 60 with value: 1066.7344970703125.
# [I 2024-09-12 08:34:04,298] Trial 61 finished with value: 1238.695068359375 and parameters: {'max_depth': 5, 'learning_rate': 0.2020418392142268, 'n_estimators': 322, 'input_chunk_length': 27, 'min_child_weight': 6.677900047812857, 'subsample': 0.7570543294497052, 'colsample_bytree': 0.9861599645480695, 'gamma': 0.7711084326362014, 'output_chunk_length': 1}. Best is trial 60 with value: 1066.7344970703125.
# [I 2024-09-12 08:34:06,135] Trial 62 finished with value: 1239.7935791015625 and parameters: {'max_depth': 12, 'learning_rate': 0.1905499903054481, 'n_estimators': 333, 'input_chunk_length': 25, 'min_child_weight': 8.954041153523633, 'subsample': 0.75635329736194, 'colsample_bytree': 0.7441486032194569, 'gamma': 0.8758196860579442, 'output_chunk_length': 1}. Best is trial 60 with value: 1066.7344970703125.
# [I 2024-09-12 08:34:06,797] Trial 57 finished with value: 1248.98486328125 and parameters: {'max_depth': 12, 'learning_rate': 0.1957806543224504, 'n_estimators': 322, 'input_chunk_length': 33, 'min_child_weight': 7.921007884254539, 'subsample': 0.6874502722525873, 'colsample_bytree': 0.8723335097453091, 'gamma': 0.30416624515169277, 'output_chunk_length': 5}. Best is trial 60 with value: 1066.7344970703125.
# [I 2024-09-12 08:34:07,997] Trial 65 finished with value: 1124.135498046875 and parameters: {'max_depth': 12, 'learning_rate': 0.15346769183682427, 'n_estimators': 340, 'input_chunk_length': 17, 'min_child_weight': 7.802044067428949, 'subsample': 0.8421963095103229, 'colsample_bytree': 0.9761751394351587, 'gamma': 0.04099487372030052, 'output_chunk_length': 1}. Best is trial 60 with value: 1066.7344970703125.
# [I 2024-09-12 08:34:09,158] Trial 64 finished with value: 1247.8489990234375 and parameters: {'max_depth': 12, 'learning_rate': 0.1978033080363436, 'n_estimators': 295, 'input_chunk_length': 40, 'min_child_weight': 7.838311213950278, 'subsample': 0.750636519695486, 'colsample_bytree': 0.9834240851451022, 'gamma': 0.9037764419294229, 'output_chunk_length': 2}. Best is trial 60 with value: 1066.7344970703125.
# [I 2024-09-12 08:34:09,676] Trial 63 finished with value: 1302.515380859375 and parameters: {'max_depth': 7, 'learning_rate': 0.22321443939780294, 'n_estimators': 333, 'input_chunk_length': 169, 'min_child_weight': 9.105252942164515, 'subsample': 0.838730383060026, 'colsample_bytree': 0.9821076748189077, 'gamma': 0.7921686038022888, 'output_chunk_length': 2}. Best is trial 60 with value: 1066.7344970703125.
# [I 2024-09-12 08:34:10,458] Trial 67 finished with value: 1222.3970947265625 and parameters: {'max_depth': 7, 'learning_rate': 0.14858881928132606, 'n_estimators': 293, 'input_chunk_length': 170, 'min_child_weight': 7.660542301243295, 'subsample': 0.8496751804055716, 'colsample_bytree': 0.9774441986542648, 'gamma': 0.039423551927844976, 'output_chunk_length': 1}. Best is trial 60 with value: 1066.7344970703125.
# [I 2024-09-12 08:34:11,613] Trial 66 finished with value: 1139.940185546875 and parameters: {'max_depth': 7, 'learning_rate': 0.15129702167746104, 'n_estimators': 291, 'input_chunk_length': 40, 'min_child_weight': 7.725769594205883, 'subsample': 0.8400458779131073, 'colsample_bytree': 0.9836626727772099, 'gamma': 0.016052464909559562, 'output_chunk_length': 2}. Best is trial 60 with value: 1066.7344970703125.
# [I 2024-09-12 08:34:12,798] Trial 69 finished with value: 1107.4918212890625 and parameters: {'max_depth': 10, 'learning_rate': 0.1070274621645481, 'n_estimators': 384, 'input_chunk_length': 16, 'min_child_weight': 9.162373082894089, 'subsample': 0.8390314015567848, 'colsample_bytree': 0.9722450307478243, 'gamma': 0.03699638925904814, 'output_chunk_length': 1}. Best is trial 60 with value: 1066.7344970703125.
# [I 2024-09-12 08:34:13,134] Trial 68 finished with value: 1143.25146484375 and parameters: {'max_depth': 10, 'learning_rate': 0.10011073920038366, 'n_estimators': 288, 'input_chunk_length': 18, 'min_child_weight': 7.719074873071434, 'subsample': 0.8439247433338999, 'colsample_bytree': 0.9796049342296468, 'gamma': 0.024040145501907896, 'output_chunk_length': 2}. Best is trial 60 with value: 1066.7344970703125.
# [I 2024-09-12 08:34:13,284] Trial 70 finished with value: 1240.354248046875 and parameters: {'max_depth': 10, 'learning_rate': 0.09172127925514745, 'n_estimators': 386, 'input_chunk_length': 17, 'min_child_weight': 8.641168578905292, 'subsample': 0.8476208612719478, 'colsample_bytree': 0.9381364464217331, 'gamma': 0.1863142468898682, 'output_chunk_length': 1}. Best is trial 60 with value: 1066.7344970703125.
# [I 2024-09-12 08:34:13,918] Trial 71 finished with value: 1240.46923828125 and parameters: {'max_depth': 11, 'learning_rate': 0.10953382916237853, 'n_estimators': 359, 'input_chunk_length': 17, 'min_child_weight': 8.737999680555548, 'subsample': 0.8705937227018817, 'colsample_bytree': 0.9339734582114643, 'gamma': 1.4103992172528332, 'output_chunk_length': 1}. Best is trial 60 with value: 1066.7344970703125.
# [I 2024-09-12 08:34:16,541] Trial 74 finished with value: 1254.033447265625 and parameters: {'max_depth': 10, 'learning_rate': 0.05763536132386101, 'n_estimators': 362, 'input_chunk_length': 46, 'min_child_weight': 2.885081618930762, 'subsample': 0.8710841075853569, 'colsample_bytree': 0.9410574007421073, 'gamma': 0.19813689434143883, 'output_chunk_length': 1}. Best is trial 60 with value: 1066.7344970703125.
# [I 2024-09-12 08:34:16,679] Trial 75 finished with value: 1239.4091796875 and parameters: {'max_depth': 11, 'learning_rate': 0.1314637963717723, 'n_estimators': 359, 'input_chunk_length': 15, 'min_child_weight': 9.331366803335108, 'subsample': 0.867110512843885, 'colsample_bytree': 0.9235216873496382, 'gamma': 0.22473585950206804, 'output_chunk_length': 1}. Best is trial 60 with value: 1066.7344970703125.
# [I 2024-09-12 08:34:17,682] Trial 76 finished with value: 1252.7557373046875 and parameters: {'max_depth': 11, 'learning_rate': 0.08277667834867188, 'n_estimators': 417, 'input_chunk_length': 45, 'min_child_weight': 9.21408219859688, 'subsample': 0.8275486848640439, 'colsample_bytree': 0.9667426777861169, 'gamma': 0.4154818885846925, 'output_chunk_length': 1}. Best is trial 60 with value: 1066.7344970703125.
# [I 2024-09-12 08:34:20,309] Trial 77 finished with value: 1239.646240234375 and parameters: {'max_depth': 11, 'learning_rate': 0.08094674186137746, 'n_estimators': 415, 'input_chunk_length': 11, 'min_child_weight': 9.143535269816876, 'subsample': 0.8270517260758085, 'colsample_bytree': 0.9643090410320153, 'gamma': 0.45679479001329437, 'output_chunk_length': 1}. Best is trial 60 with value: 1066.7344970703125.
# [I 2024-09-12 08:34:20,447] Trial 78 finished with value: 1240.494873046875 and parameters: {'max_depth': 8, 'learning_rate': 0.08099758895302367, 'n_estimators': 411, 'input_chunk_length': 10, 'min_child_weight': 9.141525042529425, 'subsample': 0.8299942478855853, 'colsample_bytree': 0.6929918496583855, 'gamma': 0.450595703930451, 'output_chunk_length': 1}. Best is trial 60 with value: 1066.7344970703125.
# [I 2024-09-12 08:34:21,719] Trial 72 finished with value: 1242.1865234375 and parameters: {'max_depth': 11, 'learning_rate': 0.10522521278471665, 'n_estimators': 361, 'input_chunk_length': 17, 'min_child_weight': 2.8187298807025796, 'subsample': 0.8680983909793117, 'colsample_bytree': 0.9401611167671947, 'gamma': 1.383193972567357, 'output_chunk_length': 4}. Best is trial 60 with value: 1066.7344970703125.
# [I 2024-09-12 08:34:23,513] Trial 73 finished with value: 1256.6790771484375 and parameters: {'max_depth': 10, 'learning_rate': 0.10482566942670275, 'n_estimators': 385, 'input_chunk_length': 48, 'min_child_weight': 8.69769240262762, 'subsample': 0.8671749842882139, 'colsample_bytree': 0.6376465941532552, 'gamma': 0.206991224864577, 'output_chunk_length': 4}. Best is trial 60 with value: 1066.7344970703125.
# [I 2024-09-12 08:34:23,859] Trial 80 finished with value: 1252.3450927734375 and parameters: {'max_depth': 9, 'learning_rate': 0.12285147047118326, 'n_estimators': 383, 'input_chunk_length': 37, 'min_child_weight': 8.373093757147522, 'subsample': 0.771675035345732, 'colsample_bytree': 0.9174937861790783, 'gamma': 0.20063922153949848, 'output_chunk_length': 1}. Best is trial 60 with value: 1066.7344970703125.
# [I 2024-09-12 08:34:27,359] Trial 83 finished with value: 1249.7752685546875 and parameters: {'max_depth': 9, 'learning_rate': 0.2579577946911837, 'n_estimators': 398, 'input_chunk_length': 30, 'min_child_weight': 7.150453476859666, 'subsample': 0.8935811683960364, 'colsample_bytree': 0.7934145413095476, 'gamma': 0.6414326338392133, 'output_chunk_length': 1}. Best is trial 60 with value: 1066.7344970703125.
# [I 2024-09-12 08:34:27,942] Trial 82 finished with value: 1251.172119140625 and parameters: {'max_depth': 9, 'learning_rate': 0.2500645105236858, 'n_estimators': 380, 'input_chunk_length': 37, 'min_child_weight': 8.417814378658022, 'subsample': 0.9068059634525836, 'colsample_bytree': 0.7941050912526346, 'gamma': 0.6736522207266902, 'output_chunk_length': 2}. Best is trial 60 with value: 1066.7344970703125.
# [I 2024-09-12 08:34:28,671] Trial 79 finished with value: 1243.626708984375 and parameters: {'max_depth': 9, 'learning_rate': 0.12114293774915012, 'n_estimators': 388, 'input_chunk_length': 21, 'min_child_weight': 8.326580321420993, 'subsample': 0.9040232785176715, 'colsample_bytree': 0.9676221477272011, 'gamma': 0.6661413290583678, 'output_chunk_length': 4}. Best is trial 60 with value: 1066.7344970703125.
# [I 2024-09-12 08:34:29,793] Trial 84 finished with value: 1264.1185302734375 and parameters: {'max_depth': 9, 'learning_rate': 0.24406056870741, 'n_estimators': 340, 'input_chunk_length': 88, 'min_child_weight': 7.272075583019211, 'subsample': 0.7877812812380346, 'colsample_bytree': 0.7878944629450356, 'gamma': 0.6981854297757016, 'output_chunk_length': 2}. Best is trial 60 with value: 1066.7344970703125.
# [I 2024-09-12 08:34:30,862] Trial 85 finished with value: 1069.7357177734375 and parameters: {'max_depth': 8, 'learning_rate': 0.16251217620966507, 'n_estimators': 344, 'input_chunk_length': 22, 'min_child_weight': 8.257304921542273, 'subsample': 0.7908342440230884, 'colsample_bytree': 0.8555303974067753, 'gamma': 0.02056226562938207, 'output_chunk_length': 1}. Best is trial 60 with value: 1066.7344970703125.
# [I 2024-09-12 08:34:31,344] Trial 81 finished with value: 1247.4210205078125 and parameters: {'max_depth': 9, 'learning_rate': 0.24000412793347456, 'n_estimators': 385, 'input_chunk_length': 21, 'min_child_weight': 8.314759907679534, 'subsample': 0.7902142053279, 'colsample_bytree': 0.9945118134399971, 'gamma': 0.7015059609823951, 'output_chunk_length': 4}. Best is trial 60 with value: 1066.7344970703125.
# [I 2024-09-12 08:34:31,554] Trial 86 finished with value: 1064.0638427734375 and parameters: {'max_depth': 8, 'learning_rate': 0.15731470449710513, 'n_estimators': 344, 'input_chunk_length': 22, 'min_child_weight': 8.607451038094148, 'subsample': 0.7922859575956563, 'colsample_bytree': 0.8603020035936848, 'gamma': 0.005848687347695322, 'output_chunk_length': 1}. Best is trial 86 with value: 1064.0638427734375.
# [I 2024-09-12 08:34:32,367] Trial 87 finished with value: 1072.9703369140625 and parameters: {'max_depth': 8, 'learning_rate': 0.05596036207848512, 'n_estimators': 347, 'input_chunk_length': 27, 'min_child_weight': 8.858696461200859, 'subsample': 0.7925014198008095, 'colsample_bytree': 0.893275477862352, 'gamma': 0.012120096698520221, 'output_chunk_length': 1}. Best is trial 86 with value: 1064.0638427734375.
# [I 2024-09-12 08:34:33,269] Trial 88 finished with value: 1206.84423828125 and parameters: {'max_depth': 8, 'learning_rate': 0.15829641700216165, 'n_estimators': 345, 'input_chunk_length': 26, 'min_child_weight': 8.891271422383351, 'subsample': 0.793518083834113, 'colsample_bytree': 0.8542145279808806, 'gamma': 0.09623908799736539, 'output_chunk_length': 1}. Best is trial 86 with value: 1064.0638427734375.
# [I 2024-09-12 08:34:34,636] Trial 89 finished with value: 1051.984619140625 and parameters: {'max_depth': 8, 'learning_rate': 0.1657583318716394, 'n_estimators': 348, 'input_chunk_length': 22, 'min_child_weight': 8.915985331342739, 'subsample': 0.7970112934742065, 'colsample_bytree': 0.8882805120543102, 'gamma': 0.004263090195781603, 'output_chunk_length': 1}. Best is trial 89 with value: 1051.984619140625.
# [I 2024-09-12 08:34:35,138] Trial 90 finished with value: 1223.98046875 and parameters: {'max_depth': 8, 'learning_rate': 0.16226936983564744, 'n_estimators': 372, 'input_chunk_length': 29, 'min_child_weight': 8.91508936670194, 'subsample': 0.7908131315887826, 'colsample_bytree': 0.8822893888057866, 'gamma': 0.12143992286778181, 'output_chunk_length': 1}. Best is trial 89 with value: 1051.984619140625.
# [I 2024-09-12 08:34:35,720] Trial 92 finished with value: 1287.4290771484375 and parameters: {'max_depth': 8, 'learning_rate': 0.0559587147943961, 'n_estimators': 277, 'input_chunk_length': 150, 'min_child_weight': 8.793003853175456, 'subsample': 0.7702719910189586, 'colsample_bytree': 0.856681816791505, 'gamma': 2.7385137760654668, 'output_chunk_length': 1}. Best is trial 89 with value: 1051.984619140625.
# [I 2024-09-12 08:34:37,721] Trial 94 finished with value: 1250.5897216796875 and parameters: {'max_depth': 8, 'learning_rate': 0.22143601320273146, 'n_estimators': 276, 'input_chunk_length': 35, 'min_child_weight': 9.650330702960519, 'subsample': 0.7385346416005859, 'colsample_bytree': 0.8879232928949956, 'gamma': 2.7342599522531583, 'output_chunk_length': 1}. Best is trial 89 with value: 1051.984619140625.
# [I 2024-09-12 08:34:38,353] Trial 95 finished with value: 1239.991455078125 and parameters: {'max_depth': 8, 'learning_rate': 0.053827902030301675, 'n_estimators': 309, 'input_chunk_length': 13, 'min_child_weight': 9.670408307517926, 'subsample': 0.768445602506437, 'colsample_bytree': 0.8630180807237356, 'gamma': 2.735457351497466, 'output_chunk_length': 1}. Best is trial 89 with value: 1051.984619140625.
# [I 2024-09-12 08:34:40,697] Trial 97 finished with value: 1241.5679931640625 and parameters: {'max_depth': 8, 'learning_rate': 0.13074321673328623, 'n_estimators': 309, 'input_chunk_length': 14, 'min_child_weight': 8.103183472604288, 'subsample': 0.7106109996683819, 'colsample_bytree': 0.8154975779187492, 'gamma': 0.15492566694134083, 'output_chunk_length': 1}. Best is trial 89 with value: 1051.984619140625.
# [I 2024-09-12 08:34:41,578] Trial 98 finished with value: 1242.150390625 and parameters: {'max_depth': 8, 'learning_rate': 0.17256439500427798, 'n_estimators': 351, 'input_chunk_length': 20, 'min_child_weight': 8.076927149015056, 'subsample': 0.8207351890287377, 'colsample_bytree': 0.8227108121632952, 'gamma': 0.1552483237245123, 'output_chunk_length': 1}. Best is trial 89 with value: 1051.984619140625.
# [I 2024-09-12 08:34:43,905] Trial 99 finished with value: 1243.6429443359375 and parameters: {'max_depth': 8, 'learning_rate': 0.13975591900525694, 'n_estimators': 351, 'input_chunk_length': 23, 'min_child_weight': 9.304725668482272, 'subsample': 0.8181592007391248, 'colsample_bytree': 0.8294867460204463, 'gamma': 0.31174352956504137, 'output_chunk_length': 1}. Best is trial 89 with value: 1051.984619140625.
# [I 2024-09-12 08:34:44,563] Trial 91 finished with value: 1117.689697265625 and parameters: {'max_depth': 8, 'learning_rate': 0.001758389932307738, 'n_estimators': 350, 'input_chunk_length': 29, 'min_child_weight': 8.825722564620058, 'subsample': 0.7957282426466464, 'colsample_bytree': 0.8265914609087959, 'gamma': 0.00025126060612409157, 'output_chunk_length': 1}. Best is trial 89 with value: 1051.984619140625.
# [I 2024-09-12 08:34:44,694] Trial 100 finished with value: 1239.951904296875 and parameters: {'max_depth': 7, 'learning_rate': 0.1345098640628355, 'n_estimators': 331, 'input_chunk_length': 21, 'min_child_weight': 9.43733307280722, 'subsample': 0.7797276750791119, 'colsample_bytree': 0.8871394397223487, 'gamma': 3.5718656416316263, 'output_chunk_length': 1}. Best is trial 89 with value: 1051.984619140625.
# [I 2024-09-12 08:34:45,615] Trial 93 finished with value: 1238.7559814453125 and parameters: {'max_depth': 8, 'learning_rate': 0.0018006008670563276, 'n_estimators': 302, 'input_chunk_length': 13, 'min_child_weight': 8.766318868991531, 'subsample': 0.7652600456692501, 'colsample_bytree': 0.8892597621162065, 'gamma': 0.13475378254543602, 'output_chunk_length': 6}. Best is trial 89 with value: 1051.984619140625.
# [I 2024-09-12 08:34:46,080] Trial 96 finished with value: 1117.1107177734375 and parameters: {'max_depth': 8, 'learning_rate': 0.0017917655912204906, 'n_estimators': 352, 'input_chunk_length': 13, 'min_child_weight': 9.619222305976228, 'subsample': 0.7409213361983207, 'colsample_bytree': 0.8227798559371929, 'gamma': 0.0008671969873290178, 'output_chunk_length': 1}. Best is trial 89 with value: 1051.984619140625.
# [I 2024-09-12 08:34:49,436] Trial 101 finished with value: 1247.0325927734375 and parameters: {'max_depth': 6, 'learning_rate': 0.17040175785568767, 'n_estimators': 331, 'input_chunk_length': 28, 'min_child_weight': 9.506988464037939, 'subsample': 0.7799193492311891, 'colsample_bytree': 0.9134993069784352, 'gamma': 0.4158469437523679, 'output_chunk_length': 2}. Best is trial 89 with value: 1051.984619140625.
# [I 2024-09-12 08:34:49,795] Trial 105 finished with value: 1248.966552734375 and parameters: {'max_depth': 10, 'learning_rate': 0.17561681259529052, 'n_estimators': 373, 'input_chunk_length': 30, 'min_child_weight': 8.509669728115783, 'subsample': 0.8027514868823734, 'colsample_bytree': 0.9177779579676086, 'gamma': 0.47884745660541533, 'output_chunk_length': 1}. Best is trial 89 with value: 1051.984619140625.
# [I 2024-09-12 08:34:50,218] Trial 102 finished with value: 1244.2928466796875 and parameters: {'max_depth': 7, 'learning_rate': 0.0010027160158212992, 'n_estimators': 330, 'input_chunk_length': 23, 'min_child_weight': 7.461490963874064, 'subsample': 0.7783350855564133, 'colsample_bytree': 0.8938818457434439, 'gamma': 4.023841770111285, 'output_chunk_length': 2}. Best is trial 89 with value: 1051.984619140625.
# [I 2024-09-12 08:34:51,762] Trial 103 finished with value: 1263.2249755859375 and parameters: {'max_depth': 7, 'learning_rate': 0.019764376683013615, 'n_estimators': 427, 'input_chunk_length': 96, 'min_child_weight': 8.547164632133917, 'subsample': 0.7479547748272701, 'colsample_bytree': 0.8948026602091319, 'gamma': 0.42628113427437453, 'output_chunk_length': 2}. Best is trial 89 with value: 1051.984619140625.
# [I 2024-09-12 08:34:52,537] Trial 104 finished with value: 1253.592041015625 and parameters: {'max_depth': 6, 'learning_rate': 0.2150132777472022, 'n_estimators': 432, 'input_chunk_length': 42, 'min_child_weight': 7.454548042321187, 'subsample': 0.7480397494207539, 'colsample_bytree': 0.9155866876575286, 'gamma': 0.4324996238262968, 'output_chunk_length': 2}. Best is trial 89 with value: 1051.984619140625.
# [I 2024-09-12 08:34:53,112] Trial 106 finished with value: 1243.2347412109375 and parameters: {'max_depth': 10, 'learning_rate': 0.11383102364025119, 'n_estimators': 372, 'input_chunk_length': 24, 'min_child_weight': 8.643115705543156, 'subsample': 0.8012502729711536, 'colsample_bytree': 0.897306269208919, 'gamma': 0.29495149693490225, 'output_chunk_length': 1}. Best is trial 89 with value: 1051.984619140625.
# [I 2024-09-12 08:34:53,553] Trial 107 finished with value: 1247.8660888671875 and parameters: {'max_depth': 14, 'learning_rate': 0.06333402432306653, 'n_estimators': 402, 'input_chunk_length': 42, 'min_child_weight': 7.480313670337537, 'subsample': 0.8556636110655683, 'colsample_bytree': 0.839069650316586, 'gamma': 0.2737286415356716, 'output_chunk_length': 1}. Best is trial 89 with value: 1051.984619140625.
# [I 2024-09-12 08:34:54,128] Trial 108 finished with value: 1247.2027587890625 and parameters: {'max_depth': 9, 'learning_rate': 0.29791711879587246, 'n_estimators': 402, 'input_chunk_length': 42, 'min_child_weight': 4.03604564453402, 'subsample': 0.8546473409879831, 'colsample_bytree': 0.8376715528355935, 'gamma': 0.2565136987172204, 'output_chunk_length': 1}. Best is trial 89 with value: 1051.984619140625.
# [I 2024-09-12 08:34:55,352] Trial 109 finished with value: 1263.8985595703125 and parameters: {'max_depth': 14, 'learning_rate': 0.2951874251184438, 'n_estimators': 366, 'input_chunk_length': 52, 'min_child_weight': 9.058270377672825, 'subsample': 0.8021633004696479, 'colsample_bytree': 0.8615287991488928, 'gamma': 0.2916038076028404, 'output_chunk_length': 1}. Best is trial 89 with value: 1051.984619140625.
# [I 2024-09-12 08:34:56,317] Trial 110 finished with value: 1248.2845458984375 and parameters: {'max_depth': 14, 'learning_rate': 0.09185494477792874, 'n_estimators': 401, 'input_chunk_length': 35, 'min_child_weight': 5.444848090738117, 'subsample': 0.8111988120463781, 'colsample_bytree': 0.9928768093726299, 'gamma': 0.2921412430506369, 'output_chunk_length': 1}. Best is trial 89 with value: 1051.984619140625.
# [I 2024-09-12 08:34:56,812] Trial 111 finished with value: 1247.336181640625 and parameters: {'max_depth': 14, 'learning_rate': 0.08830875542513349, 'n_estimators': 403, 'input_chunk_length': 34, 'min_child_weight': 9.019051180553337, 'subsample': 0.80935785914257, 'colsample_bytree': 0.8599820877982601, 'gamma': 0.26928228216280786, 'output_chunk_length': 1}. Best is trial 89 with value: 1051.984619140625.
# [I 2024-09-12 08:34:57,172] Trial 112 finished with value: 1224.1636962890625 and parameters: {'max_depth': 9, 'learning_rate': 0.09415934138383797, 'n_estimators': 395, 'input_chunk_length': 34, 'min_child_weight': 5.348190788413086, 'subsample': 0.8130582294915094, 'colsample_bytree': 0.8788855428733537, 'gamma': 0.11061086391140637, 'output_chunk_length': 1}. Best is trial 89 with value: 1051.984619140625.
# [I 2024-09-12 08:34:57,541] Trial 113 finished with value: 1229.1795654296875 and parameters: {'max_depth': 9, 'learning_rate': 0.09255524613690849, 'n_estimators': 364, 'input_chunk_length': 36, 'min_child_weight': 9.045568068905293, 'subsample': 0.8093629597377735, 'colsample_bytree': 0.9920352027962595, 'gamma': 0.10609569413255875, 'output_chunk_length': 1}. Best is trial 89 with value: 1051.984619140625.
# [I 2024-09-12 08:34:58,420] Trial 114 finished with value: 1196.46826171875 and parameters: {'max_depth': 13, 'learning_rate': 0.097826774037811, 'n_estimators': 315, 'input_chunk_length': 34, 'min_child_weight': 5.314814608825581, 'subsample': 0.8125706136443895, 'colsample_bytree': 0.8743581800110518, 'gamma': 0.0967221779562644, 'output_chunk_length': 1}. Best is trial 89 with value: 1051.984619140625.
# [I 2024-09-12 08:34:59,912] Trial 116 finished with value: 1212.338623046875 and parameters: {'max_depth': 9, 'learning_rate': 0.0036910662092804413, 'n_estimators': 318, 'input_chunk_length': 10, 'min_child_weight': 8.169739638249853, 'subsample': 0.7146773649617392, 'colsample_bytree': 0.875237024469363, 'gamma': 0.08772057336038984, 'output_chunk_length': 1}. Best is trial 89 with value: 1051.984619140625.
# ...
# [I 2024-09-12 08:56:28,987] Trial 264 finished with value: 1349.293212890625 and parameters: {'max_depth': 4, 'learning_rate': 0.2139480329559417, 'n_estimators': 319, 'input_chunk_length': 13, 'min_child_weight': 0.5754783840196006, 'subsample': 0.8155600696920892, 'colsample_bytree': 0.9418767920986302, 'gamma': 4.022518113500082, 'output_chunk_length': 7}. Best is trial 248 with value: 1345.572021484375.
# [I 2024-09-12 08:56:34,102] Trial 265 finished with value: 1359.2596435546875 and parameters: {'max_depth': 4, 'learning_rate': 0.20221590318339208, 'n_estimators': 319, 'input_chunk_length': 24, 'min_child_weight': 0.5938691989496225, 'subsample': 0.8136334495338471, 'colsample_bytree': 0.9392440801572037, 'gamma': 4.407782177512227, 'output_chunk_length': 7}. Best is trial 248 with value: 1345.572021484375.
# [I 2024-09-12 08:56:35,251] Trial 268 finished with value: 1356.1673583984375 and parameters: {'max_depth': 7, 'learning_rate': 0.14969883020431562, 'n_estimators': 307, 'input_chunk_length': 22, 'min_child_weight': 0.590835180065829, 'subsample': 0.8121880552154139, 'colsample_bytree': 0.935064918874801, 'gamma': 4.325839013631253, 'output_chunk_length': 2}. Best is trial 248 with value: 1345.572021484375.
# [I 2024-09-12 08:56:38,777] Trial 270 finished with value: 1357.793212890625 and parameters: {'max_depth': 7, 'learning_rate': 0.1560427522622804, 'n_estimators': 338, 'input_chunk_length': 21, 'min_child_weight': 0.8016398643668853, 'subsample': 0.8694677898859232, 'colsample_bytree': 0.8972408113155957, 'gamma': 4.148935880812544, 'output_chunk_length': 1}. Best is trial 248 with value: 1345.572021484375.
# [I 2024-09-12 08:56:39,206] Trial 266 finished with value: 1354.193115234375 and parameters: {'max_depth': 7, 'learning_rate': 0.14870287855601677, 'n_estimators': 322, 'input_chunk_length': 21, 'min_child_weight': 0.6162078096369283, 'subsample': 0.646566634928287, 'colsample_bytree': 0.9393366188834927, 'gamma': 4.3888688030365985, 'output_chunk_length': 7}. Best is trial 248 with value: 1345.572021484375.
# [I 2024-09-12 08:56:41,878] Trial 267 finished with value: 1358.216796875 and parameters: {'max_depth': 7, 'learning_rate': 0.1541491921236885, 'n_estimators': 319, 'input_chunk_length': 23, 'min_child_weight': 0.6191216717490642, 'subsample': 0.8139292392962331, 'colsample_bytree': 0.9355108704366784, 'gamma': 4.438817814382268, 'output_chunk_length': 7}. Best is trial 248 with value: 1345.572021484375.
# [I 2024-09-12 08:56:54,488] Trial 269 finished with value: 1357.707275390625 and parameters: {'max_depth': 7, 'learning_rate': 0.15202466985942764, 'n_estimators': 341, 'input_chunk_length': 23, 'min_child_weight': 1.0300945422777552, 'subsample': 0.8228297768820817, 'colsample_bytree': 0.8971491990828776, 'gamma': 4.438475223855309, 'output_chunk_length': 7}. Best is trial 248 with value: 1345.572021484375.
# [I 2024-09-12 08:57:00,095] Trial 271 finished with value: 1353.232421875 and parameters: {'max_depth': 6, 'learning_rate': 0.15909231090260087, 'n_estimators': 336, 'input_chunk_length': 19, 'min_child_weight': 0.8025386690263737, 'subsample': 0.8256891319636852, 'colsample_bytree': 0.900421959695225, 'gamma': 4.142631209444637, 'output_chunk_length': 7}. Best is trial 248 with value: 1345.572021484375.
# [I 2024-09-12 08:57:02,658] Trial 272 finished with value: 1346.5501708984375 and parameters: {'max_depth': 6, 'learning_rate': 0.10771338522107393, 'n_estimators': 326, 'input_chunk_length': 10, 'min_child_weight': 0.26364730870715136, 'subsample': 0.8307215879217765, 'colsample_bytree': 0.9150451184048499, 'gamma': 4.439302557672396, 'output_chunk_length': 7}. Best is trial 248 with value: 1345.572021484375.
# [I 2024-09-12 08:57:03,975] Trial 273 finished with value: 1349.403076171875 and parameters: {'max_depth': 6, 'learning_rate': 0.10558626531514798, 'n_estimators': 339, 'input_chunk_length': 10, 'min_child_weight': 0.347436924032354, 'subsample': 0.7959131050162941, 'colsample_bytree': 0.9210243224399376, 'gamma': 4.07364085484101, 'output_chunk_length': 7}. Best is trial 248 with value: 1345.572021484375.
# [I 2024-09-12 08:57:06,791] Trial 274 finished with value: 1349.5601806640625 and parameters: {'max_depth': 6, 'learning_rate': 0.11222834429499837, 'n_estimators': 342, 'input_chunk_length': 10, 'min_child_weight': 1.0935351900561099, 'subsample': 0.7995575991662072, 'colsample_bytree': 0.7298519408792769, 'gamma': 4.059660047504252, 'output_chunk_length': 7}. Best is trial 248 with value: 1345.572021484375.
# [I 2024-09-12 08:57:18,268] Trial 275 finished with value: 1346.3731689453125 and parameters: {'max_depth': 6, 'learning_rate': 0.2579225828985157, 'n_estimators': 329, 'input_chunk_length': 10, 'min_child_weight': 0.28930484011238755, 'subsample': 0.7951290113941817, 'colsample_bytree': 0.7306177077169833, 'gamma': 4.067835256151922, 'output_chunk_length': 7}. Best is trial 248 with value: 1345.572021484375.
# [I 2024-09-12 08:57:20,940] Trial 276 finished with value: 1349.563720703125 and parameters: {'max_depth': 5, 'learning_rate': 0.1037584861492386, 'n_estimators': 287, 'input_chunk_length': 10, 'min_child_weight': 0.2790581813862877, 'subsample': 0.7943879653941066, 'colsample_bytree': 0.7241583884282002, 'gamma': 4.033354978327623, 'output_chunk_length': 7}. Best is trial 248 with value: 1345.572021484375.
# [I 2024-09-12 08:57:23,457] Trial 277 finished with value: 1348.9019775390625 and parameters: {'max_depth': 6, 'learning_rate': 0.1329076714224824, 'n_estimators': 288, 'input_chunk_length': 10, 'min_child_weight': 0.32629541173372517, 'subsample': 0.7966304854153683, 'colsample_bytree': 0.9157636245478856, 'gamma': 4.295864337921125, 'output_chunk_length': 7}. Best is trial 248 with value: 1345.572021484375.
# [I 2024-09-12 08:57:27,597] Trial 278 finished with value: 1344.835205078125 and parameters: {'max_depth': 7, 'learning_rate': 0.24593457848977612, 'n_estimators': 328, 'input_chunk_length': 10, 'min_child_weight': 7.490516890310022, 'subsample': 0.7984300649642175, 'colsample_bytree': 0.8436499285402732, 'gamma': 4.29661959718613, 'output_chunk_length': 7}. Best is trial 278 with value: 1344.835205078125.
# [I 2024-09-12 08:57:30,255] Trial 279 finished with value: 1349.02001953125 and parameters: {'max_depth': 7, 'learning_rate': 0.2477557877070336, 'n_estimators': 326, 'input_chunk_length': 15, 'min_child_weight': 0.2531006681896858, 'subsample': 0.7283613114448343, 'colsample_bytree': 0.8407041439605778, 'gamma': 4.286213986035959, 'output_chunk_length': 7}. Best is trial 278 with value: 1344.835205078125.
# [I 2024-09-12 08:57:42,144] Trial 280 finished with value: 1349.1234130859375 and parameters: {'max_depth': 6, 'learning_rate': 0.1346899419598135, 'n_estimators': 328, 'input_chunk_length': 15, 'min_child_weight': 0.26386139058081004, 'subsample': 0.8295882595608826, 'colsample_bytree': 0.8444430699340444, 'gamma': 4.298963174101589, 'output_chunk_length': 7}. Best is trial 278 with value: 1344.835205078125.
# [I 2024-09-12 08:57:44,987] Trial 281 finished with value: 1349.871826171875 and parameters: {'max_depth': 6, 'learning_rate': 0.28674529818012984, 'n_estimators': 327, 'input_chunk_length': 16, 'min_child_weight': 0.30089524693158687, 'subsample': 0.8290104073298882, 'colsample_bytree': 0.845746763565575, 'gamma': 4.288622130080952, 'output_chunk_length': 7}. Best is trial 278 with value: 1344.835205078125.
# [I 2024-09-12 08:57:47,621] Trial 282 finished with value: 1348.1680908203125 and parameters: {'max_depth': 6, 'learning_rate': 0.2591958208654825, 'n_estimators': 328, 'input_chunk_length': 16, 'min_child_weight': 0.23330767033846614, 'subsample': 0.7288304887079288, 'colsample_bytree': 0.8862084150075896, 'gamma': 4.279428086577983, 'output_chunk_length': 7}. Best is trial 278 with value: 1344.835205078125.
# [I 2024-09-12 08:57:51,959] Trial 283 finished with value: 1348.1951904296875 and parameters: {'max_depth': 6, 'learning_rate': 0.2558345042788325, 'n_estimators': 328, 'input_chunk_length': 16, 'min_child_weight': 7.4638191810045535, 'subsample': 0.8256133640063056, 'colsample_bytree': 0.8502762564142988, 'gamma': 4.293382820727413, 'output_chunk_length': 7}. Best is trial 278 with value: 1344.835205078125.
# [I 2024-09-12 08:57:54,953] Trial 284 finished with value: 1351.950439453125 and parameters: {'max_depth': 6, 'learning_rate': 0.2673566238418916, 'n_estimators': 330, 'input_chunk_length': 16, 'min_child_weight': 7.187067263206925, 'subsample': 0.7872687261937072, 'colsample_bytree': 0.8562397212194527, 'gamma': 4.509359523098757, 'output_chunk_length': 7}. Best is trial 278 with value: 1344.835205078125.
# [I 2024-09-12 08:58:05,054] Trial 285 finished with value: 1349.789306640625 and parameters: {'max_depth': 7, 'learning_rate': 0.2779150940300364, 'n_estimators': 307, 'input_chunk_length': 18, 'min_child_weight': 6.897472254348176, 'subsample': 0.7840502617645211, 'colsample_bytree': 0.8590607597381693, 'gamma': 4.523165436935268, 'output_chunk_length': 7}. Best is trial 278 with value: 1344.835205078125.
# [I 2024-09-12 08:58:07,868] Trial 286 finished with value: 1350.7088623046875 and parameters: {'max_depth': 7, 'learning_rate': 0.24860819333821882, 'n_estimators': 306, 'input_chunk_length': 18, 'min_child_weight': 7.1989662011925954, 'subsample': 0.7848729196461296, 'colsample_bytree': 0.8593915672907138, 'gamma': 4.4765317515381335, 'output_chunk_length': 7}. Best is trial 278 with value: 1344.835205078125.
# [I 2024-09-12 08:58:10,706] Trial 287 finished with value: 1350.1243896484375 and parameters: {'max_depth': 6, 'learning_rate': 0.2445533264353593, 'n_estimators': 307, 'input_chunk_length': 18, 'min_child_weight': 7.142013971215724, 'subsample': 0.7822798261151114, 'colsample_bytree': 0.8857043970926205, 'gamma': 4.512131181320147, 'output_chunk_length': 7}. Best is trial 278 with value: 1344.835205078125.
# [I 2024-09-12 08:58:14,985] Trial 288 finished with value: 1351.291748046875 and parameters: {'max_depth': 6, 'learning_rate': 0.2540517616854296, 'n_estimators': 306, 'input_chunk_length': 19, 'min_child_weight': 7.053190538451933, 'subsample': 0.8076217830633441, 'colsample_bytree': 0.8527062974466167, 'gamma': 4.1829584512881715, 'output_chunk_length': 7}. Best is trial 278 with value: 1344.835205078125.
# [I 2024-09-12 08:58:18,120] Trial 289 finished with value: 1351.4954833984375 and parameters: {'max_depth': 6, 'learning_rate': 0.2990898256982514, 'n_estimators': 306, 'input_chunk_length': 20, 'min_child_weight': 7.886202005043034, 'subsample': 0.8126628804627977, 'colsample_bytree': 0.8548374049592549, 'gamma': 4.182931996576204, 'output_chunk_length': 7}. Best is trial 278 with value: 1344.835205078125.
# [I 2024-09-12 08:58:33,907] Trial 290 finished with value: 1378.1573486328125 and parameters: {'max_depth': 6, 'learning_rate': 0.23723187147524105, 'n_estimators': 328, 'input_chunk_length': 77, 'min_child_weight': 8.111990180334645, 'subsample': 0.8088863931713297, 'colsample_bytree': 0.8684278805759932, 'gamma': 4.187713002216476, 'output_chunk_length': 7}. Best is trial 278 with value: 1344.835205078125.
# [I 2024-09-12 08:58:36,307] Trial 291 finished with value: 1349.1817626953125 and parameters: {'max_depth': 6, 'learning_rate': 0.2309216882524723, 'n_estimators': 330, 'input_chunk_length': 14, 'min_child_weight': 0.13175643588401842, 'subsample': 0.8044731940784543, 'colsample_bytree': 0.8718157993770098, 'gamma': 4.163887327399143, 'output_chunk_length': 7}. Best is trial 278 with value: 1344.835205078125.
# [I 2024-09-12 08:58:39,883] Trial 292 finished with value: 1373.647216796875 and parameters: {'max_depth': 6, 'learning_rate': 0.2241377933017688, 'n_estimators': 328, 'input_chunk_length': 72, 'min_child_weight': 7.8654532621706785, 'subsample': 0.8366642809926857, 'colsample_bytree': 0.8677917494937155, 'gamma': 4.190370998190986, 'output_chunk_length': 7}. Best is trial 278 with value: 1344.835205078125.
# [I 2024-09-12 08:58:43,645] Trial 293 finished with value: 1346.781982421875 and parameters: {'max_depth': 7, 'learning_rate': 0.23324108715326825, 'n_estimators': 328, 'input_chunk_length': 14, 'min_child_weight': 7.612095068823875, 'subsample': 0.8406600845875608, 'colsample_bytree': 0.8695831786352975, 'gamma': 4.175556147781929, 'output_chunk_length': 7}. Best is trial 278 with value: 1344.835205078125.
# [I 2024-09-12 08:58:46,620] Trial 294 finished with value: 1348.1539306640625 and parameters: {'max_depth': 7, 'learning_rate': 0.22313555307422342, 'n_estimators': 327, 'input_chunk_length': 14, 'min_child_weight': 8.994217565717138, 'subsample': 0.8242863627028395, 'colsample_bytree': 0.8739890051653642, 'gamma': 4.365793608566498, 'output_chunk_length': 7}. Best is trial 278 with value: 1344.835205078125.
# [I 2024-09-12 08:59:00,541] Trial 295 finished with value: 1360.8218994140625 and parameters: {'max_depth': 7, 'learning_rate': 0.2142509213406491, 'n_estimators': 320, 'input_chunk_length': 26, 'min_child_weight': 7.491472597791898, 'subsample': 0.8319149787826174, 'colsample_bytree': 0.8739581911576751, 'gamma': 4.364737227932855, 'output_chunk_length': 7}. Best is trial 278 with value: 1344.835205078125.
# [I 2024-09-12 08:59:02,272] Trial 296 finished with value: 1361.0638427734375 and parameters: {'max_depth': 7, 'learning_rate': 0.18709798542494085, 'n_estimators': 318, 'input_chunk_length': 26, 'min_child_weight': 7.626682435290041, 'subsample': 0.8401708341739916, 'colsample_bytree': 0.8842899856901009, 'gamma': 4.3604933699858375, 'output_chunk_length': 7}. Best is trial 278 with value: 1344.835205078125.
# [I 2024-09-12 08:59:03,922] Trial 297 finished with value: 1350.590087890625 and parameters: {'max_depth': 7, 'learning_rate': 0.18316088325433016, 'n_estimators': 316, 'input_chunk_length': 14, 'min_child_weight': 7.688193594795246, 'subsample': 0.8232606790924303, 'colsample_bytree': 0.8771877807842784, 'gamma': 4.322214159538651, 'output_chunk_length': 7}. Best is trial 278 with value: 1344.835205078125.
# [I 2024-09-12 08:59:05,418] Trial 298 finished with value: 1361.74951171875 and parameters: {'max_depth': 7, 'learning_rate': 0.18306888650609845, 'n_estimators': 316, 'input_chunk_length': 27, 'min_child_weight': 7.709411876080394, 'subsample': 0.843263708895821, 'colsample_bytree': 0.8844276796114608, 'gamma': 4.373988288891721, 'output_chunk_length': 7}. Best is trial 278 with value: 1344.835205078125.
# [I 2024-09-12 08:59:05,973] Trial 299 finished with value: 1351.914794921875 and parameters: {'max_depth': 7, 'learning_rate': 0.1908145224454625, 'n_estimators': 317, 'input_chunk_length': 13, 'min_child_weight': 8.768330374472795, 'subsample': 0.8434884156920979, 'colsample_bytree': 0.8850097496189208, 'gamma': 4.367500324088432, 'output_chunk_length': 7}. Best is trial 278 with value: 1344.835205078125.
# Best hyperparameters for 10 splits:  {'max_depth': 7, 'learning_rate': 0.24593457848977612, 'n_estimators': 328, 'input_chunk_length': 10, 'min_child_weight': 7.490516890310022, 'subsample': 0.7984300649642175, 'colsample_bytree': 0.8436499285402732, 'gamma': 4.29661959718613, 'output_chunk_length': 7}
#
# Best hyperparameter combination and error metrics for the best TimeSeriesSplit configuration:
# Best n_splits: n_splits_5
# Best hyperparameters: {'max_depth': 7, 'learning_rate': 0.24593457848977612, 'n_estimators': 328, 'input_chunk_length': 10, 'min_child_weight': 7.490516890310022, 'subsample': 0.7984300649642175, 'colsample_bytree': 0.8436499285402732, 'gamma': 4.29661959718613, 'output_chunk_length': 7}
# MSE: 4331.71484375
# MAE: 43.07174301147461
# MAPE: nan
# RMSE: 65.81576538085938
#
# Error metrics for the test data using the best hyperparameters:
# MSE on Test Set: 13307.6220703125
# MAE on Test Set: 73.95270538330078
# MAPE on Test Set: nan
# RMSE on Test Set: 115.3586654663086

# %% [markdown]
# #### Including self-written Cross-Validation

# %%
import pandas as pd
import numpy as np
from darts import TimeSeries
from darts.models import XGBModel
from darts.dataprocessing.transformers import Scaler
from darts.metrics import mape, rmse, mse, mae
import optuna
from optuna.pruners import MedianPruner
import plotly.graph_objs as go

# Custom cross-validation function
def custom_time_series_cv(series, n_splits, min_train_size):
    """ Custom cross-validation for time series that accounts for seasonality and other patterns. """
    series_length = len(series)
    fold_size = (series_length - min_train_size) // n_splits
    indices = np.arange(series_length)
    
    for i in range(n_splits):
        train_end = min_train_size + i * fold_size
        test_start = train_end
        test_end = test_start + fold_size

        if test_end > series_length:
            break  # Avoid out-of-bound indices
        
        yield indices[:train_end], indices[test_start:test_end]

# Function to train the model and evaluate performance using cross-validation with pruning
def train_and_evaluate(tscv_generator, series_train_scaled, future_covariates_train_scaled, scaler_series, n_splits):
    def objective(trial):
        # Define hyperparameters to tune
        max_depth = trial.suggest_int('max_depth', 3, 15)
        n_estimators = trial.suggest_int('n_estimators', 50, 500)
        input_chunk_length = trial.suggest_int('input_chunk_length', 50, 200) 
        min_child_weight = trial.suggest_float('min_child_weight', 0.1, 10.0)
        subsample = trial.suggest_float('subsample', 0.5, 1.0)
        colsample_bytree = trial.suggest_float('colsample_bytree', 0.5, 1.0)
        # Refine hyperparameters with smaller ranges
        learning_rate = trial.suggest_float('learning_rate', 0.001, 0.05, log=True)
        gamma = trial.suggest_float('gamma', 0, 2)


        # Initialize the model with the trial hyperparameters (no model argument)
        model = XGBModel(
            lags=input_chunk_length,
            output_chunk_length=1,
            lags_future_covariates=[0],
            max_depth=max_depth,
            learning_rate=learning_rate,
            n_estimators=n_estimators,
            min_child_weight=min_child_weight,
            subsample=subsample,
            colsample_bytree=colsample_bytree,
            gamma=gamma,
            random_state=42
        )

        # Cross-validation loop with early stopping
        errors_mse, errors_mae, errors_mape, errors_rmse = [], [], [], []

        # Initialize a counter for iterations
        i = 0

        # Cross-validation loop with early stopping
        for train_index, test_index in tscv_generator:
            # Check if there is enough data in the current fold to accommodate input_chunk_length
            if len(train_index) <= input_chunk_length:
                continue  # Skip this fold if not enough data

            # Get the corresponding date ranges from indices
            train_start, train_end = series_train_scaled.time_index[train_index[0]], series_train_scaled.time_index[train_index[-1]]
            test_start, test_end = series_train_scaled.time_index[test_index[0]], series_train_scaled.time_index[test_index[-1]]

            # Slice the TimeSeries objects based on date ranges
            train_series = series_train_scaled.slice(train_start, train_end)
            val_series = series_train_scaled.slice(test_start, test_end)
            train_covariates = future_covariates_train_scaled.slice(train_start, train_end)
            val_covariates = future_covariates_train_scaled.slice(test_start, test_end)

            # Train the model on the training set
            model.fit(train_series, future_covariates=train_covariates)

            # Predict on the validation set
            forecast_scaled = model.predict(n=len(val_series), future_covariates=val_covariates)

            # Inverse transform the forecast to the original scale
            forecast = scaler_series.inverse_transform(forecast_scaled)

            # Calculate errors on the validation set
            errors_mse.append(mse(val_series, forecast))
            errors_mae.append(mae(val_series, forecast))
            errors_rmse.append(rmse(val_series, forecast))

            # Only calculate MAPE if all actual values are positive
            if (val_series.values() > 0).all():
                errors_mape.append(mape(val_series, forecast))
            else:
                errors_mape.append(np.nan)  # Handle cases where MAPE cannot be calculated

            # Prune trial if not improving
            trial.report(np.mean(errors_mse), i)
            if trial.should_prune():
                raise optuna.exceptions.TrialPruned()

            # Increment the iteration counter
            i += 1

        # Safely calculate the average metrics
        mse_mean = np.nanmean(errors_mse) if errors_mse else np.inf
        mae_mean = np.nanmean(errors_mae) if errors_mae else np.inf
        rmse_mean = np.nanmean(errors_rmse) if errors_rmse else np.inf
        mape_mean = np.nanmean(errors_mape) if errors_mape else np.nan

        # Return the average MSE across all splits as the metric to optimize
        if np.isnan(mse_mean):
            return np.inf  # Return a high value if the result is NaN
        return mse_mean

    # Create an Optuna study with a pruner and optimize
    study = optuna.create_study(direction='minimize', pruner=optuna.pruners.PatientPruner(optuna.pruners.MedianPruner()))
    study.optimize(objective, n_trials=100, n_jobs=5)

    return study

# Function to make final predictions and evaluate on the test set
def final_model_evaluation(best_params, series_train_scaled, future_covariates_train_scaled, series_test, future_covariates_test_scaled, scaler_series):
    best_model = XGBModel(
        lags=best_params['input_chunk_length'],
        output_chunk_length=1,  # Predicting one day at a time
        lags_future_covariates=[0],  # Using the current value of future covariates for prediction
        max_depth=best_params['max_depth'],
        learning_rate=best_params['learning_rate'],
        n_estimators=best_params['n_estimators'],
        min_child_weight=best_params['min_child_weight'],
        subsample=best_params['subsample'],
        colsample_bytree=best_params['colsample_bytree'],
        gamma=best_params['gamma'],
        random_state=42
    )

    # Fit the model on the entire scaled training set
    best_model.fit(series_train_scaled, future_covariates=future_covariates_train_scaled)

    # Make predictions on the test set
    forecast_scaled = best_model.predict(n=len(series_test), future_covariates=future_covariates_test_scaled)

    # Inverse transform the forecast to the original scale
    forecast = scaler_series.inverse_transform(forecast_scaled)

    return forecast

# Convert future covariates to TimeSeries objects
future_covariates_train = TimeSeries.from_dataframe(train_df, 'Date', future_covariates_columns).astype('float32')
future_covariates_full = TimeSeries.from_dataframe(df, 'Date', future_covariates_columns, fill_missing_dates=True, freq="D").astype('float32')

# Scaling the data
scaler_series = Scaler()
scaler_covariates = Scaler()

# Fit the scaler on the full training data
series_train_scaled = scaler_series.fit_transform(series_train)
future_covariates_train_scaled = scaler_covariates.fit_transform(future_covariates_train)

# Define list of n_splits to try
n_splits_list = [5, 10, 15]

# Initialize a dictionary to store DataFrames for each n_splits value
results_dict = {}

# Loop over different n_splits values
min_train_size = 200  # Define a minimum training size to ensure seasonality capture or other patterns
for n_splits in n_splits_list:
    print(f"Processing custom cross-validation with {n_splits} splits...")

    # Create custom cross-validation generator
    tscv_generator = custom_time_series_cv(series_train_scaled.pd_dataframe(), n_splits=n_splits, min_train_size=min_train_size)
    
    # Train and evaluate model using cross-validation with pruning
    study = train_and_evaluate(tscv_generator, series_train_scaled, future_covariates_train_scaled, scaler_series, n_splits)

    # Print the best hyperparameters
    print(f'Best hyperparameters for {n_splits} splits: ', study.best_params)

    # Store the best hyperparameters for each split setting
    best_params = study.best_params

    # --- Slicing the Test Covariates According to Best `input_chunk_length` ---
    input_chunk_length = best_params['input_chunk_length']
    required_start_date = pd.Timestamp(test_df['Date'].iloc[0]) - pd.DateOffset(days=input_chunk_length)
    required_end_date = pd.Timestamp(test_df['Date'].iloc[0]) + pd.DateOffset(days=len(series_test) - 1)
    future_covariates_test = future_covariates_full.slice(required_start_date, required_end_date)
    future_covariates_test_scaled = scaler_covariates.transform(future_covariates_test)

    # Make final predictions on the test set using the best hyperparameters
    forecast = final_model_evaluation(best_params, series_train_scaled, future_covariates_train_scaled, series_test, future_covariates_test_scaled, scaler_series)

    # Store the results
    results_dict[f'n_splits_{n_splits}'] = pd.DataFrame({
        'mse': [mse(series_test, forecast)],
        'mae': [mae(series_test, forecast)],
        'mape': [mape(series_test, forecast) if (series_test.values() > 0).all() else np.nan],
        'rmse': [rmse(series_test, forecast)]
    })

# Find the best n_splits based on the lowest mse
comparison_df = pd.concat(
    [df.assign(n_splits=int(n_splits.split('_')[-1])) for n_splits, df in results_dict.items()]
)

best_n_splits = comparison_df['n_splits'].iloc[comparison_df['mse'].idxmin()]

# Corrected: Format the key properly to match the results_dict keys
best_n_splits_key = f'n_splits_{best_n_splits}'  # No need to convert to int, as it's already the correct format

# Extract the best hyperparameters for the best n_splits
best_results_df = results_dict[best_n_splits_key]
best_trial = best_results_df.loc[best_results_df['mse'].idxmin()]

print("\nBest hyperparameter combination and error metrics for the best TimeSeriesSplit configuration:")
print(f"Best n_splits: {best_n_splits_key}")
print(f"Best hyperparameters: {study.best_params}")
print(f"MSE: {best_trial['mse']}")
print(f"MAE: {best_trial['mae']}")
print(f"MAPE: {best_trial['mape']}")
print(f"RMSE: {best_trial['rmse']}")

# Evaluate error metrics on the full test data using the best hyperparameters
mse_test = mse(series_test, forecast)
mae_test = mae(series_test, forecast)
mape_test = mape(series_test, forecast) if (series_test.values() > 0).all() else np.nan
rmse_test = rmse(series_test, forecast)

print("\nError metrics for the test data using the best hyperparameters:")
print(f"MSE on Test Set: {mse_test}")
print(f"MAE on Test Set: {mae_test}")
print(f"MAPE on Test Set: {mape_test}")
print(f"RMSE on Test Set: {rmse_test}")

# Plot the results using Plotly for the best hyperparameters
test_df_plotly = series_test.pd_dataframe()
forecast_df_plotly = forecast.pd_dataframe()

fig = go.Figure()

# Add actual test data trace
fig.add_trace(go.Scatter(x=test_df_plotly.index, y=test_df_plotly['Day_ahead_price (€/MWh)'],
                         mode='lines', name='Actual Test Data', line=dict(color='darkblue')))

# Add forecast data trace
fig.add_trace(go.Scatter(x=forecast_df_plotly.index, y=forecast_df_plotly['Day_ahead_price (€/MWh)'],
                         mode='lines', name='XGBoost Forecast on Test Data', line=dict(color='red')))

# Update layout
fig.update_layout(
    title=f'XGBoost Model - Test Performance (Best n_splits={best_n_splits_key})',
    xaxis_title='Date',
    yaxis_title='Day Ahead Price (€/MWh)',
    legend=dict(
        x=1,   # Set x position to 1 (far right)
        y=1,   # Set y position to 1 (top)
        xanchor='right',  # Anchor the legend's x position to the right
        yanchor='top',    # Anchor the legend's y position to the top
        bordercolor='black',  # Optional: Add a border around the legend
        borderwidth=1        # Optional: Set the border width
    ),
    template='plotly'
)

# Show the plot
fig.show()
# Out:
# Processing custom cross-validation with 5 splits...
# /var/folders/8w/b_0gc01d70g6h4k62sb7ytyw0000gn/T/ipykernel_25368/841950022.py:120: ExperimentalWarning:
#
# PatientPruner is experimental (supported from v2.8.0). The interface can change in the future.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 179
#     176 tscv_generator = custom_time_series_cv(series_train_scaled.pd_dataframe(), n_splits=n_splits, min_train_size=min_train_size)
#     178 # Train and evaluate model using cross-validation with pruning
# --> 179 study = train_and_evaluate(tscv_generator, series_train_scaled, future_covariates_train_scaled, scaler_series, n_splits)
#     181 # Print the best hyperparameters
#     182 print(f'Best hyperparameters for {n_splits} splits: ', study.best_params)
#
# Cell In[28], line 120, in train_and_evaluate(tscv_generator, series_train_scaled, future_covariates_train_scaled, scaler_series, n_splits)
#     117     return mse_mean
#     119 # Create an Optuna study with a pruner and optimize
# --> 120 study = optuna.create_study(direction='minimize', pruner=optuna.pruners.PatientPruner(optuna.pruners.MedianPruner()))
#     121 study.optimize(objective, n_trials=100, n_jobs=5)
#     123 return study
#
# File ~/Documents/Masterarbeit/Prediction_of_energy_prices/master_thesis/lib/python3.10/site-packages/optuna/_experimental.py:114, in experimental_class.<locals>.decorator.<locals>.wrapper.<locals>.wrapped_init(self, *args, **kwargs)
#     103 @functools.wraps(_original_init)
#     104 def wrapped_init(self: Any, *args: Any, **kwargs: Any) -> None:
#     105     warnings.warn(
#     106         "{} is experimental (supported from v{}). "
#     107         "The interface can change in the future.".format(
#    (...)
#     111         stacklevel=2,
#     112     )
# --> 114     _original_init(self, *args, **kwargs)
#
# TypeError: PatientPruner.__init__() missing 1 required positional argument: 'patience'

# %%
import pandas as pd
import numpy as np
from darts import TimeSeries
from darts.models import XGBModel
from darts.dataprocessing.transformers import Scaler
from darts.metrics import mape, rmse, mse, mae
import plotly.graph_objs as go

# Convert future covariates to TimeSeries objects (if you have future covariates, otherwise omit this)
future_covariates_train = TimeSeries.from_dataframe(train_df, 'Date', future_covariates_columns).astype('float32')
future_covariates_full = TimeSeries.from_dataframe(df, 'Date', future_covariates_columns, fill_missing_dates=True, freq="D").astype('float32')

# Scaling the data
scaler_series = Scaler()
scaler_covariates = Scaler()

# Fit the scaler on the full training data
series_train_scaled = scaler_series.fit_transform(series_train)
future_covariates_train_scaled = scaler_covariates.fit_transform(future_covariates_train)

# --- XGBoost Model ---
# Define the model
xgb_model = XGBModel(
    lags=120,  # Number of past lags to use for the model
    output_chunk_length=1,  # Predict one step ahead
    lags_future_covariates=[0],  # You need to specify the lags for future covariates
    max_depth=6,  # Example of hyperparameter
    n_estimators=500,  # Number of trees in the model
    learning_rate=0.03,  # Learning rate
    random_state=42
)

# Train the model on the scaled training data
xgb_model.fit(series_train_scaled, future_covariates=future_covariates_train_scaled)

# --- Testing the model ---
# Scale the test data
series_test_scaled = scaler_series.transform(series_test)
future_covariates_test_scaled = scaler_covariates.transform(future_covariates_test)

# Make predictions on the test set
forecast_scaled = xgb_model.predict(n=len(series_test), future_covariates=future_covariates_test_scaled)

# Inverse transform the forecast to the original scale
forecast = scaler_series.inverse_transform(forecast_scaled)

# --- Evaluate the performance ---
mse_test = mse(series_test, forecast)
mae_test = mae(series_test, forecast)
rmse_test = rmse(series_test, forecast)

# Only calculate MAPE if actual values are positive
if (series_test.values() > 0).all():
    mape_test = mape(series_test, forecast)
else:
    mape_test = np.nan

print(f"MSE on Test Set: {mse_test}")
print(f"MAE on Test Set: {mae_test}")
print(f"MAPE on Test Set: {mape_test}")
print(f"RMSE on Test Set: {rmse_test}")

# --- Plot the results using Plotly ---
test_df_plotly = series_test.pd_dataframe()
forecast_df_plotly = forecast.pd_dataframe()

fig = go.Figure()

# Add actual test data trace
fig.add_trace(go.Scatter(x=test_df_plotly.index, y=test_df_plotly['Day_ahead_price (€/MWh)'],
                         mode='lines', name='Actual Test Data', line=dict(color='darkblue')))

# Add forecast data trace
fig.add_trace(go.Scatter(x=forecast_df_plotly.index, y=forecast_df_plotly['Day_ahead_price (€/MWh)'],
                         mode='lines', name='XGBoost Forecast on Test Data', line=dict(color='red')))

# Update layout
fig.update_layout(
    title='XGBoost Model - Test Performance',
    xaxis_title='Date',
    yaxis_title='Day Ahead Price (€/MWh)',
    legend=dict(
        x=1,   
        y=1,   
        xanchor='right',  
        yanchor='top',    
        bordercolor='black',  
        borderwidth=1        
    ),
    template='plotly_white'
)

# Show the plot
fig.show()
# Out:
# MSE on Test Set: 4220.7763671875
# MAE on Test Set: 44.283077239990234
# MAPE on Test Set: nan
# RMSE on Test Set: 64.96749877929688
